# %% [markdown]
# # 1. Fuentes de información

# %% [markdown]
# ## 1.0 Importación de liberías

# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# ## 1.1 Definicion de rutas absolutas

# %%
BASE_DIR = Path().resolve() 
DATA_DIR = BASE_DIR /"Data"/ "Extraidos"
DURACION_CURSO = DATA_DIR / "duracion_asignatura.csv" 
PLANES_ESTUDIO = DATA_DIR / "plan_estudios.csv"
DOCENTES_MINIMO = DATA_DIR / "docentes_minimos.csv"
DISPONIBILIDAD_DOCENTE = DATA_DIR / "disponibilidad_docentes_simulada.csv"

# %% [markdown]
# ## 1.2 Lectura de datasets

# %%
df_duracion = pd.read_csv(DURACION_CURSO,sep=";",encoding="utf-8-sig")
df_duracion.head()
# Out:
#                             NomAsignatura  DuracionHoras  Ciclo CodAsignatura
# 0                           ALGORÍTMICA I            5.0      3      202W0301
# 1                             ESTADÍSTICA            5.0      3      202W0302
# 2                      FISICA ELÉCTRONICA            4.0      3      202W0303
# 3                    INGENIERÍA ECONÓMICA            4.0      3      202W0304
# 4  INTRODUCCIÓN AL DESARROLLO DE SOFTWARE            4.0      3      202W0305

# %%
df_plan = pd.read_csv(PLANES_ESTUDIO,sep=";",encoding="utf-8-sig")
df_plan.head()
# Out:
#    Ciclo  Créditos CodAsignatura  \
# 0      1       2.0        INE002
# 1      1       2.0        INE013
# 2      1       3.0        INO101
# 3      1       2.0        INO102
# 4      1       2.0        INO103
#
#                                      NomAsignatura Cod Pre-Requisito  \
# 0                       PROGRAMACIÓN Y COMPUTACIÓN               NaN
# 1                      EMPRENDIMIENTO E INNOVACIÓN               NaN
# 2  REDACCIÓN Y TÉCNICAS DE COMUNICACIÓN EFECTIVA I               NaN
# 3                 MÉTODOS DE ESTUDIO UNIVERSITARIO               NaN
# 4                  DESARROLLO PERSONAL Y LIDERAZGO               NaN
#
#   Nom Pre-Requisito
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
df_docentes_min = pd.read_csv(DOCENTES_MINIMO,sep=";",encoding="utf-8-sig")
df_docentes_min.head()
# Out:
#   CodAsignatura                           NomAsignatura  Matriculados  \
# 0      202W0301                           ALGORÍTMICA I            10
# 1      202W0302                             ESTADÍSTICA             5
# 2      202W0303                      FISICA ELÉCTRONICA             6
# 3      202W0304                    INGENIERÍA ECONÓMICA             2
# 4      202W0305  INTRODUCCIÓN AL DESARROLLO DE SOFTWARE             4
#
#    DuracionHoras  NumGrupos  HorasTotales
# 0            5.0          1           5.0
# 1            5.0          1           5.0
# 2            4.0          1           4.0
# 3            4.0          1           4.0
# 4            4.0          1           4.0

# %%
df_disp = pd.read_csv(DISPONIBILIDAD_DOCENTE,sep=",",encoding="utf-8-sig")
df_disp.head()
# Out:
#   CodDocente CodAsignatura     Día HoraInicio HoraFin  DuracionHoras  Ciclo
# 0     085774      202W0301   LUNES      14:00   19:00            5.0      3
# 1     0A1609      202W0301  JUEVES      17:00   22:00            5.0      3
# 2     0A9179      202W0301   LUNES      08:00   13:00            5.0      3
# 3     007056      202W0302  JUEVES      08:00   13:00            5.0      3
# 4     043788      202W0302  JUEVES      08:00   13:00            5.0      3

# %% [markdown]
# ## 1.3 Generación de datasets restantes

# %%
# Eliminar duplicados para quedarte solo con relaciones únicas docente-curso
df_docente_curso = df_disp[["CodDocente", "CodAsignatura"]].drop_duplicates()

# Agrupar por docente si quieres ver todos los cursos que puede dictar
docentes_con_cursos = df_docente_curso.groupby("CodDocente")["CodAsignatura"].apply(list).reset_index()

# Si quieres usarlo como diccionario:
dict_docente_cursos = df_docente_curso.groupby("CodDocente")["CodAsignatura"].apply(set).to_dict()

# %%
dict_docente_cursos
# Out:
# {'007056': {'202W0302'},
#  '011797': {'202W0704', '202W0803'},
#  '01345428': {'202W0503'},
#  '030228': {'202W0502'},
#  '043788': {'202W0302', '202W0405'},
#  '07240690': {'INE002'},
#  '08232375': {'202W0706', '202W0902', '202W0905'},
#  '08490635': {'202W0304'},
#  '085774': {'202W0301', 'INE002'},
#  '091081': {'202W0706'},
#  '095699': {'202W0407'},
#  '095702': {'202W0607'},
#  '09571E': {'202W0305', '202W0504'},
#  '095729': {'202W0501'},
#  '095753': {'202W0401', '202W0704'},
#  '09620253': {'202W0507', '202W0904'},
#  '099562': {'202W0904'},
#  '099589': {'202W0906'},
#  '0A0182': {'202W0901', 'INE002'},
#  '0A0259': {'202W0306'},
#  '0A0280': {'202W0306'},
#  '0A0307': {'202W0705'},
#  '0A0314': {'202W0305', '202W0808'},
#  '0A06292': {'202W0303'},
#  '0A0690': {'202W0701', '202W0703', '202W0905'},
#  '0A1236': {'202W0802'},
#  '0A1331': {'202W0306'},
#  '0A1607': {'202W0901'},
#  '0A1609': {'202W0301'},
#  '0A1871': {'202W0307', '202W0507', '202W0604'},
#  '0A1873': {'202W0901', '202W0903', '202W0905'},
#  '0A1874': {'202W0807', '202W1004', '202W1005'},
#  '0A1875': {'202W0605', '202W0901'},
#  '0A1876': {'202W0602', '202W1003'},
#  '0A1877': {'202W0503', '202W0706', '202W1006'},
#  '0A1981': {'202W0707', '202W0806'},
#  '0A1982': {'202W0505'},
#  '0A2067': {'202W0702', '202W0705', '202W1001'},
#  '0A2417': {'202W0908', '202W1002'},
#  '0A4049': {'INO205'},
#  '0A4523': {'202W0906'},
#  '0A4524': {'202W0403', '202W0901'},
#  '0A4525': {'202W0603', '202W0701'},
#  '0A5140': {'202W0506'},
#  '0A5230': {'202W0404', '202W0507', '202W1002'},
#  '0A5291': {'202W0601', '202W0704'},
#  '0A5292': {'202W0805', '202W0908'},
#  '0A5306': {'202W0901'},
#  '0A6225': {'202W0803'},
#  '0A6226': {'202W0901', '202W1002'},
#  '0A7565': {'202W0606', '202W0903'},
#  '0A7583': {'202W0303'},
#  '0A7624': {'202W0305'},
#  '0A9124': {'202W0804'},
#  '0A9126': {'202W0703', '202W0907'},
#  '0A9179': {'202W0301', '202W0702'},
#  '10089409': {'202W0502'},
#  '10645375': {'INE002'},
#  '15584946': {'INO101'},
#  '21571331': {'INO106'},
#  '40667934': {'INO106'},
#  '40764399': {'INO204'},
#  '41388541': {'202W0402', 'INO103'},
#  '42229911': {'INO101', 'INO102'},
#  '43813470': {'202W0907'},
#  '44230686': {'202W0705', '202W0801'},
#  '45993187': {'202W0902'},
#  '46107976': {'202W1004'},
#  '72531782': {'202W0506'},
#  'Z000000': {'202W0301'},
#  'Z000016': {'202W0504'},
#  'Z000017': {'202W0505'},
#  'Z000057': {'202W0905'},
#  'Z000058': {'202W0906'},
#  'Z000059': {'202W0906'},
#  'Z000060': {'202W0907'},
#  'Z000061': {'202W0907'},
#  'Z000062': {'202W0908'},
#  'Z000065': {'202W1002'},
#  'Z000070': {'INE002'},
#  'Z000071': {'INO101'}}

# %%
dict_prerrequisitos = {}

for _, fila in df_plan.iterrows():
    curso = fila["CodAsignatura"]
    prereq = fila["Cod Pre-Requisito"]

    if pd.notna(prereq):
        if curso not in dict_prerrequisitos:
            dict_prerrequisitos[curso] = []
        dict_prerrequisitos[curso].append(prereq)

# %%
dict_prerrequisitos
# Out:
# {'INO201': ['INO101'],
#  'INO204': ['INO104'],
#  '202W0401': ['202W0301'],
#  '202W0402': ['202W0307'],
#  '202W0403': ['202W0304'],
#  '202W0404': ['202W0306'],
#  '202W0405': ['202W0302'],
#  '202W0406': ['202W0305', '202W0304'],
#  '202W0407': ['202W0303'],
#  '202W0501': ['202W0401', '202W0405'],
#  '202W0502': ['202W0407'],
#  '202W0503': ['202W0406'],
#  '202W0504': ['202W0404'],
#  '202W0505': ['202W0401'],
#  '202W0506': ['202W0402'],
#  '202W0507': ['202W0406'],
#  '202W0601': ['202W0503'],
#  '202W0602': ['202W0505'],
#  '202W0603': ['202W0507', '202W0505'],
#  '202W0604': ['202W0506', '202W0403'],
#  '202W0605': ['202W0406'],
#  '202W0606': ['202W0504'],
#  '202W0607': ['202W0502'],
#  '202W0701': ['202W0602', '202W0603', '202W0601'],
#  '202W0702': ['202W0602'],
#  '202W0703': ['202W0603', '202W0606'],
#  '202W0704': ['202W0604'],
#  '202W0705': ['202W0606'],
#  '202W0706': ['202W0503', '202W0605'],
#  '202W0707': ['202W0607'],
#  '202W0801': ['202W0707'],
#  '202W0802': ['202W0501', '202W0702'],
#  '202W0803': ['202W0701', '202W0705'],
#  '202W0804': ['202W0702'],
#  '202W0805': ['202W0607'],
#  '202W0806': ['202W0601', '202W0707'],
#  '202W0807': ['202W0701', '202W0702', '202W0703', '202W0707'],
#  '202W0808': ['202W0706'],
#  '202W0901': ['202W0803'],
#  '202W0902': ['202W0806'],
#  '202W0903': ['202W0704'],
#  '202W0904': ['202W0807'],
#  '202W0905': ['202W0704'],
#  '202W0906': ['202W0801'],
#  '202W0907': ['202W0807', '202W0808'],
#  '202W0908': ['202W0705'],
#  '202W1001': ['202W0802', '202W0908'],
#  '202W1002': ['202W0901'],
#  '202W1003': ['202W0907'],
#  '202W1004': ['202W0907'],
#  '202W1005': ['202W0907'],
#  '202W1006': ['202W0903']}

# %% [markdown]
# # 2. Definicion de clases

# %% [markdown]
# ## 2.0 Constructores de clase

# %%
from dataclasses import dataclass, field
from typing import List, Set, Optional
#from pathlib import Path
#import pandas as pd

# -------- Clases base --------

@dataclass
class Curso:
    codigo: str
    nombre: str
    ciclo: int
    duracion: float  # en horas
    creditos: float
    prerequisitos: List[str]

@dataclass
class Docente:
    codigo: str
    cursos_dictables: Set[str]
    carga: List['Asignacion'] = field(default_factory=list)

    def agregar_asignacion(self, asignacion: 'Asignacion'):
        self.carga.append(asignacion)

    def horas_totales_asignadas(self) -> float:
        return sum(asig.duracion_horas() for asig in self.carga)

@dataclass
class Disponibilidad:
    cod_docente: str
    cod_asignatura: str
    dia: str
    hora_inicio: str
    hora_fin: str
    duracion: float
    ciclo: int

@dataclass
class Seccion:
    cod_asignatura: str
    grupo: int
    matriculados: int
    duracion: float

@dataclass
class Asignacion:
    cod_asignatura: str
    seccion: int
    cod_docente: str
    dia: str
    hora_inicio: str
    hora_fin: str
    ciclo: str

    def duracion_horas(self) -> float:
        h1, m1 = map(int, self.hora_inicio.split(":"))
        h2, m2 = map(int, self.hora_fin.split(":"))
        return (h2 + m2/60) - (h1 + m1/60)
    
    def __repr__(self):
        return f"{self.cod_asignatura}-Ciclo{self.ciclo}-Sec{self.seccion}- Docente {self.cod_docente} - {self.dia}-{self.hora_inicio}-{self.hora_fin}"


# -------- Individuo (horario completo) --------

@dataclass
class Individuo:
    asignaciones: List[Asignacion]

    def __iter__(self):
        return iter(self.asignaciones)

    def get_carga_por_docente(self, cod_docente: str) -> List[Asignacion]:
        return [a for a in self.asignaciones if a.docente.codigo == cod_docente]

# %% [markdown]
# ## 2.1 Carga de informacion a las clases

# %%
def cargar_cursos(df_duracion: pd.DataFrame, df_plan: pd.DataFrame) -> List[Curso]:
    cursos = []
    for _, row in df_duracion.iterrows():
        codigo = row['CodAsignatura']
        nombre = row['NomAsignatura']
    
        duracion = float(row['DuracionHoras'])
        
        creditos = df_plan[df_plan['CodAsignatura'] == codigo]['Créditos'].values
        creditos = float(creditos[0]) if len(creditos) > 0 else 0
        ciclo = df_plan[df_plan['CodAsignatura'] == codigo]['Ciclo'].values

        prereqs = df_plan[df_plan['CodAsignatura'] == codigo]['Cod Pre-Requisito'].dropna().tolist()

        cursos.append(Curso(codigo, nombre, ciclo, duracion, creditos, prereqs))
    return cursos

def cargar_docentes(dict_docente_cursos: dict) -> List[Docente]:
    return [Docente(codigo=cod, cursos_dictables=set(cursos)) for cod, cursos in dict_docente_cursos.items()]

def cargar_disponibilidades(df_disp: pd.DataFrame) -> List[Disponibilidad]:
    disponibilidades = []
    for _, row in df_disp.iterrows():
        disponibilidades.append(
            Disponibilidad(
                cod_docente=row['CodDocente'],
                cod_asignatura=row['CodAsignatura'],
                dia=row['Día'],
                hora_inicio=row['HoraInicio'],
                hora_fin=row['HoraFin'],
                duracion=float(row['DuracionHoras']),
                ciclo=int(row['Ciclo'])
            )
        )
    return disponibilidades

def cargar_secciones(df_docentes_min: pd.DataFrame) -> List[Seccion]:
    secciones = []
    for _, row in df_docentes_min.iterrows():
        for grupo in range(1, int(row['NumGrupos']) + 1):
            secciones.append(
                Seccion(
                    cod_asignatura=row['CodAsignatura'],
                    grupo=grupo,
                    matriculados=int(row['Matriculados']),
                    duracion=float(row['DuracionHoras'])
                )
            )
    return secciones

# %% [markdown]
# # 3. Creación del algoritmo genético

# %% [markdown]
# ## 3.0 Creación de individuo

# %%
import random
from datetime import datetime, timedelta

# Clase para generar individuos
class GeneradorIndividuo:
    def __init__(self, df_docentes_min, dict_docente_cursos, df_plan):
        self.df_docentes_min = df_docentes_min
        self.dict_docente_cursos = dict_docente_cursos
        self.df_plan=df_plan

    def generar_individuo(self):
        individuo = []

        for _, row in self.df_docentes_min.iterrows():
            cod_asig = row["CodAsignatura"]
            num_grupos = int(row["NumGrupos"])
            duracion = float(row["DuracionHoras"])
            ciclo = df_plan[df_plan['CodAsignatura'] == cod_asig]['Ciclo'].values[0]
            
            # Obtener docentes que puedan dictar ese curso
            posibles_docentes = [doc for doc, cursos in self.dict_docente_cursos.items() if cod_asig in cursos]

            for seccion_num in range(1, num_grupos + 1):
                if not posibles_docentes:
                    continue  # No hay docentes para este curso

                docente = random.choice(posibles_docentes)
                dia = random.choice(["LUNES", "MARTES", "MIÉRCOLES", "JUEVES", "VIERNES", "SÁBADO"])

                # Elegir hora random entre 08:00 y (22:00 - duracion)
                hora_min = datetime.strptime("08:00", "%H:%M")
                hora_max = datetime.strptime("22:00", "%H:%M") - timedelta(hours=duracion)

                # Generar lista de posibles horas (de 1 en 1 hora)
                horas_posibles = []
                hora_actual = hora_min
                while hora_actual <= hora_max:
                    horas_posibles.append(hora_actual)
                    hora_actual += timedelta(hours=1)

                hora_inicio = random.choice(horas_posibles)
                hora_fin = hora_inicio + timedelta(hours=duracion)  

                asignacion = Asignacion(
                    cod_asignatura=cod_asig,
                    ciclo=ciclo,
                    seccion=seccion_num,
                    cod_docente=docente,
                    dia=dia,
                    hora_inicio=hora_inicio.strftime("%H:%M"),
                    hora_fin=hora_fin.strftime("%H:%M")
                )

                individuo.append(asignacion)

        return individuo

# %%
generador = GeneradorIndividuo(df_docentes_min, dict_docente_cursos, df_plan)
individuo = generador.generar_individuo()

for a in individuo:
    print(a)
# Out:
# 202W0301-Ciclo3-Sec1- Docente 0A1609 - SÁBADO-17:00-22:00
# 202W0302-Ciclo3-Sec1- Docente 043788 - JUEVES-15:00-20:00
# 202W0303-Ciclo3-Sec1- Docente 0A06292 - MIÉRCOLES-12:00-16:00
# 202W0304-Ciclo3-Sec1- Docente 08490635 - LUNES-17:00-21:00
# 202W0305-Ciclo3-Sec1- Docente 09571E - LUNES-10:00-14:00
# 202W0306-Ciclo3-Sec1- Docente 0A0259 - MARTES-14:00-19:00
# 202W0307-Ciclo3-Sec1- Docente 0A1871 - VIERNES-18:00-22:00
# 202W0401-Ciclo4-Sec1- Docente 095753 - JUEVES-13:00-18:00
# 202W0402-Ciclo4-Sec1- Docente 41388541 - VIERNES-09:00-13:00
# 202W0403-Ciclo4-Sec1- Docente 0A4524 - VIERNES-15:00-19:00
# 202W0404-Ciclo4-Sec1- Docente 0A5230 - JUEVES-12:00-16:00
# 202W0405-Ciclo4-Sec1- Docente 043788 - MARTES-15:00-19:00
# 202W0407-Ciclo4-Sec1- Docente 095699 - MIÉRCOLES-12:00-17:00
# 202W0501-Ciclo5-Sec1- Docente 095729 - LUNES-14:00-18:00
# 202W0502-Ciclo5-Sec1- Docente 10089409 - VIERNES-15:00-19:00
# 202W0503-Ciclo5-Sec1- Docente 01345428 - VIERNES-09:00-13:00
# 202W0504-Ciclo5-Sec1- Docente Z000016 - MIÉRCOLES-15:00-19:00
# 202W0505-Ciclo5-Sec1- Docente Z000017 - MARTES-10:00-15:00
# 202W0506-Ciclo5-Sec1- Docente 72531782 - VIERNES-15:00-19:00
# 202W0507-Ciclo5-Sec1- Docente 0A5230 - LUNES-16:00-21:00
# 202W0601-Ciclo6-Sec1- Docente 0A5291 - MARTES-16:00-20:00
# 202W0602-Ciclo6-Sec1- Docente 0A1876 - MARTES-17:00-22:00
# 202W0603-Ciclo6-Sec1- Docente 0A4525 - VIERNES-10:00-15:00
# 202W0604-Ciclo6-Sec1- Docente 0A1871 - JUEVES-10:00-14:00
# 202W0605-Ciclo6-Sec1- Docente 0A1875 - VIERNES-13:00-18:00
# 202W0606-Ciclo6-Sec1- Docente 0A7565 - VIERNES-10:00-14:00
# 202W0607-Ciclo6-Sec1- Docente 095702 - LUNES-14:00-18:00
# 202W0701-Ciclo7-Sec1- Docente 0A0690 - MIÉRCOLES-10:00-15:00
# 202W0701-Ciclo7-Sec2- Docente 0A0690 - LUNES-16:00-21:00
# 202W0702-Ciclo7-Sec1- Docente 0A9179 - MIÉRCOLES-11:00-16:00
# 202W0702-Ciclo7-Sec2- Docente 0A2067 - SÁBADO-14:00-19:00
# 202W0703-Ciclo7-Sec1- Docente 0A9126 - LUNES-10:00-14:00
# 202W0703-Ciclo7-Sec2- Docente 0A0690 - MARTES-11:00-15:00
# 202W0704-Ciclo7-Sec1- Docente 011797 - MARTES-18:00-22:00
# 202W0705-Ciclo7-Sec1- Docente 0A0307 - JUEVES-16:00-20:00
# 202W0705-Ciclo7-Sec2- Docente 0A0307 - JUEVES-16:00-20:00
# 202W0706-Ciclo7-Sec1- Docente 08232375 - MIÉRCOLES-14:00-18:00
# 202W0706-Ciclo7-Sec2- Docente 08232375 - VIERNES-13:00-17:00
# 202W0707-Ciclo7-Sec1- Docente 0A1981 - JUEVES-11:00-15:00
# 202W0707-Ciclo7-Sec2- Docente 0A1981 - MIÉRCOLES-18:00-22:00
# 202W0801-Ciclo8-Sec1- Docente 44230686 - JUEVES-13:00-17:00
# 202W0802-Ciclo8-Sec1- Docente 0A1236 - MARTES-16:00-20:00
# 202W0803-Ciclo8-Sec1- Docente 0A6225 - JUEVES-16:00-19:00
# 202W0804-Ciclo8-Sec1- Docente 0A9124 - MARTES-13:00-17:00
# 202W0805-Ciclo8-Sec1- Docente 0A5292 - JUEVES-15:00-19:00
# 202W0806-Ciclo8-Sec1- Docente 0A1981 - SÁBADO-08:00-12:00
# 202W0807-Ciclo8-Sec1- Docente 0A1874 - JUEVES-09:00-13:00
# 202W0808-Ciclo8-Sec1- Docente 0A0314 - JUEVES-14:00-18:00
# 202W0901-Ciclo9-Sec1- Docente 0A0182 - LUNES-10:00-13:00
# 202W0901-Ciclo9-Sec2- Docente 0A6226 - JUEVES-16:00-19:00
# 202W0902-Ciclo9-Sec1- Docente 45993187 - VIERNES-09:00-13:00
# 202W0902-Ciclo9-Sec2- Docente 08232375 - MIÉRCOLES-15:00-19:00
# 202W0903-Ciclo9-Sec1- Docente 0A1873 - MARTES-16:00-20:00
# 202W0903-Ciclo9-Sec2- Docente 0A1873 - LUNES-11:00-15:00
# 202W0904-Ciclo9-Sec1- Docente 09620253 - LUNES-12:00-16:00
# 202W0904-Ciclo9-Sec2- Docente 099562 - LUNES-18:00-22:00
# 202W0905-Ciclo9-Sec1- Docente 0A1873 - SÁBADO-13:00-17:00
# 202W0905-Ciclo9-Sec2- Docente 08232375 - JUEVES-11:00-15:00
# 202W0906-Ciclo9-Sec1- Docente 0A4523 - VIERNES-14:00-18:00
# 202W0906-Ciclo9-Sec2- Docente 099589 - MIÉRCOLES-14:00-18:00
# 202W0907-Ciclo9-Sec1- Docente Z000060 - LUNES-18:00-22:00
# 202W0907-Ciclo9-Sec2- Docente Z000060 - MIÉRCOLES-17:00-21:00
# 202W0908-Ciclo9-Sec1- Docente 0A2417 - VIERNES-15:00-19:00
# 202W0908-Ciclo9-Sec2- Docente 0A2417 - SÁBADO-10:00-14:00
# 202W1001-Ciclo10-Sec1- Docente 0A2067 - SÁBADO-09:00-13:00
# 202W1002-Ciclo10-Sec1- Docente 0A2417 - MIÉRCOLES-17:00-20:00
# 202W1003-Ciclo10-Sec1- Docente 0A1876 - MARTES-12:00-18:00
# 202W1004-Ciclo10-Sec1- Docente 0A1874 - MARTES-11:00-16:00
# 202W1005-Ciclo10-Sec1- Docente 0A1874 - LUNES-11:00-15:00
# 202W1006-Ciclo10-Sec1- Docente 0A1877 - LUNES-18:00-22:00
# INE002-Ciclo1-Sec1- Docente 085774 - MARTES-16:00-19:00
# INO101-Ciclo1-Sec1- Docente Z000071 - MARTES-15:00-19:00
# INO102-Ciclo1-Sec1- Docente 42229911 - LUNES-16:00-19:00
# INO103-Ciclo1-Sec1- Docente 41388541 - MIÉRCOLES-10:00-13:00
# INO106-Ciclo1-Sec1- Docente 40667934 - MARTES-12:00-18:00
# INO204-Ciclo2-Sec1- Docente 40764399 - LUNES-08:00-14:00
# INO205-Ciclo2-Sec1- Docente 0A4049 - LUNES-10:00-15:00

# %% [markdown]
# ## 3.1 Calcular Fitness

# %% [markdown]
# ### constrain_cursos_mismo_ciclo_no_solapados

# %%
from collections import defaultdict
from datetime import datetime

# %%
def se_solapan(inicio1, fin1, inicio2, fin2):
    fmt = "%H:%M"
    i1 = datetime.strptime(inicio1, fmt)
    f1 = datetime.strptime(fin1, fmt)
    i2 = datetime.strptime(inicio2, fmt)
    f2 = datetime.strptime(fin2, fmt)
    return max(i1, i2) < min(f1, f2)

# %%
# penalidad por cada curso que genere solape
def constrain_cursos_mismo_ciclo_no_solapados(individuo):

    penalidad = 0
    detalles = []

    # Agrupar asignaciones por ciclo
    asignaciones_por_ciclo = defaultdict(list)
    for asignacion in individuo:
        asignaciones_por_ciclo[asignacion.ciclo].append(asignacion)
    
    for ciclo, asignaciones in asignaciones_por_ciclo.items():
        # Verificar solapes dentro del mismo ciclo
        for i in range(len(asignaciones)):
            for j in range(i + 1, len(asignaciones)):
                a1 = asignaciones[i]
                a2 = asignaciones[j]

                # Si están en el mismo día y se cruzan en horario
                if a1.dia == a2.dia and se_solapan(a1.hora_inicio, a1.hora_fin, a2.hora_inicio, a2.hora_fin):
                    penalidad += 1
                    detalles.append(
                        f"Solapamiento en ciclo {ciclo}: {a1.cod_asignatura}-Sec{a1.seccion} y {a2.cod_asignatura}-Sec{a2.seccion} el {a1.dia} entre {a1.hora_inicio}-{a1.hora_fin} y {a2.hora_inicio}-{a2.hora_fin}"
                    )

    return penalidad, detalles

# %% [markdown]
# ### constrain_cumplir_totalidad_horas

# %%
# penalidades por diferencias entre horas dictadas y horas requeridas
def constrain_cumplir_totalidad_horas(individuo):
    # clave: (cod_asignatura, seccion), valor: suma de horas
    horas_asignadas = defaultdict(float)

    for asignacion in individuo:
        clave = (asignacion.cod_asignatura, asignacion.seccion)
        duracion = asignacion.duracion_horas()
        horas_asignadas[clave] += duracion
        
    penalidad = 0
    detalles = []

    for clave, horas_dictadas in horas_asignadas.items():
        cod_asig, seccion = clave

        fila = df_duracion[df_duracion['CodAsignatura'] == cod_asig]
        if not fila.empty:
            horas_requeridas = float(fila['DuracionHoras'].values[0])
        else:
            # Si no se encuentra el curso en df_duracion, lo penalizamos
            penalidad += 1
            detalles.append(f"{cod_asig} no encontrado en df_duracion")
            continue

        if horas_dictadas != horas_requeridas:
            diferencia = abs(horas_dictadas - horas_requeridas)
            penalidad += diferencia  # penalización proporcional a la diferencia
            detalles.append(f"{cod_asig}-Sec{seccion}: {horas_dictadas}h vs {horas_requeridas}h requeridas")

    return penalidad, detalles

# %% [markdown]
# ### constrain_franjas_validas

# %%
# penalidad por cada curso que este fuera del rango
def constrain_franjas_validas(individuo):
    penalidad = 0
    detalles = []

    hora_minima = 8 * 60     # 08:00 → minutos
    hora_maxima = 22 * 60    # 22:00 → minutos

    for asignacion in individuo:
        # Convertimos hora_inicio y hora_fin a minutos
        h_ini, m_ini = map(int, asignacion.hora_inicio.split(":"))
        h_fin, m_fin = map(int, asignacion.hora_fin.split(":"))
        inicio = h_ini * 60 + m_ini
        fin = h_fin * 60 + m_fin

        # Verificar si está fuera del rango
        if inicio < hora_minima or fin > hora_maxima:
            penalidad += 1
            detalles += f"[{asignacion}] fuera de rango permitido"

    return penalidad, detalles

# %% [markdown]
# ### constrain_docente_max4_cursos

# %%
# 1 punto de penalidad por cada curso de exceso
def constrain_docente_max4_cursos(individuo):
    penalidad = 0
    detalles = []

    # Mapeo: cod_docente → conjunto de cod_asignatura únicos
    cursos_por_docente = defaultdict(set)

    for asignacion in individuo:
        cursos_por_docente[asignacion.cod_docente].add(asignacion.cod_asignatura)

    for cod_docente, cursos in cursos_por_docente.items():
        cantidad_cursos = len(cursos)
        if cantidad_cursos > 4:
            exceso = cantidad_cursos - 4
            penalidad += exceso
            detalles.append(f"Docente {cod_docente} tiene {cantidad_cursos} cursos asignados (máx 4)")

    return penalidad, detalles

# %% [markdown]
# ### constrain_minimo_docentes_por_curso

# %%
# 1 punto de penalidad por cada curso no encontrado y puntos de penalidad 
# adicionales por la diferencia entre aulas reales - aulas requeridas
def constrain_minimo_docentes_por_curso(individuo):
    penalidad = 0
    detalles = []

    # Mapeo: cod_asignatura → conjunto de cod_docente
    docentes_por_curso = defaultdict(set)

    for asignacion in individuo:
        docentes_por_curso[asignacion.cod_asignatura].add(asignacion.cod_docente)

    for cod_asignatura, docentes in docentes_por_curso.items():
        fila = df_docentes_min[df_docentes_min['CodAsignatura'] == cod_asignatura]
        if not fila.empty:
            minimo_requerido = int(fila['NumGrupos'].values[0])
        else:
            # Si no se encuentra el curso en el DataFrame, lo penalizamos
            penalidad += 1
            detalles.append(f"{cod_asignatura} no encontrado en df_docentes_min")
            continue

        cantidad_asignada = len(docentes)
        if cantidad_asignada < minimo_requerido:
            diferencia = minimo_requerido - cantidad_asignada
            penalidad += diferencia
            detalles.append(f"{cod_asignatura} tiene {cantidad_asignada} docentes, requiere mínimo {minimo_requerido}")

    return penalidad, detalles

# %% [markdown]
# ### constrain_ciclos_bajos_horario_preferido

# %%
from datetime import datetime

def constrain_ciclos_bajos_horario_preferido(individuo):
    penalizacion = 0
    detalles_penalizacion = []

    ciclos_bajos = {1, 2, 3, 4, 5}
    hora_almuerzo_inicio = datetime.strptime("13:00", "%H:%M")
    hora_almuerzo_fin = datetime.strptime("14:00", "%H:%M")
    hora_limite = datetime.strptime("18:00", "%H:%M")

    for asignacion in individuo:
        if asignacion.ciclo in ciclos_bajos:
            hora_inicio_dt = datetime.strptime(asignacion.hora_inicio, "%H:%M")

            if hora_almuerzo_inicio <= hora_inicio_dt < hora_almuerzo_fin:
                penalizacion += 1
                detalles_penalizacion.append({
                    "Motivo": "Clase en hora de almuerzo",
                    "CodAsignatura": asignacion.cod_asignatura,
                    "Ciclo": asignacion.ciclo,
                    "HoraInicio": asignacion.hora_inicio,
                    "CodDocente": asignacion.cod_docente,
                    "Día": asignacion.dia
                })

            elif hora_inicio_dt >= hora_limite:
                penalizacion += 1
                detalles_penalizacion.append({
                    "Motivo": "Clase después de las 6pm",
                    "CodAsignatura": asignacion.cod_asignatura,
                    "Ciclo": asignacion.ciclo,
                    "HoraInicio": asignacion.hora_inicio,
                    "CodDocente": asignacion.cod_docente,
                    "Día": asignacion.dia
                })

    return penalizacion, detalles_penalizacion

# %% [markdown]
# ### constrain_preferencias_docente

# %%
def constrain_preferencias_docente(individuo):
    penalizacion = 0
    detalles = []

    # Construimos el diccionario de disponibilidad a partir del DataFrame global
    disponibilidad_dict = {}
    for _, row in df_disp.iterrows():
        cod = row["CodDocente"]
        dia = row["Día"]
        h_ini = row["HoraInicio"]
        h_fin = row["HoraFin"]

        if cod not in disponibilidad_dict:
            disponibilidad_dict[cod] = {}

        if dia not in disponibilidad_dict[cod]:
            disponibilidad_dict[cod][dia] = []

        disponibilidad_dict[cod][dia].append((h_ini, h_fin))

    for asignacion in individuo:
        cod_docente = asignacion.cod_docente
        dia = asignacion.dia
        h_ini = asignacion.hora_inicio
        h_fin = asignacion.hora_fin

        disponible = False
        if cod_docente in disponibilidad_dict and dia in disponibilidad_dict[cod_docente]:
            for rango in disponibilidad_dict[cod_docente][dia]:
                if h_ini >= rango[0] and h_fin <= rango[1]:
                    disponible = True
                    break

        if not disponible:
            penalizacion += 1
            detalles.append(f"{cod_docente} fuera de preferencia en {dia} de {h_ini} a {h_fin}")

    return penalizacion, detalles

# %% [markdown]
# ### constrain_3_franjas_mismo_dia

# %%
from collections import defaultdict

def constrain_3_franjas_mismo_dia(individuo):
    penalizacion = 0
    detalles = []

    # Diccionario: (ciclo, día) → contador de franjas
    franjas_por_dia = defaultdict(int)

    for asignacion in individuo:
        clave = (asignacion.ciclo, asignacion.dia)
        franjas_por_dia[clave] += 1

    for (ciclo, dia), cantidad in franjas_por_dia.items():
        if cantidad > 2:
            exceso = cantidad - 2
            penalizacion += exceso
            detalles.append(f"Ciclo {ciclo} tiene {cantidad} cursos el {dia}")

    return penalizacion, detalles

# %% [markdown]
# ### constrain_espacios_mayores_3h_docente

# %%
from collections import defaultdict
from datetime import datetime

def constrain_espacios_mayores_3h_docente(individuo):
    penalizacion = 0
    detalles = []

    # Diccionario: (docente, día) → lista de horas de clases
    sesiones_por_docente_dia = defaultdict(list)

    for asignacion in individuo:
        hora_inicio = datetime.strptime(asignacion.hora_inicio, "%H:%M")
        hora_fin = datetime.strptime(asignacion.hora_fin, "%H:%M")
        sesiones_por_docente_dia[(asignacion.cod_docente, asignacion.dia)].append((hora_inicio, hora_fin))

    for (docente, dia), sesiones in sesiones_por_docente_dia.items():
        # Ordenar las sesiones por hora de inicio
        sesiones.sort()
        for i in range(len(sesiones) - 1):
            fin_actual = sesiones[i][1]
            inicio_siguiente = sesiones[i + 1][0]
            espacio = (inicio_siguiente - fin_actual).total_seconds() / 3600

            if espacio > 3:
                penalizacion += 1
                detalles.append(f"{docente} tiene espacio de {espacio:.1f}h el {dia}")

    return penalizacion, detalles

# %% [markdown]
# ### constrain_espacios_mayores_3h_ciclo

# %%
from collections import defaultdict
from datetime import datetime

def constrain_espacios_mayores_3h_ciclo(individuo):
    penalizacion = 0
    detalles = []

    # Diccionario: (ciclo, día) → lista de horas de clases
    sesiones_por_ciclo_dia = defaultdict(list)

    for asignacion in individuo:
        hora_inicio = datetime.strptime(asignacion.hora_inicio, "%H:%M")
        hora_fin = datetime.strptime(asignacion.hora_fin, "%H:%M")
        sesiones_por_ciclo_dia[(asignacion.ciclo, asignacion.dia)].append((hora_inicio, hora_fin))

    for (ciclo, dia), sesiones in sesiones_por_ciclo_dia.items():
        sesiones.sort()
        for i in range(len(sesiones) - 1):
            fin_actual = sesiones[i][1]
            inicio_siguiente = sesiones[i + 1][0]
            espacio = (inicio_siguiente - fin_actual).total_seconds() / 3600

            if espacio > 3:
                penalizacion += 1
                detalles.append(f"Ciclo {ciclo} tiene espacio de {espacio:.1f}h el {dia}")

    return penalizacion, detalles

# %% [markdown]
# ### constrain_prereq_vs_otros_ciclos

# %%
from datetime import datetime

# Mapa para ordenar los días de la semana
ORDEN_DIAS = {
    "LUNES": 0, "MARTES": 1, "MIÉRCOLES": 2, "JUEVES": 3,
    "VIERNES": 4, "SÁBADO": 5
}

def constrain_prereq_vs_otros_ciclos(individuo):
    penalizacion = 0
    detalles = []

    # Agrupar asignaciones por curso
    sesiones_por_curso = {}
    
    for asignacion in individuo:
        if asignacion.cod_asignatura not in sesiones_por_curso:
            sesiones_por_curso[asignacion.cod_asignatura] = []
        sesiones_por_curso[asignacion.cod_asignatura].append(asignacion)

    for curso, prereqs in dict_prerrequisitos.items():
        if curso not in sesiones_por_curso:
            continue  # No se programó el curso
        for prereq in prereqs:
            if prereq not in sesiones_por_curso:
                continue  # No se programó el prerrequisito

            # Obtener la sesión más temprana de prereq y la más temprana del curso
            min_inicio_prereq = min(
                (ORDEN_DIAS[a.dia], datetime.strptime(a.hora_inicio, "%H:%M")) 
                for a in sesiones_por_curso[prereq]
            )

            min_inicio_curso = min(
                (ORDEN_DIAS[a.dia], datetime.strptime(a.hora_inicio, "%H:%M")) 
                for a in sesiones_por_curso[curso]
            )

            if min_inicio_prereq > min_inicio_curso:
                penalizacion += 1
                detalles.append(
                    f"Curso {curso} se dicta antes que su prerrequisito {prereq}"
                )

    return penalizacion, detalles

# %% [markdown]
# ### Ejecución del fitness

# %%
def calcular_fitness(individuo):
    penalidad_total = 0
    detalles_penalidades = []
    penalidad_por_constrain = []

    # Cada función evalúa un constraint y devuelve un número (penalidad) y descripción
    for funcion, nombre_constraint, peso in [
        (constrain_cursos_mismo_ciclo_no_solapados, "Cursos del mismo ciclo no deben compartir franja", 6),
        (constrain_cumplir_totalidad_horas, "Cursos deben cumplir totalidad de horas", 6),
        (constrain_franjas_validas, "Cursos deben estar entre 8am-1pm y 2pm-10pm", 6),
        (constrain_docente_max4_cursos, "Docente dicta máximo 4 cursos", 5),
        (constrain_minimo_docentes_por_curso, "Cantidad mínima de docentes por curso", 5),

        #(constrain_docentes_limite_horas, "Docente no pasa su límite de horas lectivas", 5),
        #(constrain_docente_para_todas_secciones, "Asignar docentes a todas las secciones", 5),

        (constrain_ciclos_bajos_horario_preferido, "Cursos 1-5 ciclo preferencia horario", 4),
        (constrain_preferencias_docente, "Preferencias horarias del docente", 3),
        (constrain_3_franjas_mismo_dia, "Evitar 3 franjas distintas mismo día (mismo ciclo)", 3),
        (constrain_espacios_mayores_3h_docente, "Evitar huecos >3h en un mismo día (docente)", 3),
        (constrain_espacios_mayores_3h_ciclo, "Evitar huecos >3h en un mismo día (ciclo)", 3),
        (constrain_prereq_vs_otros_ciclos, "Evitar solapes de no-prereqs entre ciclos cercanos", 2)#,
        #(constrain_dias_lunes_viernes, "Preferencia lunes a viernes", 1),
    ]:
        penalidad, descripcion = funcion(individuo)
        penalidad_ponderada = penalidad * peso
        penalidad_por_constrain.append({"nombre_constraint": nombre_constraint, "penalidad":penalidad_ponderada})
        penalidad_total += penalidad_ponderada
        detalles_penalidades.append((nombre_constraint, penalidad, peso, penalidad_ponderada, descripcion))

    return penalidad_total, detalles_penalidades,penalidad_por_constrain

# %%
penalidad,detalles_penalidad,penalidad_por_constrain = calcular_fitness(individuo)

# %%
test=calcular_fitness(individuo)

# %%
penalidad
# Out:
# 562

# %%
detalles_penalidad
# Out:
# [('Cursos del mismo ciclo no deben compartir franja',
#   32,
#   6,
#   192,
#   ['Solapamiento en ciclo 4: 202W0401-Sec1 y 202W0404-Sec1 el JUEVES entre 13:00-18:00 y 12:00-16:00',
#    'Solapamiento en ciclo 5: 202W0501-Sec1 y 202W0507-Sec1 el LUNES entre 14:00-18:00 y 16:00-21:00',
#    'Solapamiento en ciclo 5: 202W0502-Sec1 y 202W0506-Sec1 el VIERNES entre 15:00-19:00 y 15:00-19:00',
#    'Solapamiento en ciclo 6: 202W0601-Sec1 y 202W0602-Sec1 el MARTES entre 16:00-20:00 y 17:00-22:00',
#    'Solapamiento en ciclo 6: 202W0603-Sec1 y 202W0605-Sec1 el VIERNES entre 10:00-15:00 y 13:00-18:00',
#    'Solapamiento en ciclo 6: 202W0603-Sec1 y 202W0606-Sec1 el VIERNES entre 10:00-15:00 y 10:00-14:00',
#    'Solapamiento en ciclo 6: 202W0605-Sec1 y 202W0606-Sec1 el VIERNES entre 13:00-18:00 y 10:00-14:00',
#    'Solapamiento en ciclo 7: 202W0701-Sec1 y 202W0702-Sec1 el MIÉRCOLES entre 10:00-15:00 y 11:00-16:00',
#    'Solapamiento en ciclo 7: 202W0701-Sec1 y 202W0706-Sec1 el MIÉRCOLES entre 10:00-15:00 y 14:00-18:00',
#    'Solapamiento en ciclo 7: 202W0702-Sec1 y 202W0706-Sec1 el MIÉRCOLES entre 11:00-16:00 y 14:00-18:00',
#    'Solapamiento en ciclo 7: 202W0705-Sec1 y 202W0705-Sec2 el JUEVES entre 16:00-20:00 y 16:00-20:00',
#    'Solapamiento en ciclo 8: 202W0801-Sec1 y 202W0803-Sec1 el JUEVES entre 13:00-17:00 y 16:00-19:00',
#    'Solapamiento en ciclo 8: 202W0801-Sec1 y 202W0805-Sec1 el JUEVES entre 13:00-17:00 y 15:00-19:00',
#    'Solapamiento en ciclo 8: 202W0801-Sec1 y 202W0808-Sec1 el JUEVES entre 13:00-17:00 y 14:00-18:00',
#    'Solapamiento en ciclo 8: 202W0802-Sec1 y 202W0804-Sec1 el MARTES entre 16:00-20:00 y 13:00-17:00',
#    'Solapamiento en ciclo 8: 202W0803-Sec1 y 202W0805-Sec1 el JUEVES entre 16:00-19:00 y 15:00-19:00',
#    'Solapamiento en ciclo 8: 202W0803-Sec1 y 202W0808-Sec1 el JUEVES entre 16:00-19:00 y 14:00-18:00',
#    'Solapamiento en ciclo 8: 202W0805-Sec1 y 202W0808-Sec1 el JUEVES entre 15:00-19:00 y 14:00-18:00',
#    'Solapamiento en ciclo 9: 202W0901-Sec1 y 202W0903-Sec2 el LUNES entre 10:00-13:00 y 11:00-15:00',
#    'Solapamiento en ciclo 9: 202W0901-Sec1 y 202W0904-Sec1 el LUNES entre 10:00-13:00 y 12:00-16:00',
#    'Solapamiento en ciclo 9: 202W0902-Sec2 y 202W0906-Sec2 el MIÉRCOLES entre 15:00-19:00 y 14:00-18:00',
#    'Solapamiento en ciclo 9: 202W0902-Sec2 y 202W0907-Sec2 el MIÉRCOLES entre 15:00-19:00 y 17:00-21:00',
#    'Solapamiento en ciclo 9: 202W0903-Sec2 y 202W0904-Sec1 el LUNES entre 11:00-15:00 y 12:00-16:00',
#    'Solapamiento en ciclo 9: 202W0904-Sec2 y 202W0907-Sec1 el LUNES entre 18:00-22:00 y 18:00-22:00',
#    'Solapamiento en ciclo 9: 202W0905-Sec1 y 202W0908-Sec2 el SÁBADO entre 13:00-17:00 y 10:00-14:00',
#    'Solapamiento en ciclo 9: 202W0906-Sec1 y 202W0908-Sec1 el VIERNES entre 14:00-18:00 y 15:00-19:00',
#    'Solapamiento en ciclo 9: 202W0906-Sec2 y 202W0907-Sec2 el MIÉRCOLES entre 14:00-18:00 y 17:00-21:00',
#    'Solapamiento en ciclo 10: 202W1003-Sec1 y 202W1004-Sec1 el MARTES entre 12:00-18:00 y 11:00-16:00',
#    'Solapamiento en ciclo 1: INE002-Sec1 y INO101-Sec1 el MARTES entre 16:00-19:00 y 15:00-19:00',
#    'Solapamiento en ciclo 1: INE002-Sec1 y INO106-Sec1 el MARTES entre 16:00-19:00 y 12:00-18:00',
#    'Solapamiento en ciclo 1: INO101-Sec1 y INO106-Sec1 el MARTES entre 15:00-19:00 y 12:00-18:00',
#    'Solapamiento en ciclo 2: INO204-Sec1 y INO205-Sec1 el LUNES entre 08:00-14:00 y 10:00-15:00']),
#  ('Cursos deben cumplir totalidad de horas', 0, 6, 0, []),
#  ('Cursos deben estar entre 8am-1pm y 2pm-10pm', 0, 6, 0, []),
#  ('Docente dicta máximo 4 cursos', 0, 5, 0, []),
#  ('Cantidad mínima de docentes por curso',
#   7,
#   5,
#   35,
#   ['202W0701 tiene 1 docentes, requiere mínimo 2',
#    '202W0705 tiene 1 docentes, requiere mínimo 2',
#    '202W0706 tiene 1 docentes, requiere mínimo 2',
#    '202W0707 tiene 1 docentes, requiere mínimo 2',
#    '202W0903 tiene 1 docentes, requiere mínimo 2',
#    '202W0907 tiene 1 docentes, requiere mínimo 2',
#    '202W0908 tiene 1 docentes, requiere mínimo 2']),
#  ('Cursos 1-5 ciclo preferencia horario',
#   2,
#   4,
#   8,
#   [{'Motivo': 'Clase después de las 6pm',
#     'CodAsignatura': '202W0307',
#     'Ciclo': np.int64(3),
#     'HoraInicio': '18:00',
#     'CodDocente': '0A1871',
#     'Día': 'VIERNES'},
#    {'Motivo': 'Clase en hora de almuerzo',
#     'CodAsignatura': '202W0401',
#     'Ciclo': np.int64(4),
#     'HoraInicio': '13:00',
#     'CodDocente': '095753',
#     'Día': 'JUEVES'}]),
#  ('Preferencias horarias del docente',
#   75,
#   3,
#   225,
#   ['0A1609 fuera de preferencia en SÁBADO de 17:00 a 22:00',
#    '043788 fuera de preferencia en JUEVES de 15:00 a 20:00',
#    '0A06292 fuera de preferencia en MIÉRCOLES de 12:00 a 16:00',
#    '08490635 fuera de preferencia en LUNES de 17:00 a 21:00',
#    '09571E fuera de preferencia en LUNES de 10:00 a 14:00',
#    '0A0259 fuera de preferencia en MARTES de 14:00 a 19:00',
#    '0A1871 fuera de preferencia en VIERNES de 18:00 a 22:00',
#    '095753 fuera de preferencia en JUEVES de 13:00 a 18:00',
#    '41388541 fuera de preferencia en VIERNES de 09:00 a 13:00',
#    '0A4524 fuera de preferencia en VIERNES de 15:00 a 19:00',
#    '0A5230 fuera de preferencia en JUEVES de 12:00 a 16:00',
#    '043788 fuera de preferencia en MARTES de 15:00 a 19:00',
#    '095699 fuera de preferencia en MIÉRCOLES de 12:00 a 17:00',
#    '095729 fuera de preferencia en LUNES de 14:00 a 18:00',
#    '10089409 fuera de preferencia en VIERNES de 15:00 a 19:00',
#    '01345428 fuera de preferencia en VIERNES de 09:00 a 13:00',
#    'Z000016 fuera de preferencia en MIÉRCOLES de 15:00 a 19:00',
#    'Z000017 fuera de preferencia en MARTES de 10:00 a 15:00',
#    '72531782 fuera de preferencia en VIERNES de 15:00 a 19:00',
#    '0A5230 fuera de preferencia en LUNES de 16:00 a 21:00',
#    '0A5291 fuera de preferencia en MARTES de 16:00 a 20:00',
#    '0A1876 fuera de preferencia en MARTES de 17:00 a 22:00',
#    '0A4525 fuera de preferencia en VIERNES de 10:00 a 15:00',
#    '0A1871 fuera de preferencia en JUEVES de 10:00 a 14:00',
#    '0A1875 fuera de preferencia en VIERNES de 13:00 a 18:00',
#    '0A7565 fuera de preferencia en VIERNES de 10:00 a 14:00',
#    '095702 fuera de preferencia en LUNES de 14:00 a 18:00',
#    '0A0690 fuera de preferencia en MIÉRCOLES de 10:00 a 15:00',
#    '0A0690 fuera de preferencia en LUNES de 16:00 a 21:00',
#    '0A9179 fuera de preferencia en MIÉRCOLES de 11:00 a 16:00',
#    '0A2067 fuera de preferencia en SÁBADO de 14:00 a 19:00',
#    '0A9126 fuera de preferencia en LUNES de 10:00 a 14:00',
#    '0A0690 fuera de preferencia en MARTES de 11:00 a 15:00',
#    '011797 fuera de preferencia en MARTES de 18:00 a 22:00',
#    '0A0307 fuera de preferencia en JUEVES de 16:00 a 20:00',
#    '0A0307 fuera de preferencia en JUEVES de 16:00 a 20:00',
#    '08232375 fuera de preferencia en MIÉRCOLES de 14:00 a 18:00',
#    '08232375 fuera de preferencia en VIERNES de 13:00 a 17:00',
#    '0A1981 fuera de preferencia en JUEVES de 11:00 a 15:00',
#    '0A1981 fuera de preferencia en MIÉRCOLES de 18:00 a 22:00',
#    '44230686 fuera de preferencia en JUEVES de 13:00 a 17:00',
#    '0A1236 fuera de preferencia en MARTES de 16:00 a 20:00',
#    '0A6225 fuera de preferencia en JUEVES de 16:00 a 19:00',
#    '0A9124 fuera de preferencia en MARTES de 13:00 a 17:00',
#    '0A5292 fuera de preferencia en JUEVES de 15:00 a 19:00',
#    '0A1981 fuera de preferencia en SÁBADO de 08:00 a 12:00',
#    '0A1874 fuera de preferencia en JUEVES de 09:00 a 13:00',
#    '0A0314 fuera de preferencia en JUEVES de 14:00 a 18:00',
#    '0A0182 fuera de preferencia en LUNES de 10:00 a 13:00',
#    '0A6226 fuera de preferencia en JUEVES de 16:00 a 19:00',
#    '45993187 fuera de preferencia en VIERNES de 09:00 a 13:00',
#    '08232375 fuera de preferencia en MIÉRCOLES de 15:00 a 19:00',
#    '0A1873 fuera de preferencia en MARTES de 16:00 a 20:00',
#    '0A1873 fuera de preferencia en LUNES de 11:00 a 15:00',
#    '09620253 fuera de preferencia en LUNES de 12:00 a 16:00',
#    '099562 fuera de preferencia en LUNES de 18:00 a 22:00',
#    '0A1873 fuera de preferencia en SÁBADO de 13:00 a 17:00',
#    '08232375 fuera de preferencia en JUEVES de 11:00 a 15:00',
#    '0A4523 fuera de preferencia en VIERNES de 14:00 a 18:00',
#    '099589 fuera de preferencia en MIÉRCOLES de 14:00 a 18:00',
#    'Z000060 fuera de preferencia en MIÉRCOLES de 17:00 a 21:00',
#    '0A2417 fuera de preferencia en VIERNES de 15:00 a 19:00',
#    '0A2417 fuera de preferencia en SÁBADO de 10:00 a 14:00',
#    '0A2067 fuera de preferencia en SÁBADO de 09:00 a 13:00',
#    '0A2417 fuera de preferencia en MIÉRCOLES de 17:00 a 20:00',
#    '0A1876 fuera de preferencia en MARTES de 12:00 a 18:00',
#    '0A1874 fuera de preferencia en MARTES de 11:00 a 16:00',
#    '0A1874 fuera de preferencia en LUNES de 11:00 a 15:00',
#    '085774 fuera de preferencia en MARTES de 16:00 a 19:00',
#    'Z000071 fuera de preferencia en MARTES de 15:00 a 19:00',
#    '42229911 fuera de preferencia en LUNES de 16:00 a 19:00',
#    '41388541 fuera de preferencia en MIÉRCOLES de 10:00 a 13:00',
#    '40667934 fuera de preferencia en MARTES de 12:00 a 18:00',
#    '40764399 fuera de preferencia en LUNES de 08:00 a 14:00',
#    '0A4049 fuera de preferencia en LUNES de 10:00 a 15:00']),
#  ('Evitar 3 franjas distintas mismo día (mismo ciclo)',
#   14,
#   3,
#   42,
#   ['Ciclo 5 tiene 3 cursos el VIERNES',
#    'Ciclo 6 tiene 3 cursos el VIERNES',
#    'Ciclo 7 tiene 4 cursos el MIÉRCOLES',
#    'Ciclo 7 tiene 3 cursos el JUEVES',
#    'Ciclo 8 tiene 5 cursos el JUEVES',
#    'Ciclo 9 tiene 5 cursos el LUNES',
#    'Ciclo 9 tiene 3 cursos el VIERNES',
#    'Ciclo 9 tiene 3 cursos el MIÉRCOLES',
#    'Ciclo 1 tiene 3 cursos el MARTES']),
#  ('Evitar huecos >3h en un mismo día (docente)', 0, 3, 0, []),
#  ('Evitar huecos >3h en un mismo día (ciclo)', 0, 3, 0, []),
#  ('Evitar solapes de no-prereqs entre ciclos cercanos',
#   30,
#   2,
#   60,
#   ['Curso 202W0401 se dicta antes que su prerrequisito 202W0301',
#    'Curso 202W0402 se dicta antes que su prerrequisito 202W0307',
#    'Curso 202W0405 se dicta antes que su prerrequisito 202W0302',
#    'Curso 202W0501 se dicta antes que su prerrequisito 202W0401',
#    'Curso 202W0501 se dicta antes que su prerrequisito 202W0405',
#    'Curso 202W0504 se dicta antes que su prerrequisito 202W0404',
#    'Curso 202W0505 se dicta antes que su prerrequisito 202W0401',
#    'Curso 202W0601 se dicta antes que su prerrequisito 202W0503',
#    'Curso 202W0604 se dicta antes que su prerrequisito 202W0506',
#    'Curso 202W0604 se dicta antes que su prerrequisito 202W0403',
#    'Curso 202W0607 se dicta antes que su prerrequisito 202W0502',
#    'Curso 202W0701 se dicta antes que su prerrequisito 202W0602',
#    'Curso 202W0701 se dicta antes que su prerrequisito 202W0603',
#    'Curso 202W0701 se dicta antes que su prerrequisito 202W0601',
#    'Curso 202W0703 se dicta antes que su prerrequisito 202W0603',
#    'Curso 202W0703 se dicta antes que su prerrequisito 202W0606',
#    'Curso 202W0704 se dicta antes que su prerrequisito 202W0604',
#    'Curso 202W0705 se dicta antes que su prerrequisito 202W0606',
#    'Curso 202W0706 se dicta antes que su prerrequisito 202W0503',
#    'Curso 202W0706 se dicta antes que su prerrequisito 202W0605',
#    'Curso 202W0802 se dicta antes que su prerrequisito 202W0702',
#    'Curso 202W0804 se dicta antes que su prerrequisito 202W0702',
#    'Curso 202W0901 se dicta antes que su prerrequisito 202W0803',
#    'Curso 202W0902 se dicta antes que su prerrequisito 202W0806',
#    'Curso 202W0903 se dicta antes que su prerrequisito 202W0704',
#    'Curso 202W0904 se dicta antes que su prerrequisito 202W0807',
#    'Curso 202W0906 se dicta antes que su prerrequisito 202W0801',
#    'Curso 202W0907 se dicta antes que su prerrequisito 202W0807',
#    'Curso 202W0907 se dicta antes que su prerrequisito 202W0808',
#    'Curso 202W1005 se dicta antes que su prerrequisito 202W0907'])]

# %%
penalidad_por_constrain
# Out:
# [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#   'penalidad': 192},
#  {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#   'penalidad': 0},
#  {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#   'penalidad': 0},
#  {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#  {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#   'penalidad': 35},
#  {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario', 'penalidad': 8},
#  {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 225},
#  {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#   'penalidad': 42},
#  {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#   'penalidad': 0},
#  {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#   'penalidad': 0},
#  {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#   'penalidad': 60}]

# %% [markdown]
# ## 3.2 Cruce

# %% [markdown]
# ### Cruce

# %%
def cruce_inteligente(poblacion, tamaño_torneo=5, prob_cruce=0.9):
    nueva_poblacion = []

    while len(nueva_poblacion) < len(poblacion):
        # Selección por torneo
        torneo1 = random.sample(poblacion, tamaño_torneo)
        torneo2 = random.sample(poblacion, tamaño_torneo)

        padre1 = min(torneo1, key=lambda ind: calcular_fitness(ind)[0])
        padre2 = min(torneo2, key=lambda ind: calcular_fitness(ind)[0])

        if random.random() < prob_cruce:
            penalidades1 = calcular_fitness(padre1)[2]  # penalidad_por_constrain
            penalidades2 = calcular_fitness(padre2)[2]

            hijo = []
            for i in range(len(padre1)):
                penal1 = penalidades1.get(i, 0)
                penal2 = penalidades2.get(i, 0)

                if penal1 == 0 and penal2 == 0:
                    # Ambos son válidos, elegir aleatorio
                    hijo.append(random.choice([padre1[i], padre2[i]]))
                elif penal1 == 0:
                    hijo.append(padre1[i])
                elif penal2 == 0:
                    hijo.append(padre2[i])
                else:
                    # Ambos están mal, elegir el menos malo
                    hijo.append(padre1[i] if penal1 < penal2 else padre2[i])
            nueva_poblacion.append(hijo)
        else:
            nueva_poblacion.extend([padre1.copy(), padre2.copy()])

    return nueva_poblacion[:len(poblacion)]

# %% [markdown]
# ## 3.3 Mutación

# %% [markdown]
# ### Mutación

# %%
import random
import copy

DIAS_VALIDOS = ['LUNES', 'MARTES', 'MIÉRCOLES', 'JUEVES', 'VIERNES', 'SÁBADO']

def mutar_individuo_por_penalidad(individuo, penalidad, dia=None, penalidad_max=1000):
    """
    Aplica mutación más intensa en individuos con más penalidad.
    Cambia el día de una o más sesiones del individuo.

    Args:
        individuo: lista de sesiones (cada una es un objeto Asignacion)
        penalidad: penalidad del individuo
        dia: día al que se quiere mutar (si None, se elige al azar distinto del actual)
        penalidad_max: penalidad más alta posible (para escalar la probabilidad)

    Return:
        nuevo_individuo: individuo mutado
    """
    nuevo_individuo = [copy.deepcopy(sesion) for sesion in individuo]

    # Escalar la probabilidad: más penalidad → más chance de mutar
    prob_mutacion = min(1.0, penalidad / penalidad_max)  # Normalizar entre 0 y 1

    for sesion in nuevo_individuo:
        if random.random() < prob_mutacion:
            dia_actual = sesion.dia

            if dia:
                nuevo_dia = dia
            else:
                dias_disponibles = [d for d in DIAS_VALIDOS if d != dia_actual]
                nuevo_dia = random.choice(dias_disponibles)

            sesion.dia = nuevo_dia

    return nuevo_individuo

# %% [markdown]
# ## 4.3 Correr algoritmo genetico

# %%
import matplotlib.pyplot as plt

def run_algoritmo_genetico(
    tam_poblacion=30,
    generaciones=100,
    porcentaje_elite=0.1,
    verbose=True
):
    penalidades_totales = []
    historial_penalidad = []

    # 1. Inicialización
    poblacion = [generador.generar_individuo() for _ in range(tam_poblacion)]
    poblacion_fitness = [(ind, *calcular_fitness(ind)) for ind in poblacion]

    for gen in range(generaciones):
        # Ordenar por penalidad (fitness más bajo = mejor)
        poblacion_fitness.sort(key=lambda x: x[2])
        elite_count = int(porcentaje_elite * tam_poblacion)
        elite = [x[0] for x in poblacion_fitness[:elite_count]]

        # Obtener individuos para cruce (solo genotipos)
        poblacion_actual = [x[0] for x in poblacion_fitness]

        # Aplicar cruce por torneo con población completa
        hijos = cruce_por_torneo(poblacion_actual)

        # Aplicar mutación a los hijos
        hijos_mutados = []
        for hijo in hijos:
            penalidad,_,_ = calcular_fitness(hijo)
            hijo_mutado = mutar_individuo_por_penalidad(hijo, penalidad)
            hijos_mutados.append(hijo_mutado)

        # Armar nueva población (elite + hijos mutados)
        nueva_poblacion = elite + hijos_mutados[:tam_poblacion - elite_count]

        # Evaluar nueva población
        poblacion_fitness = [(ind, *calcular_fitness(ind)) for ind in nueva_poblacion]

        # Ordenar por penalidad total (p[1]) y extraer p[2]

        # Mejor individuo de la generación
        mejor_individuo_fitness = min(poblacion_fitness, key=lambda p: p[1])
        mejor_penalidad = mejor_individuo_fitness[1]
        h_pemalidades = mejor_individuo_fitness[3]

        penalidades_totales.append(mejor_penalidad)
        historial_penalidad.append(h_pemalidades)

        if verbose:
            print(f"Generación {gen + 1}: Mejor penalidad = {mejor_penalidad}")

        # Obtener mejor individuo
        mejor_individuo = min(poblacion_fitness, key=lambda x: x[2])

    return mejor_individuo, historial_penalidad, penalidades_totales

# %%
mejor_individuo, historial, mejores_penalidades = run_algoritmo_genetico(
    tam_poblacion=60,
    generaciones=300,
    porcentaje_elite=0.3
)
# Out:
# Generación 1: Mejor penalidad = 494
# Generación 2: Mejor penalidad = 484
# Generación 3: Mejor penalidad = 484
# Generación 4: Mejor penalidad = 473
# Generación 5: Mejor penalidad = 473
# Generación 6: Mejor penalidad = 468
# Generación 7: Mejor penalidad = 468
# Generación 8: Mejor penalidad = 468
# Generación 9: Mejor penalidad = 468
# Generación 10: Mejor penalidad = 456
# Generación 11: Mejor penalidad = 456
# Generación 12: Mejor penalidad = 456
# Generación 13: Mejor penalidad = 439
# Generación 14: Mejor penalidad = 439
# Generación 15: Mejor penalidad = 439
# Generación 16: Mejor penalidad = 439
# Generación 17: Mejor penalidad = 439
# Generación 18: Mejor penalidad = 439
# Generación 19: Mejor penalidad = 439
# Generación 20: Mejor penalidad = 439
# Generación 21: Mejor penalidad = 439
# Generación 22: Mejor penalidad = 439
# Generación 23: Mejor penalidad = 439
# Generación 24: Mejor penalidad = 437
# Generación 25: Mejor penalidad = 437
# Generación 26: Mejor penalidad = 437
# Generación 27: Mejor penalidad = 437
# Generación 28: Mejor penalidad = 437
# Generación 29: Mejor penalidad = 437
# Generación 30: Mejor penalidad = 437
# Generación 31: Mejor penalidad = 437
# Generación 32: Mejor penalidad = 437
# Generación 33: Mejor penalidad = 437
# Generación 34: Mejor penalidad = 437
# Generación 35: Mejor penalidad = 437
# Generación 36: Mejor penalidad = 437
# Generación 37: Mejor penalidad = 437
# Generación 38: Mejor penalidad = 437
# Generación 39: Mejor penalidad = 437
# Generación 40: Mejor penalidad = 437
# Generación 41: Mejor penalidad = 435
# Generación 42: Mejor penalidad = 435
# Generación 43: Mejor penalidad = 435
# Generación 44: Mejor penalidad = 435
# Generación 45: Mejor penalidad = 435
# Generación 46: Mejor penalidad = 435
# Generación 47: Mejor penalidad = 435
# Generación 48: Mejor penalidad = 435
# Generación 49: Mejor penalidad = 435
# Generación 50: Mejor penalidad = 435
# Generación 51: Mejor penalidad = 435
# Generación 52: Mejor penalidad = 435
# Generación 53: Mejor penalidad = 435
# Generación 54: Mejor penalidad = 435
# Generación 55: Mejor penalidad = 435
# Generación 56: Mejor penalidad = 435
# Generación 57: Mejor penalidad = 435
# Generación 58: Mejor penalidad = 435
# Generación 59: Mejor penalidad = 430
# Generación 60: Mejor penalidad = 430
# Generación 61: Mejor penalidad = 430
# Generación 62: Mejor penalidad = 430
# Generación 63: Mejor penalidad = 430
# Generación 64: Mejor penalidad = 430
# Generación 65: Mejor penalidad = 430
# Generación 66: Mejor penalidad = 430
# Generación 67: Mejor penalidad = 430
# Generación 68: Mejor penalidad = 430
# Generación 69: Mejor penalidad = 430
# Generación 70: Mejor penalidad = 430
# Generación 71: Mejor penalidad = 430
# Generación 72: Mejor penalidad = 430
# Generación 73: Mejor penalidad = 430
# Generación 74: Mejor penalidad = 430
# Generación 75: Mejor penalidad = 430
# Generación 76: Mejor penalidad = 430
# Generación 77: Mejor penalidad = 417
# Generación 78: Mejor penalidad = 417
# Generación 79: Mejor penalidad = 417
# Generación 80: Mejor penalidad = 417
# Generación 81: Mejor penalidad = 417
# Generación 82: Mejor penalidad = 417
# Generación 83: Mejor penalidad = 417
# Generación 84: Mejor penalidad = 417
# Generación 85: Mejor penalidad = 417
# Generación 86: Mejor penalidad = 417
# Generación 87: Mejor penalidad = 417
# Generación 88: Mejor penalidad = 417
# Generación 89: Mejor penalidad = 417
# Generación 90: Mejor penalidad = 417
# Generación 91: Mejor penalidad = 417
# Generación 92: Mejor penalidad = 417
# Generación 93: Mejor penalidad = 417
# Generación 94: Mejor penalidad = 417
# Generación 95: Mejor penalidad = 417
# Generación 96: Mejor penalidad = 417
# Generación 97: Mejor penalidad = 417
# Generación 98: Mejor penalidad = 417
# Generación 99: Mejor penalidad = 417
# Generación 100: Mejor penalidad = 417
# Generación 101: Mejor penalidad = 417
# Generación 102: Mejor penalidad = 417
# Generación 103: Mejor penalidad = 417
# Generación 104: Mejor penalidad = 417
# Generación 105: Mejor penalidad = 417
# Generación 106: Mejor penalidad = 417
# Generación 107: Mejor penalidad = 417
# Generación 108: Mejor penalidad = 417
# Generación 109: Mejor penalidad = 417
# Generación 110: Mejor penalidad = 417
# Generación 111: Mejor penalidad = 417
# Generación 112: Mejor penalidad = 417
# Generación 113: Mejor penalidad = 417
# Generación 114: Mejor penalidad = 417
# Generación 115: Mejor penalidad = 417
# Generación 116: Mejor penalidad = 417
# Generación 117: Mejor penalidad = 417
# Generación 118: Mejor penalidad = 417
# Generación 119: Mejor penalidad = 417
# Generación 120: Mejor penalidad = 417
# Generación 121: Mejor penalidad = 417
# Generación 122: Mejor penalidad = 417
# Generación 123: Mejor penalidad = 417
# Generación 124: Mejor penalidad = 417
# Generación 125: Mejor penalidad = 417
# Generación 126: Mejor penalidad = 417
# Generación 127: Mejor penalidad = 417
# Generación 128: Mejor penalidad = 417
# Generación 129: Mejor penalidad = 417
# Generación 130: Mejor penalidad = 417
# Generación 131: Mejor penalidad = 417
# Generación 132: Mejor penalidad = 417
# Generación 133: Mejor penalidad = 417
# Generación 134: Mejor penalidad = 417
# Generación 135: Mejor penalidad = 417
# Generación 136: Mejor penalidad = 417
# Generación 137: Mejor penalidad = 417
# Generación 138: Mejor penalidad = 417
# Generación 139: Mejor penalidad = 417
# Generación 140: Mejor penalidad = 417
# Generación 141: Mejor penalidad = 417
# Generación 142: Mejor penalidad = 417
# Generación 143: Mejor penalidad = 417
# Generación 144: Mejor penalidad = 417
# Generación 145: Mejor penalidad = 417
# Generación 146: Mejor penalidad = 417
# Generación 147: Mejor penalidad = 417
# Generación 148: Mejor penalidad = 417
# Generación 149: Mejor penalidad = 417
# Generación 150: Mejor penalidad = 417
# Generación 151: Mejor penalidad = 417
# Generación 152: Mejor penalidad = 417
# Generación 153: Mejor penalidad = 417
# Generación 154: Mejor penalidad = 417
# Generación 155: Mejor penalidad = 417
# Generación 156: Mejor penalidad = 417
# Generación 157: Mejor penalidad = 417
# Generación 158: Mejor penalidad = 417
# Generación 159: Mejor penalidad = 417
# Generación 160: Mejor penalidad = 417
# Generación 161: Mejor penalidad = 417
# Generación 162: Mejor penalidad = 417
# Generación 163: Mejor penalidad = 417
# Generación 164: Mejor penalidad = 417
# Generación 165: Mejor penalidad = 417
# Generación 166: Mejor penalidad = 417
# Generación 167: Mejor penalidad = 417
# Generación 168: Mejor penalidad = 417
# Generación 169: Mejor penalidad = 417
# Generación 170: Mejor penalidad = 417
# Generación 171: Mejor penalidad = 417
# Generación 172: Mejor penalidad = 417
# Generación 173: Mejor penalidad = 417
# Generación 174: Mejor penalidad = 417
# Generación 175: Mejor penalidad = 417
# Generación 176: Mejor penalidad = 417
# Generación 177: Mejor penalidad = 417
# Generación 178: Mejor penalidad = 417
# Generación 179: Mejor penalidad = 417
# Generación 180: Mejor penalidad = 417
# Generación 181: Mejor penalidad = 417
# Generación 182: Mejor penalidad = 417
# Generación 183: Mejor penalidad = 417
# Generación 184: Mejor penalidad = 417
# Generación 185: Mejor penalidad = 417
# Generación 186: Mejor penalidad = 417
# Generación 187: Mejor penalidad = 417
# Generación 188: Mejor penalidad = 417
# Generación 189: Mejor penalidad = 417
# Generación 190: Mejor penalidad = 417
# Generación 191: Mejor penalidad = 417
# Generación 192: Mejor penalidad = 417
# Generación 193: Mejor penalidad = 417
# Generación 194: Mejor penalidad = 417
# Generación 195: Mejor penalidad = 417
# Generación 196: Mejor penalidad = 417
# Generación 197: Mejor penalidad = 417
# Generación 198: Mejor penalidad = 417
# Generación 199: Mejor penalidad = 417
# Generación 200: Mejor penalidad = 417
# Generación 201: Mejor penalidad = 417
# Generación 202: Mejor penalidad = 417
# Generación 203: Mejor penalidad = 417
# Generación 204: Mejor penalidad = 417
# Generación 205: Mejor penalidad = 417
# Generación 206: Mejor penalidad = 409
# Generación 207: Mejor penalidad = 409
# Generación 208: Mejor penalidad = 409
# Generación 209: Mejor penalidad = 409
# Generación 210: Mejor penalidad = 409
# Generación 211: Mejor penalidad = 409
# Generación 212: Mejor penalidad = 409
# Generación 213: Mejor penalidad = 409
# Generación 214: Mejor penalidad = 409
# Generación 215: Mejor penalidad = 409
# Generación 216: Mejor penalidad = 409
# Generación 217: Mejor penalidad = 409
# Generación 218: Mejor penalidad = 409
# Generación 219: Mejor penalidad = 409
# Generación 220: Mejor penalidad = 409
# Generación 221: Mejor penalidad = 409
# Generación 222: Mejor penalidad = 409
# Generación 223: Mejor penalidad = 393
# Generación 224: Mejor penalidad = 393
# Generación 225: Mejor penalidad = 393
# Generación 226: Mejor penalidad = 393
# Generación 227: Mejor penalidad = 393
# Generación 228: Mejor penalidad = 393
# Generación 229: Mejor penalidad = 393
# Generación 230: Mejor penalidad = 393
# Generación 231: Mejor penalidad = 393
# Generación 232: Mejor penalidad = 393
# Generación 233: Mejor penalidad = 393
# Generación 234: Mejor penalidad = 393
# Generación 235: Mejor penalidad = 393
# Generación 236: Mejor penalidad = 393
# Generación 237: Mejor penalidad = 393
# Generación 238: Mejor penalidad = 393
# Generación 239: Mejor penalidad = 393
# Generación 240: Mejor penalidad = 393
# Generación 241: Mejor penalidad = 393
# Generación 242: Mejor penalidad = 393
# Generación 243: Mejor penalidad = 393
# Generación 244: Mejor penalidad = 393
# Generación 245: Mejor penalidad = 393
# Generación 246: Mejor penalidad = 393
# Generación 247: Mejor penalidad = 393
# Generación 248: Mejor penalidad = 393
# Generación 249: Mejor penalidad = 393
# Generación 250: Mejor penalidad = 393
# Generación 251: Mejor penalidad = 393
# Generación 252: Mejor penalidad = 393
# Generación 253: Mejor penalidad = 393
# Generación 254: Mejor penalidad = 393
# Generación 255: Mejor penalidad = 393
# Generación 256: Mejor penalidad = 393
# Generación 257: Mejor penalidad = 393
# Generación 258: Mejor penalidad = 393
# Generación 259: Mejor penalidad = 393
# Generación 260: Mejor penalidad = 393
# Generación 261: Mejor penalidad = 393
# Generación 262: Mejor penalidad = 393
# Generación 263: Mejor penalidad = 393
# Generación 264: Mejor penalidad = 393
# Generación 265: Mejor penalidad = 393
# Generación 266: Mejor penalidad = 393
# Generación 267: Mejor penalidad = 393
# Generación 268: Mejor penalidad = 393
# Generación 269: Mejor penalidad = 393
# Generación 270: Mejor penalidad = 393
# Generación 271: Mejor penalidad = 393
# Generación 272: Mejor penalidad = 393
# Generación 273: Mejor penalidad = 393
# Generación 274: Mejor penalidad = 393
# Generación 275: Mejor penalidad = 393
# Generación 276: Mejor penalidad = 393
# Generación 277: Mejor penalidad = 393
# Generación 278: Mejor penalidad = 393
# Generación 279: Mejor penalidad = 393
# Generación 280: Mejor penalidad = 393
# Generación 281: Mejor penalidad = 393
# Generación 282: Mejor penalidad = 393
# Generación 283: Mejor penalidad = 393
# Generación 284: Mejor penalidad = 393
# Generación 285: Mejor penalidad = 393
# Generación 286: Mejor penalidad = 393
# Generación 287: Mejor penalidad = 393
# Generación 288: Mejor penalidad = 393
# Generación 289: Mejor penalidad = 393
# Generación 290: Mejor penalidad = 393
# Generación 291: Mejor penalidad = 393
# Generación 292: Mejor penalidad = 393
# Generación 293: Mejor penalidad = 393
# Generación 294: Mejor penalidad = 393
# Generación 295: Mejor penalidad = 393
# Generación 296: Mejor penalidad = 393
# Generación 297: Mejor penalidad = 393
# Generación 298: Mejor penalidad = 393
# Generación 299: Mejor penalidad = 393
# Generación 300: Mejor penalidad = 393

# %%
historial
# Out:
# [[{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 132},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 25},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 12},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 228},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 36},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 58}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 126},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 45},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 216},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 36},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 54}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 126},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 45},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 216},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 36},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 54}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 102},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 35},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 228},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 30},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 70}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 102},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 35},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 228},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 30},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 70}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 114},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 225},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 58}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 114},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 225},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 58}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 114},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 225},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 58}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 114},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 225},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 58}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 108},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 225},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 58}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 108},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 225},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 58}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 108},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 225},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 58}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 84},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 25},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 30},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 70}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 84},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 25},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 30},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 70}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 84},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 25},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 30},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 70}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 84},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 25},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 30},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 70}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 84},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 25},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 30},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 70}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 84},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 25},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 30},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 70}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 84},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 25},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 30},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 70}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 84},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 25},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 30},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 70}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 84},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 25},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 30},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 70}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 84},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 25},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 30},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 70}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 84},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 25},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 30},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 70}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 12},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 231},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 12},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 231},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 12},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 231},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 12},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 231},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 12},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 231},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 12},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 231},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 12},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 231},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 12},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 231},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 12},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 231},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 12},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 231},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 12},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 231},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 12},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 231},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 12},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 231},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 12},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 231},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 12},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 231},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 12},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 231},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 12},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 231},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 78},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 30},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 58}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 78},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 30},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 58}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 78},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 30},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 58}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 78},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 30},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 58}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 78},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 30},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 58}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 78},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 30},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 58}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 78},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 30},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 58}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 78},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 30},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 58}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 78},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 30},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 58}],
# ...
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 48},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 16},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 210},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 48},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 16},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 210},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 48},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 16},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 210},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 48},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 16},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 210},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 48},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 16},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 210},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 48},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 16},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 210},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 48},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 16},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 210},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 48},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 16},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 210},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 48},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 16},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 210},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 48},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 16},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 210},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 48},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 16},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 210},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 48},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 16},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 210},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 48},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 16},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 210},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 48},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 16},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 210},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 48},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 16},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 210},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 48},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 30},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 16},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 210},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}]]

# %%
# Transformar historial a una lista de diccionarios por generación
historial_dicts = [
    {item['nombre_constraint']: item['penalidad'] for item in generacion}
    for generacion in historial
]

# %%
historial_dicts
# Out:
# [{'Cursos del mismo ciclo no deben compartir franja': 132,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 25,
#   'Cursos 1-5 ciclo preferencia horario': 12,
#   'Preferencias horarias del docente': 228,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 36,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 126,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 45,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 36,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 54},
#  {'Cursos del mismo ciclo no deben compartir franja': 126,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 45,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 36,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 54},
#  {'Cursos del mismo ciclo no deben compartir franja': 102,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 35,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 228,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 0,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 70},
#  {'Cursos del mismo ciclo no deben compartir franja': 102,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 35,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 228,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 0,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 70},
#  {'Cursos del mismo ciclo no deben compartir franja': 114,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 114,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 114,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 114,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 108,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 0,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 108,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 0,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 108,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 0,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 84,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 25,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 0,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 70},
#  {'Cursos del mismo ciclo no deben compartir franja': 84,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 25,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 0,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 70},
#  {'Cursos del mismo ciclo no deben compartir franja': 84,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 25,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 0,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 70},
#  {'Cursos del mismo ciclo no deben compartir franja': 84,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 25,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 0,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 70},
#  {'Cursos del mismo ciclo no deben compartir franja': 84,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 25,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 0,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 70},
#  {'Cursos del mismo ciclo no deben compartir franja': 84,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 25,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 0,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 70},
#  {'Cursos del mismo ciclo no deben compartir franja': 84,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 25,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 0,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 70},
#  {'Cursos del mismo ciclo no deben compartir franja': 84,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 25,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 0,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 70},
#  {'Cursos del mismo ciclo no deben compartir franja': 84,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 25,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 0,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 70},
#  {'Cursos del mismo ciclo no deben compartir franja': 84,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 25,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 0,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 70},
#  {'Cursos del mismo ciclo no deben compartir franja': 84,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 25,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 0,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 70},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 12,
#   'Preferencias horarias del docente': 231,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 12,
#   'Preferencias horarias del docente': 231,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 12,
#   'Preferencias horarias del docente': 231,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 12,
#   'Preferencias horarias del docente': 231,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 12,
#   'Preferencias horarias del docente': 231,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 12,
#   'Preferencias horarias del docente': 231,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 12,
#   'Preferencias horarias del docente': 231,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 12,
#   'Preferencias horarias del docente': 231,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 12,
#   'Preferencias horarias del docente': 231,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 12,
#   'Preferencias horarias del docente': 231,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 12,
#   'Preferencias horarias del docente': 231,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 12,
#   'Preferencias horarias del docente': 231,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 12,
#   'Preferencias horarias del docente': 231,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 12,
#   'Preferencias horarias del docente': 231,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 12,
#   'Preferencias horarias del docente': 231,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 12,
#   'Preferencias horarias del docente': 231,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 12,
#   'Preferencias horarias del docente': 231,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 58},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 33,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 56},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 12,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 12,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 12,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 12,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 12,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 12,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 12,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 12,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 12,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 12,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 12,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 12,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 12,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 12,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 12,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 12,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 12,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 52},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 52},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 52},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 52},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 52},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 52},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 52},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 52},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 52},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 225,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 52},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
# ...
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 48,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 30,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 210,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62}]

# %%
mejor_individuo[0]
# Out:
# [202W0301-Ciclo3-Sec1- Docente 0A9179 - LUNES-09:00-14:00,
#  202W0302-Ciclo3-Sec1- Docente 043788 - VIERNES-12:00-17:00,
#  202W0303-Ciclo3-Sec1- Docente 0A7583 - LUNES-15:00-19:00,
#  202W0304-Ciclo3-Sec1- Docente 08490635 - SÁBADO-17:00-21:00,
#  202W0305-Ciclo3-Sec1- Docente 09571E - VIERNES-18:00-22:00,
#  202W0306-Ciclo3-Sec1- Docente 0A0259 - MIÉRCOLES-14:00-19:00,
#  202W0307-Ciclo3-Sec1- Docente 0A1871 - MARTES-13:00-17:00,
#  202W0401-Ciclo4-Sec1- Docente 095753 - SÁBADO-08:00-13:00,
#  202W0402-Ciclo4-Sec1- Docente 41388541 - LUNES-11:00-15:00,
#  202W0403-Ciclo4-Sec1- Docente 0A4524 - MIÉRCOLES-16:00-20:00,
#  202W0404-Ciclo4-Sec1- Docente 0A5230 - SÁBADO-14:00-18:00,
#  202W0405-Ciclo4-Sec1- Docente 043788 - VIERNES-10:00-14:00,
#  202W0407-Ciclo4-Sec1- Docente 095699 - MARTES-12:00-17:00,
#  202W0501-Ciclo5-Sec1- Docente 095729 - MIÉRCOLES-11:00-15:00,
#  202W0502-Ciclo5-Sec1- Docente 10089409 - MIÉRCOLES-14:00-18:00,
#  202W0503-Ciclo5-Sec1- Docente 01345428 - LUNES-18:00-22:00,
#  202W0504-Ciclo5-Sec1- Docente Z000016 - LUNES-12:00-16:00,
#  202W0505-Ciclo5-Sec1- Docente Z000017 - VIERNES-10:00-15:00,
#  202W0506-Ciclo5-Sec1- Docente 0A5140 - MARTES-18:00-22:00,
#  202W0507-Ciclo5-Sec1- Docente 0A1871 - MARTES-09:00-14:00,
#  202W0601-Ciclo6-Sec1- Docente 0A5291 - MARTES-08:00-12:00,
#  202W0602-Ciclo6-Sec1- Docente 0A1876 - MIÉRCOLES-17:00-22:00,
#  202W0603-Ciclo6-Sec1- Docente 0A4525 - JUEVES-09:00-14:00,
#  202W0604-Ciclo6-Sec1- Docente 0A1871 - VIERNES-13:00-17:00,
#  202W0605-Ciclo6-Sec1- Docente 0A1875 - LUNES-17:00-22:00,
#  202W0606-Ciclo6-Sec1- Docente 0A7565 - SÁBADO-11:00-15:00,
#  202W0607-Ciclo6-Sec1- Docente 095702 - MARTES-09:00-13:00,
#  202W0701-Ciclo7-Sec1- Docente 0A0690 - MARTES-08:00-13:00,
#  202W0701-Ciclo7-Sec2- Docente 0A4525 - VIERNES-17:00-22:00,
#  202W0702-Ciclo7-Sec1- Docente 0A2067 - JUEVES-09:00-14:00,
#  202W0702-Ciclo7-Sec2- Docente 0A2067 - LUNES-12:00-17:00,
#  202W0703-Ciclo7-Sec1- Docente 0A9126 - MARTES-13:00-17:00,
#  202W0703-Ciclo7-Sec2- Docente 0A0690 - SÁBADO-11:00-15:00,
#  202W0704-Ciclo7-Sec1- Docente 095753 - VIERNES-12:00-16:00,
#  202W0705-Ciclo7-Sec1- Docente 44230686 - MIÉRCOLES-15:00-19:00,
#  202W0705-Ciclo7-Sec2- Docente 44230686 - SÁBADO-18:00-22:00,
#  202W0706-Ciclo7-Sec1- Docente 091081 - JUEVES-14:00-18:00,
#  202W0706-Ciclo7-Sec2- Docente 091081 - JUEVES-18:00-22:00,
#  202W0707-Ciclo7-Sec1- Docente 0A1981 - MARTES-13:00-17:00,
#  202W0707-Ciclo7-Sec2- Docente 0A1981 - LUNES-18:00-22:00,
#  202W0801-Ciclo8-Sec1- Docente 44230686 - MIÉRCOLES-16:00-20:00,
#  202W0802-Ciclo8-Sec1- Docente 0A1236 - JUEVES-16:00-20:00,
#  202W0803-Ciclo8-Sec1- Docente 011797 - MARTES-12:00-15:00,
#  202W0804-Ciclo8-Sec1- Docente 0A9124 - MIÉRCOLES-17:00-21:00,
#  202W0805-Ciclo8-Sec1- Docente 0A5292 - SÁBADO-14:00-18:00,
#  202W0806-Ciclo8-Sec1- Docente 0A1981 - MIÉRCOLES-11:00-15:00,
#  202W0807-Ciclo8-Sec1- Docente 0A1874 - LUNES-09:00-13:00,
#  202W0808-Ciclo8-Sec1- Docente 0A0314 - VIERNES-15:00-19:00,
#  202W0901-Ciclo9-Sec1- Docente 0A1875 - MIÉRCOLES-17:00-20:00,
#  202W0901-Ciclo9-Sec2- Docente 0A1607 - VIERNES-13:00-16:00,
#  202W0902-Ciclo9-Sec1- Docente 08232375 - LUNES-13:00-17:00,
#  202W0902-Ciclo9-Sec2- Docente 45993187 - SÁBADO-18:00-22:00,
#  202W0903-Ciclo9-Sec1- Docente 0A7565 - JUEVES-13:00-17:00,
#  202W0903-Ciclo9-Sec2- Docente 0A1873 - SÁBADO-09:00-13:00,
#  202W0904-Ciclo9-Sec1- Docente 09620253 - MIÉRCOLES-12:00-16:00,
#  202W0904-Ciclo9-Sec2- Docente 09620253 - MARTES-08:00-12:00,
#  202W0905-Ciclo9-Sec1- Docente 08232375 - MIÉRCOLES-17:00-21:00,
#  202W0905-Ciclo9-Sec2- Docente 0A0690 - LUNES-18:00-22:00,
#  202W0906-Ciclo9-Sec1- Docente 099589 - VIERNES-09:00-13:00,
#  202W0906-Ciclo9-Sec2- Docente 0A4523 - SÁBADO-13:00-17:00,
#  202W0907-Ciclo9-Sec1- Docente 0A9126 - LUNES-13:00-17:00,
#  202W0907-Ciclo9-Sec2- Docente 0A9126 - MARTES-12:00-16:00,
#  202W0908-Ciclo9-Sec1- Docente Z000062 - MARTES-18:00-22:00,
#  202W0908-Ciclo9-Sec2- Docente 0A5292 - SÁBADO-08:00-12:00,
#  202W1001-Ciclo10-Sec1- Docente 0A2067 - MARTES-11:00-15:00,
#  202W1002-Ciclo10-Sec1- Docente 0A2417 - JUEVES-09:00-12:00,
#  202W1003-Ciclo10-Sec1- Docente 0A1876 - SÁBADO-13:00-19:00,
#  202W1004-Ciclo10-Sec1- Docente 46107976 - LUNES-08:00-13:00,
#  202W1005-Ciclo10-Sec1- Docente 0A1874 - SÁBADO-10:00-14:00,
#  202W1006-Ciclo10-Sec1- Docente 0A1877 - VIERNES-18:00-22:00,
#  INE002-Ciclo1-Sec1- Docente 10645375 - LUNES-15:00-18:00,
#  INO101-Ciclo1-Sec1- Docente 42229911 - MIÉRCOLES-16:00-20:00,
#  INO102-Ciclo1-Sec1- Docente 42229911 - MIÉRCOLES-12:00-15:00,
#  INO103-Ciclo1-Sec1- Docente 41388541 - VIERNES-09:00-12:00,
#  INO106-Ciclo1-Sec1- Docente 21571331 - SÁBADO-09:00-15:00,
#  INO204-Ciclo2-Sec1- Docente 40764399 - MARTES-15:00-21:00,
#  INO205-Ciclo2-Sec1- Docente 0A4049 - LUNES-17:00-22:00]

# %%
import matplotlib.pyplot as plt

def graficar_penalidades_por_constraint(historial_penalidad):
    claves = historial_penalidad[0].keys()
    penalidades_por_constraint = {clave: [] for clave in claves}

    for generacion in historial_penalidad:
        for clave in claves:
            penalidades_por_constraint[clave].append(generacion.get(clave, 0))

    plt.figure(figsize=(12, 6))
    for clave, valores in penalidades_por_constraint.items():
        plt.plot(valores, label=clave)

    plt.xlabel("Generación")
    plt.ylabel("Penalidad")
    plt.title("Evolución de penalidades por constraint")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
graficar_penalidades_por_constraint(historial_dicts)

# %% [markdown]
# # 5. Algoritmo Tabu

# %%
from copy import deepcopy
from typing import Tuple
import random

# %%
def hay_solapamiento(a1: Asignacion, a2: Asignacion) -> bool:
    h1_ini = int(a1.hora_inicio.replace(":", ""))
    h1_fin = int(a1.hora_fin.replace(":", ""))
    h2_ini = int(a2.hora_inicio.replace(":", ""))
    h2_fin = int(a2.hora_fin.replace(":", ""))
    return not (h1_fin <= h2_ini or h2_fin <= h1_ini)

def mover_franja_no_solapada(asignacion: Asignacion) -> Tuple[str, str]:
    # Intenta mover 1 hora más tarde o antes dentro del rango válido (8:00-22:00)
    h, m = map(int, asignacion.hora_inicio.split(":"))
    nueva_h = h + 1
    if nueva_h + asignacion.duracion_horas() <= 22:
        nueva_inicio = f"{nueva_h:02d}:{m:02d}"
        nueva_fin = f"{int(nueva_h + asignacion.duracion_horas()):02d}:{m:02d}"
        return nueva_inicio, nueva_fin
    return None

def detectar_cursos_con_pocas_secciones(individuo: Individuo) -> List[str]:
    conteo = {}
    for a in individuo.asignaciones:
        conteo.setdefault(a.cod_asignatura, set()).add(a.seccion)

    cursos_faltantes = []
    for curso, secciones in conteo.items():
        fila = df_docentes_min[df_docentes_min["CodAsignatura"] == curso]
        if not fila.empty:
            min_secciones = int(fila["NumGrupos"].values[0])
            if len(secciones) < min_secciones:
                cursos_faltantes.append(curso)
    return cursos_faltantes

def generar_asignacion_valida(cod_asignatura: str) -> Asignacion:
    # Genera una nueva asignación simple con datos al azar
    seccion = random.randint(1, 5)
    docente = random.choice(df_disp[cod_asignatura])
    dia = random.choice(["LUNES", "MARTES", "MIERCOLES", "JUEVES", "VIERNES"])
    hora_inicio = f"{random.randint(8, 20):02d}:00"
    duracion = df_docentes_min[cod_asignatura]
    hora_fin = f"{int(hora_inicio.split(':')[0]) + duracion:02d}:00"
    ciclo = df_docentes_min[cod_asignatura]
    return Asignacion(cod_asignatura, seccion, docente, dia, hora_inicio, hora_fin, ciclo)

# %%
def generar_vecinos(individuo: Individuo) -> List[Individuo]:
    vecinos = []

    # 1. Resolver solapamientos
    for i, a1 in enumerate(individuo.asignaciones):
        for j, a2 in enumerate(individuo.asignaciones):
            if i >= j:
                continue
            if a1.ciclo == a2.ciclo and a1.dia == a2.dia:
                if hay_solapamiento(a1, a2):
                    nuevo = deepcopy(individuo)
                    nueva_hora = mover_franja_no_solapada(a1)
                    if nueva_hora:
                        nuevo.asignaciones[i].hora_inicio, nuevo.asignaciones[i].hora_fin = nueva_hora
                        vecinos.append(nuevo)

    # 2. Aumentar secciones si faltan (simplificado)
    cursos_con_falta = detectar_cursos_con_pocas_secciones(individuo)
    for cod_asignatura in cursos_con_falta:
        nuevo = deepcopy(individuo)
        nueva_asignacion = generar_asignacion_valida(cod_asignatura)
        if nueva_asignacion:
            nuevo.asignaciones.append(nueva_asignacion)
            vecinos.append(nuevo)

    return vecinos

# %%
def algoritmo_tabu_solapamientos_y_minsecciones(
    individuo_inicial: Individuo,
    calcular_fitness,
    max_iter: int = 100,
    tabu_tam: int = 20
) -> Tuple[Individuo, List[float]]:
    
    actual = deepcopy(individuo_inicial)
    mejor = deepcopy(individuo_inicial)
    tabu_lista = []
    historial_penalidades = []

    mejor_penalidad, _, _ = calcular_fitness(mejor)
    
    for iteracion in range(max_iter):
        vecinos = generar_vecinos(actual)
        vecinos_filtrados = [v for v in vecinos if v not in tabu_lista]
        
        if not vecinos_filtrados:
            break

        penalidades_vecinos = [calcular_fitness(v)[0] for v in vecinos_filtrados]
        mejor_vecino = vecinos_filtrados[penalidades_vecinos.index(min(penalidades_vecinos))]

        actual = mejor_vecino
        tabu_lista.append(actual)
        if len(tabu_lista) > tabu_tam:
            tabu_lista.pop(0)

        penalidad_actual, _, _ = calcular_fitness(actual)
        historial_penalidades.append(penalidad_actual)

        if penalidad_actual < mejor_penalidad:
            mejor = deepcopy(actual)
            mejor_penalidad = penalidad_actual

    return mejor, historial_penalidades

# %%
type(mejor_individuo[0][0])
# Out:
# __main__.Asignacion

# %%
individuo_inicial = Individuo(asignaciones=mejor_individuo[0])

# %%
mejor_individuo, historial_penalidades = algoritmo_tabu_solapamientos_y_minsecciones(
    individuo_inicial=individuo_inicial,
    calcular_fitness=calcular_fitness,
    max_iter=200,
    tabu_tam=60
)

# %%
import matplotlib.pyplot as plt

plt.plot(historial_penalidades)
plt.xlabel("Iteración")
plt.ylabel("Penalidad")
plt.title("Evolución de penalidad - Algoritmo Tabú")
plt.grid(True)
plt.show()

# %%
historial_penalidades
# Out:
# [387,
#  387,
#  387,
#  387,
#  387,
#  381,
#  381,
#  381,
#  381,
#  381,
#  381,
#  383,
#  383,
#  383,
#  383,
#  377,
#  381,
#  377,
#  377,
#  377,
#  377,
#  375,
#  381,
#  381,
#  375,
#  372,
#  378,
#  378,
#  372,
#  372,
#  372,
#  378,
#  378,
#  372]

# %%
type(mejor_individuo)
# Out:
# __main__.Individuo

# %%
penalidad_final,detalles_penalidad_final,penalidad_por_constrain_final = calcular_fitness(mejor_individuo)

# %%
detalles_penalidad_final
# Out:
# [('Cursos del mismo ciclo no deben compartir franja',
#   4,
#   6,
#   24,
#   ['Solapamiento en ciclo 8: 202W0801-Sec1 y 202W0804-Sec1 el MIÉRCOLES entre 18:00-22:00 y 17:00-21:00',
#    'Solapamiento en ciclo 9: 202W0901-Sec1 y 202W0905-Sec1 el MIÉRCOLES entre 19:00-22:00 y 17:00-21:00',
#    'Solapamiento en ciclo 9: 202W0902-Sec1 y 202W0905-Sec2 el LUNES entre 18:00-22:00 y 18:00-22:00',
#    'Solapamiento en ciclo 9: 202W0903-Sec2 y 202W0908-Sec2 el SÁBADO entre 09:00-13:00 y 08:00-12:00']),
#  ('Cursos deben cumplir totalidad de horas', 0, 6, 0, []),
#  ('Cursos deben estar entre 8am-1pm y 2pm-10pm', 0, 6, 0, []),
#  ('Docente dicta máximo 4 cursos', 0, 5, 0, []),
#  ('Cantidad mínima de docentes por curso',
#   6,
#   5,
#   30,
#   ['202W0702 tiene 1 docentes, requiere mínimo 2',
#    '202W0705 tiene 1 docentes, requiere mínimo 2',
#    '202W0706 tiene 1 docentes, requiere mínimo 2',
#    '202W0707 tiene 1 docentes, requiere mínimo 2',
#    '202W0904 tiene 1 docentes, requiere mínimo 2',
#    '202W0907 tiene 1 docentes, requiere mínimo 2']),
#  ('Cursos 1-5 ciclo preferencia horario',
#   5,
#   4,
#   20,
#   [{'Motivo': 'Clase después de las 6pm',
#     'CodAsignatura': '202W0305',
#     'Ciclo': np.int64(3),
#     'HoraInicio': '18:00',
#     'CodDocente': '09571E',
#     'Día': 'VIERNES'},
#    {'Motivo': 'Clase en hora de almuerzo',
#     'CodAsignatura': '202W0307',
#     'Ciclo': np.int64(3),
#     'HoraInicio': '13:00',
#     'CodDocente': '0A1871',
#     'Día': 'MARTES'},
#    {'Motivo': 'Clase después de las 6pm',
#     'CodAsignatura': '202W0501',
#     'Ciclo': np.int64(5),
#     'HoraInicio': '18:00',
#     'CodDocente': '095729',
#     'Día': 'MIÉRCOLES'},
#    {'Motivo': 'Clase después de las 6pm',
#     'CodAsignatura': '202W0503',
#     'Ciclo': np.int64(5),
#     'HoraInicio': '18:00',
#     'CodDocente': '01345428',
#     'Día': 'LUNES'},
#    {'Motivo': 'Clase después de las 6pm',
#     'CodAsignatura': '202W0506',
#     'Ciclo': np.int64(5),
#     'HoraInicio': '18:00',
#     'CodDocente': '0A5140',
#     'Día': 'MARTES'}]),
#  ('Preferencias horarias del docente',
#   69,
#   3,
#   207,
#   ['0A9179 fuera de preferencia en LUNES de 09:00 a 14:00',
#    '043788 fuera de preferencia en VIERNES de 12:00 a 17:00',
#    '0A7583 fuera de preferencia en LUNES de 15:00 a 19:00',
#    '08490635 fuera de preferencia en SÁBADO de 17:00 a 21:00',
#    '0A0259 fuera de preferencia en MIÉRCOLES de 14:00 a 19:00',
#    '0A1871 fuera de preferencia en MARTES de 13:00 a 17:00',
#    '095753 fuera de preferencia en SÁBADO de 08:00 a 13:00',
#    '41388541 fuera de preferencia en LUNES de 11:00 a 15:00',
#    '0A4524 fuera de preferencia en MIÉRCOLES de 16:00 a 20:00',
#    '0A5230 fuera de preferencia en SÁBADO de 14:00 a 18:00',
#    '043788 fuera de preferencia en VIERNES de 10:00 a 14:00',
#    '095699 fuera de preferencia en MARTES de 12:00 a 17:00',
#    '095729 fuera de preferencia en MIÉRCOLES de 18:00 a 22:00',
#    '10089409 fuera de preferencia en MIÉRCOLES de 14:00 a 18:00',
#    'Z000016 fuera de preferencia en LUNES de 12:00 a 16:00',
#    'Z000017 fuera de preferencia en VIERNES de 10:00 a 15:00',
#    '0A5140 fuera de preferencia en MARTES de 18:00 a 22:00',
#    '0A1871 fuera de preferencia en MARTES de 09:00 a 14:00',
#    '0A5291 fuera de preferencia en MARTES de 13:00 a 17:00',
#    '0A1876 fuera de preferencia en MIÉRCOLES de 17:00 a 22:00',
#    '0A4525 fuera de preferencia en JUEVES de 09:00 a 14:00',
#    '0A1871 fuera de preferencia en VIERNES de 13:00 a 17:00',
#    '0A1875 fuera de preferencia en LUNES de 17:00 a 22:00',
#    '0A7565 fuera de preferencia en SÁBADO de 11:00 a 15:00',
#    '095702 fuera de preferencia en MARTES de 09:00 a 13:00',
#    '0A0690 fuera de preferencia en MARTES de 08:00 a 13:00',
#    '0A4525 fuera de preferencia en VIERNES de 17:00 a 22:00',
#    '0A2067 fuera de preferencia en JUEVES de 09:00 a 14:00',
#    '0A2067 fuera de preferencia en LUNES de 12:00 a 17:00',
#    '0A9126 fuera de preferencia en MARTES de 17:00 a 21:00',
#    '0A0690 fuera de preferencia en SÁBADO de 11:00 a 15:00',
#    '095753 fuera de preferencia en VIERNES de 12:00 a 16:00',
#    '44230686 fuera de preferencia en MIÉRCOLES de 15:00 a 19:00',
#    '44230686 fuera de preferencia en SÁBADO de 18:00 a 22:00',
#    '091081 fuera de preferencia en JUEVES de 14:00 a 18:00',
#    '091081 fuera de preferencia en JUEVES de 18:00 a 22:00',
#    '0A1981 fuera de preferencia en MARTES de 13:00 a 17:00',
#    '44230686 fuera de preferencia en MIÉRCOLES de 18:00 a 22:00',
#    '0A1236 fuera de preferencia en JUEVES de 16:00 a 20:00',
#    '011797 fuera de preferencia en MARTES de 12:00 a 15:00',
#    '0A9124 fuera de preferencia en MIÉRCOLES de 17:00 a 21:00',
#    '0A5292 fuera de preferencia en SÁBADO de 14:00 a 18:00',
#    '0A1981 fuera de preferencia en MIÉRCOLES de 11:00 a 15:00',
#    '0A1874 fuera de preferencia en LUNES de 09:00 a 13:00',
#    '0A0314 fuera de preferencia en VIERNES de 15:00 a 19:00',
#    '0A1875 fuera de preferencia en MIÉRCOLES de 19:00 a 22:00',
#    '0A1607 fuera de preferencia en VIERNES de 13:00 a 16:00',
#    '45993187 fuera de preferencia en SÁBADO de 18:00 a 22:00',
#    '0A7565 fuera de preferencia en JUEVES de 13:00 a 17:00',
#    '0A1873 fuera de preferencia en SÁBADO de 09:00 a 13:00',
#    '09620253 fuera de preferencia en MIÉRCOLES de 12:00 a 16:00',
#    '09620253 fuera de preferencia en MARTES de 08:00 a 12:00',
#    '08232375 fuera de preferencia en MIÉRCOLES de 17:00 a 21:00',
#    '099589 fuera de preferencia en VIERNES de 09:00 a 13:00',
#    '0A4523 fuera de preferencia en SÁBADO de 13:00 a 17:00',
#    '0A9126 fuera de preferencia en LUNES de 13:00 a 17:00',
#    '0A9126 fuera de preferencia en MARTES de 12:00 a 16:00',
#    '0A5292 fuera de preferencia en SÁBADO de 08:00 a 12:00',
#    '0A2067 fuera de preferencia en MARTES de 11:00 a 15:00',
#    '0A2417 fuera de preferencia en JUEVES de 09:00 a 12:00',
#    '0A1876 fuera de preferencia en SÁBADO de 14:00 a 20:00',
#    '46107976 fuera de preferencia en LUNES de 08:00 a 13:00',
#    '0A1874 fuera de preferencia en SÁBADO de 10:00 a 14:00',
#    '10645375 fuera de preferencia en LUNES de 15:00 a 18:00',
#    '42229911 fuera de preferencia en MIÉRCOLES de 16:00 a 20:00',
#    '42229911 fuera de preferencia en MIÉRCOLES de 12:00 a 15:00',
#    '21571331 fuera de preferencia en SÁBADO de 09:00 a 15:00',
#    '40764399 fuera de preferencia en MARTES de 15:00 a 21:00',
#    '0A4049 fuera de preferencia en LUNES de 17:00 a 22:00']),
#  ('Evitar 3 franjas distintas mismo día (mismo ciclo)',
#   8,
#   3,
#   24,
#   ['Ciclo 7 tiene 3 cursos el MARTES',
#    'Ciclo 7 tiene 3 cursos el JUEVES',
#    'Ciclo 8 tiene 3 cursos el MIÉRCOLES',
#    'Ciclo 9 tiene 3 cursos el MIÉRCOLES',
#    'Ciclo 9 tiene 3 cursos el LUNES',
#    'Ciclo 9 tiene 4 cursos el SÁBADO',
#    'Ciclo 9 tiene 3 cursos el MARTES']),
#  ('Evitar huecos >3h en un mismo día (docente)', 0, 3, 0, []),
#  ('Evitar huecos >3h en un mismo día (ciclo)',
#   1,
#   3,
#   3,
#   ['Ciclo 5 tiene espacio de 4.0h el MARTES']),
#  ('Evitar solapes de no-prereqs entre ciclos cercanos',
#   32,
#   2,
#   64,
#   ['Curso 202W0402 se dicta antes que su prerrequisito 202W0307',
#    'Curso 202W0403 se dicta antes que su prerrequisito 202W0304',
#    'Curso 202W0405 se dicta antes que su prerrequisito 202W0302',
#    'Curso 202W0501 se dicta antes que su prerrequisito 202W0401',
#    'Curso 202W0501 se dicta antes que su prerrequisito 202W0405',
#    'Curso 202W0504 se dicta antes que su prerrequisito 202W0404',
#    'Curso 202W0505 se dicta antes que su prerrequisito 202W0401',
#    'Curso 202W0602 se dicta antes que su prerrequisito 202W0505',
#    'Curso 202W0603 se dicta antes que su prerrequisito 202W0505',
#    'Curso 202W0607 se dicta antes que su prerrequisito 202W0502',
#    'Curso 202W0701 se dicta antes que su prerrequisito 202W0602',
#    'Curso 202W0701 se dicta antes que su prerrequisito 202W0603',
#    'Curso 202W0701 se dicta antes que su prerrequisito 202W0601',
#    'Curso 202W0702 se dicta antes que su prerrequisito 202W0602',
#    'Curso 202W0703 se dicta antes que su prerrequisito 202W0603',
#    'Curso 202W0703 se dicta antes que su prerrequisito 202W0606',
#    'Curso 202W0704 se dicta antes que su prerrequisito 202W0604',
#    'Curso 202W0705 se dicta antes que su prerrequisito 202W0606',
#    'Curso 202W0707 se dicta antes que su prerrequisito 202W0607',
#    'Curso 202W0803 se dicta antes que su prerrequisito 202W0705',
#    'Curso 202W0807 se dicta antes que su prerrequisito 202W0701',
#    'Curso 202W0807 se dicta antes que su prerrequisito 202W0702',
#    'Curso 202W0807 se dicta antes que su prerrequisito 202W0703',
#    'Curso 202W0807 se dicta antes que su prerrequisito 202W0707',
#    'Curso 202W0902 se dicta antes que su prerrequisito 202W0806',
#    'Curso 202W0903 se dicta antes que su prerrequisito 202W0704',
#    'Curso 202W0905 se dicta antes que su prerrequisito 202W0704',
#    'Curso 202W0907 se dicta antes que su prerrequisito 202W0808',
#    'Curso 202W0908 se dicta antes que su prerrequisito 202W0705',
#    'Curso 202W1001 se dicta antes que su prerrequisito 202W0802',
#    'Curso 202W1001 se dicta antes que su prerrequisito 202W0908',
#    'Curso 202W1004 se dicta antes que su prerrequisito 202W0907'])]
