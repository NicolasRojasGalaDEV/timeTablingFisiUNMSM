# %% [markdown]
# # 1. Extraemos los horarios del Ciclo académico 2025 I - Plan 2018 EAP Ing. Software

# %% [markdown]
# Fuente [Programación de matricula SUM](https://sum.unmsm.edu.pe/alumnoWebSum/v2/matricula/programacion)
# - Este dataset genera:
#     1.  sum_horario_programado2025I.csv

# %%
import pdfplumber
import pandas as pd

# %% [markdown]
# ## Testeamos como se imprimen las páginas

# %%
pdf = pdfplumber.open("..\\Data\\Origen\\Programacion_Asignaturas.pdf")
page = pdf.pages[5]
page.extract_tables()
# Out:
# [[['202W0901 - DESARROLLO DE TESIS\nI',
#    '2.0',
#    '6',
#    '0A6226 - HERRERA QUISPE, JOSÉ\nALFREDO',
#    '22',
#    '15',
#    '108',
#    'MIERCOLES',
#    '15:00 - 16:00'],
#   [None, None, None, None, None, None, '108', 'MIERCOLES', '16:00 - 18:00'],
#   ['202W0901 - DESARROLLO DE TESIS\nI',
#    '2.0',
#    '7',
#    '0A0182 - RUIZ RIVERA, MARIA\nELENA',
#    '15',
#    '3',
#    '--',
#    'MIERCOLES',
#    '19:00 - 20:00'],
#   [None, None, None, None, None, None, '--', 'MIERCOLES', '20:00 - 22:00'],
#   ['202W0902 - GARANTÍA DE\nSOFTWARE',
#    '3.0',
#    '1',
#    '45993187 - LINARES JUAREZ,\nRICARDO JOSE',
#    '47',
#    '37',
#    '109',
#    'SABADO',
#    '14:00 - 16:00'],
#   [None, None, None, None, None, None, '109', 'SABADO', '16:00 - 18:00'],
#   ['202W0902 - GARANTÍA DE\nSOFTWARE',
#    '3.0',
#    '2',
#    '08232375 - DEL MAR ARZOLA,\nJORGE LUIS',
#    '60',
#    '59',
#    '212',
#    'SABADO',
#    '14:00 - 16:00'],
#   [None, None, None, None, None, None, '212', 'SABADO', '16:00 - 18:00'],
#   ['202W0902 - GARANTÍA DE\nSOFTWARE',
#    '3.0',
#    '3',
#    '45993187 - LINARES JUAREZ,\nRICARDO JOSE',
#    '40',
#    '11',
#    '--',
#    'SABADO',
#    '14:00 - 16:00'],
#   [None, None, None, None, None, None, '--', 'SABADO', '16:00 - 18:00'],
#   ['202W0903 - GERENCIA DE\nTECNOLOGÍA DE LA INFORMACIÓN',
#    '3.0',
#    '1',
#    '0A1873 - MACHADO VICENTE, JOEL\nFERNANDO',
#    '45',
#    '20',
#    '102',
#    'JUEVES',
#    '18:00 - 20:00'],
#   [None, None, None, None, None, None, '102', 'JUEVES', '20:00 - 22:00'],
#   ['202W0903 - GERENCIA DE\nTECNOLOGÍA DE LA INFORMACIÓN',
#    '3.0',
#    '2',
#    '0A7565 - PRUDENCIO VIDAL,\nJAVIER ANTONIO',
#    '52',
#    '51',
#    '103',
#    'JUEVES',
#    '18:00 - 20:00'],
#   [None, None, None, None, None, None, '103', 'JUEVES', '20:00 - 22:00'],
#   ['202W0904 - GESTIÓN DE\nMANTENIMIENTO DEL SOFTWARE',
#    '3.0',
#    '1',
#    '099562 - MAC DOWALL REYNOSO,\nERWIN',
#    '40',
#    '12',
#    'NP-\n101',
#    'VIERNES',
#    '18:00 - 20:00'],
#   [None, None, None, None, None, None, 'NP-\n101', 'VIERNES', '20:00 - 22:00'],
#   ['202W0904 - GESTIÓN DE\nMANTENIMIENTO DEL SOFTWARE',
#    '3.0',
#    '2',
#    '09620253 - COLCA GARCIA, HEDDY\nLILIANA',
#    '50',
#    '50',
#    'NP-\n102',
#    'VIERNES',
#    '18:00 - 20:00'],
#   [None, None, None, None, None, None, 'NP-\n102', 'VIERNES', '20:00 - 22:00'],
#   ['202W0905 - GESTIÓN DE RIESGO\nDEL SOFTWARE',
#    '3.0',
#    '1',
#    '0A1873 - MACHADO VICENTE, JOEL\nFERNANDO',
#    '50',
#    '15',
#    'NP-\n103',
#    'LUNES',
#    '18:00 - 20:00'],
#   [None, None, None, None, None, None, 'NP-\n103', 'LUNES', '20:00 - 22:00'],
#   ['202W0905 - GESTIÓN DE RIESGO\nDEL SOFTWARE',
#    '3.0',
#    '2',
#    '0A0690 - LÓPEZ VILLANUEVA,\nPABLO EDWIN',
#    '40',
#    '40',
#    'NP-\n105',
#    'LUNES',
#    '18:00 - 20:00'],
#   [None, None, None, None, None, None, 'NP-\n105', 'LUNES', '20:00 - 22:00'],
#   ['202W0905 - GESTIÓN DE RIESGO\nDEL SOFTWARE',
#    '3.0',
#    '3',
#    '08232375 - DEL MAR ARZOLA,\nJORGE LUIS',
#    '48',
#    '45',
#    '--',
#    'LUNES',
#    '18:00 - 20:00'],
#   [None, None, None, None, None, None, '--', 'LUNES', '20:00 - 22:00'],
#   ['202W0906 - INTERNET DE LAS\nCOSAS',
#    '3.0',
#    '1',
#    '099589 - FERMIN PEREZ, FELIX\nARMANDO',
#    '50',
#    '45',
#    'NP-\n105',
#    'MARTES',
#    '14:00 - 16:00'],
#   [None, None, None, None, None, None, 'NP-\n105', 'MARTES', '16:00 - 18:00'],
#   ['202W0906 - INTERNET DE LAS\nCOSAS',
#    '3.0',
#    '2',
#    '0A4523 - VALCARCEL ASCENCIOS,\nSERGIO PAULO',
#    '45',
#    '28',
#    'NP-\n105',
#    'JUEVES',
#    '14:00 - 16:00'],
#   [None, None, None, None, None, None, 'NP-\n105', 'JUEVES', '20:00 - 22:00'],
#   ['202W0907 - TALLER DE\nCONSTRUCCIÓN DE SOFTWARE\nMÓVIL',
#    '3.0',
#    '1',
#    '0A9126 - PETRLIK AZABACHE, IVAN\nCARLO',
#    '45',
#    '23',
#    'NP-\n105',
#    'SABADO',
#    '08:00 - 10:00'],
#   [None, None, None, None, None, None, 'NP-\n105', 'SABADO', '10:00 - 12:00'],
#   ['202W0907 - TALLER DE\nCONSTRUCCIÓN DE SOFTWARE\nMÓVIL',
#    '3.0',
#    '2',
#    '43813470 - TIZNADO UBILLUS, JOSÉ\nARMANDO',
#    '45',
#    '42',
#    'NP-\n103',
#    'SABADO',
#    '08:00 - 10:00'],
#   [None, None, None, None, None, None, 'NP-\n103', 'SABADO', '10:00 - 12:00'],
#   ['202W0908 - SOFTWARE\nINTELIGENTE',
#    '3.0',
#    '1',
#    '0A2417 - CALDERON VILCA, HUGO\nDAVID',
#    '52',
#    '50',
#    'NP-\n103',
#    'MARTES',
#    '18:00 - 20:00'],
#   [None, None, None, None, None, None, 'NP-\n103', 'MARTES', '20:00 - 22:00'],
#   ['202W0908 - SOFTWARE\nINTELIGENTE',
#    '3.0',
#    '2',
#    '0A5292 - PAUCAR CURASMA ,\nHERMINIO',
#    '46',
#    '42',
#    'NP-\n102',
#    'MARTES',
#    '18:00 - 20:00'],
#   [None, None, None, None, None, None, 'NP-\n102', 'MARTES', '20:00 - 22:00']],
#  [['Asignatura',
#    'Créd.',
#    'Sec.',
#    'Docente',
#    'Tope',
#    'Matri.',
#    'Aula',
#    'Día',
#    'Horas Clase']]]

# %%
pdf_path = "..\\Data\\Origen\\Programacion_Asignaturas.pdf"

# %%
data = []
asignatura = creditos = seccion = docente = tope = matriculados = None

# Encabezado oficial que vamos a insertar
encabezado_oficial = ['Asignatura', 'Créd.', 'Sec.', 'Docente', 'Tope', 'Matri.', 'Aula', 'Día', 'Horas Clase']

with pdfplumber.open(pdf_path) as pdf:
    for page in pdf.pages:
        tables = page.extract_tables()

        for table in tables:
            if not table or len(table) < 2:
                continue

            # Forzar encabezado solo si NO es la página 1
            if page.page_number != 1:
                table.insert(0, encabezado_oficial)

            for row in table[1:]:
                if not any(row):
                    continue
                if row[0] and "asignatura" in row[0].lower():
                    continue

                # Si contiene asignatura, es nueva fila
                if row[0]:
                    asignatura = row[0].replace('\n', ' ').strip()
                    creditos = row[1]
                    seccion = row[2]
                    docente = row[3].replace('\n', ' ').strip() if row[3] else None
                    tope = row[4]
                    matriculados = row[5]

                aula = row[6].replace('\n', ' ') if row[6] else None
                dia = row[7]
                hora = row[8]

                if any([aula, dia, hora]):
                    data.append({
                        "Asignatura": asignatura,
                        "Créditos": creditos,
                        "Sección": seccion,
                        "Docente": docente,
                        "Tope": tope,
                        "Matriculados": matriculados,
                        "Aula": aula,
                        "Día": dia,
                        "Hora": hora
                    })

# %%
# Convertir a DataFrame
df = pd.DataFrame(data)

# Separar hora
df[['HoraInicio', 'HoraFin']] = df['Hora'].str.extract(r'(\d{2}:\d{2})\s*-\s*(\d{2}:\d{2})')
df.drop(columns=['Hora'], inplace=True)

# %%
# Convertir columnas numéricas
for col in ['Créditos', 'Tope', 'Matriculados']:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
# Mostrar algunos registros para validar
pd.set_option('display.max_rows', None)
print(df.head(10).to_string(index=False))
# Out:
#                                               Asignatura  Créditos Sección                                        Docente  Tope  Matriculados    Aula       Día HoraInicio HoraFin
#                      INE002 - PROGRAMACIÓN Y COMPUTACIÓN       2.0       2              0A0182 - RUIZ RIVERA, MARIA ELENA     4             2     211   VIERNES      14:00   15:00
#                      INE002 - PROGRAMACIÓN Y COMPUTACIÓN       2.0       2              0A0182 - RUIZ RIVERA, MARIA ELENA     4             2     211   VIERNES      15:00   17:00
#                      INE002 - PROGRAMACIÓN Y COMPUTACIÓN       2.0       3             07240690 - DAMASO RIOS, MARIA ROSA     4             3     211    MARTES      10:00   11:00
#                      INE002 - PROGRAMACIÓN Y COMPUTACIÓN       2.0       3             07240690 - DAMASO RIOS, MARIA ROSA     4             3     211    MARTES      11:00   13:00
#                      INE002 - PROGRAMACIÓN Y COMPUTACIÓN       2.0       5               085774 - VERA POMALAZA, VIRGINIA     4             1     211 MIERCOLES      10:00   11:00
#                      INE002 - PROGRAMACIÓN Y COMPUTACIÓN       2.0       5               085774 - VERA POMALAZA, VIRGINIA     4             1     211 MIERCOLES      11:00   13:00
#                      INE002 - PROGRAMACIÓN Y COMPUTACIÓN       2.0       6 10645375 - USCUCHAGUA FLORES, GELBER CHRISTIAN     4             3     109 MIERCOLES      10:00   11:00
#                      INE002 - PROGRAMACIÓN Y COMPUTACIÓN       2.0       6 10645375 - USCUCHAGUA FLORES, GELBER CHRISTIAN     4             3     109 MIERCOLES      11:00   13:00
# INO101 - REDACCIÓN Y TÉCNICAS DE COMUNICACIÓN EFECTIVA I       3.0       4      15584946 - DIONICIO MEJÍA, CARMEN VIOLETA     4             2 NP- 108     LUNES      10:00   12:00
# INO101 - REDACCIÓN Y TÉCNICAS DE COMUNICACIÓN EFECTIVA I       3.0       4      15584946 - DIONICIO MEJÍA, CARMEN VIOLETA     4             2 NP- 108     LUNES      12:00   14:00

# %%
df["Asignatura"] = df["Asignatura"].str.strip('"')

# %% [markdown]
# ## Normalizamos Asignaturas

# %%
df[['CodAsignatura', 'NomAsignatura']] = df['Asignatura'].str.split(' - ', n=1, expand=True)
df=df.drop(columns=["Asignatura"])
df.head()
# Out:
#    Créditos Sección                             Docente  Tope  Matriculados  \
# 0       2.0       2   0A0182 - RUIZ RIVERA, MARIA ELENA     4             2
# 1       2.0       2   0A0182 - RUIZ RIVERA, MARIA ELENA     4             2
# 2       2.0       3  07240690 - DAMASO RIOS, MARIA ROSA     4             3
# 3       2.0       3  07240690 - DAMASO RIOS, MARIA ROSA     4             3
# 4       2.0       5    085774 - VERA POMALAZA, VIRGINIA     4             1
#
#   Aula        Día HoraInicio HoraFin CodAsignatura               NomAsignatura
# 0  211    VIERNES      14:00   15:00        INE002  PROGRAMACIÓN Y COMPUTACIÓN
# 1  211    VIERNES      15:00   17:00        INE002  PROGRAMACIÓN Y COMPUTACIÓN
# 2  211     MARTES      10:00   11:00        INE002  PROGRAMACIÓN Y COMPUTACIÓN
# 3  211     MARTES      11:00   13:00        INE002  PROGRAMACIÓN Y COMPUTACIÓN
# 4  211  MIERCOLES      10:00   11:00        INE002  PROGRAMACIÓN Y COMPUTACIÓN

# %% [markdown]
# ## Normalizamos Docente

# %%
df[['CodDocente', 'NomDocente']] = df['Docente'].str.split(' - ', n=1, expand=True)
df=df.drop(columns=["Docente"])
df.head()
# Out:
#    Créditos Sección  Tope  Matriculados Aula        Día HoraInicio HoraFin  \
# 0       2.0       2     4             2  211    VIERNES      14:00   15:00
# 1       2.0       2     4             2  211    VIERNES      15:00   17:00
# 2       2.0       3     4             3  211     MARTES      10:00   11:00
# 3       2.0       3     4             3  211     MARTES      11:00   13:00
# 4       2.0       5     4             1  211  MIERCOLES      10:00   11:00
#
#   CodAsignatura               NomAsignatura CodDocente  \
# 0        INE002  PROGRAMACIÓN Y COMPUTACIÓN     0A0182
# 1        INE002  PROGRAMACIÓN Y COMPUTACIÓN     0A0182
# 2        INE002  PROGRAMACIÓN Y COMPUTACIÓN   07240690
# 3        INE002  PROGRAMACIÓN Y COMPUTACIÓN   07240690
# 4        INE002  PROGRAMACIÓN Y COMPUTACIÓN     085774
#
#                  NomDocente
# 0  RUIZ RIVERA, MARIA ELENA
# 1  RUIZ RIVERA, MARIA ELENA
# 2   DAMASO RIOS, MARIA ROSA
# 3   DAMASO RIOS, MARIA ROSA
# 4   VERA POMALAZA, VIRGINIA

# %% [markdown]
# ## Dataset Final

# %%
df=df[["CodAsignatura","NomAsignatura","Créditos","CodDocente","NomDocente","Sección","Aula","Día","HoraInicio","HoraFin","Tope","Matriculados"]]
df.head()
# Out:
#   CodAsignatura               NomAsignatura  Créditos CodDocente  \
# 0        INE002  PROGRAMACIÓN Y COMPUTACIÓN       2.0     0A0182
# 1        INE002  PROGRAMACIÓN Y COMPUTACIÓN       2.0     0A0182
# 2        INE002  PROGRAMACIÓN Y COMPUTACIÓN       2.0   07240690
# 3        INE002  PROGRAMACIÓN Y COMPUTACIÓN       2.0   07240690
# 4        INE002  PROGRAMACIÓN Y COMPUTACIÓN       2.0     085774
#
#                  NomDocente Sección Aula        Día HoraInicio HoraFin  Tope  \
# 0  RUIZ RIVERA, MARIA ELENA       2  211    VIERNES      14:00   15:00     4
# 1  RUIZ RIVERA, MARIA ELENA       2  211    VIERNES      15:00   17:00     4
# 2   DAMASO RIOS, MARIA ROSA       3  211     MARTES      10:00   11:00     4
# 3   DAMASO RIOS, MARIA ROSA       3  211     MARTES      11:00   13:00     4
# 4   VERA POMALAZA, VIRGINIA       5  211  MIERCOLES      10:00   11:00     4
#
#    Matriculados
# 0             2
# 1             2
# 2             3
# 3             3
# 4             1

# %%
df.to_csv('..\\Data\\Extraidos\\sum_horario_programado2025I.csv', index=False, sep=";",encoding='utf-8-sig')
