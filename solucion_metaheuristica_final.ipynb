# %% [markdown]
# # 1. Fuentes de información

# %% [markdown]
# ## 1.0 Importación de liberías

# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# ## 1.1 Definicion de rutas absolutas

# %%
BASE_DIR = Path().resolve()

# %%
BASE_DIR
# Out:
# WindowsPath('C:/Users/nicol/OneDrive/Documentos/GitHub/timeTablingFisi')

# %%
DATA_DIR = BASE_DIR /"Data"/ "Extraidos"
DURACION_CURSO = DATA_DIR / "duracion_asignatura.csv" 
PLANES_ESTUDIO = DATA_DIR / "plan_estudios.csv"
DOCENTES_MINIMO = DATA_DIR / "docentes_minimos.csv"
DISPONIBILIDAD_DOCENTE = DATA_DIR / "disponibilidad_docentes_simulada.csv"

# %% [markdown]
# ## 1.2 Lectura de datasets

# %%
df_duracion = pd.read_csv(DURACION_CURSO,sep=";",encoding="utf-8-sig")
df_duracion.head()
# Out:
#                             NomAsignatura  DuracionHoras  Ciclo CodAsignatura
# 0                           ALGORÍTMICA I            5.0      3      202W0301
# 1                             ESTADÍSTICA            5.0      3      202W0302
# 2                      FISICA ELÉCTRONICA            4.0      3      202W0303
# 3                    INGENIERÍA ECONÓMICA            4.0      3      202W0304
# 4  INTRODUCCIÓN AL DESARROLLO DE SOFTWARE            4.0      3      202W0305

# %%
df_plan = pd.read_csv(PLANES_ESTUDIO,sep=";",encoding="utf-8-sig")
df_plan.head()
# Out:
#    Ciclo  Créditos CodAsignatura  \
# 0      1       2.0        INE002
# 1      1       2.0        INE013
# 2      1       3.0        INO101
# 3      1       2.0        INO102
# 4      1       2.0        INO103
#
#                                      NomAsignatura Cod Pre-Requisito  \
# 0                       PROGRAMACIÓN Y COMPUTACIÓN               NaN
# 1                      EMPRENDIMIENTO E INNOVACIÓN               NaN
# 2  REDACCIÓN Y TÉCNICAS DE COMUNICACIÓN EFECTIVA I               NaN
# 3                 MÉTODOS DE ESTUDIO UNIVERSITARIO               NaN
# 4                  DESARROLLO PERSONAL Y LIDERAZGO               NaN
#
#   Nom Pre-Requisito
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
df_docentes_min = pd.read_csv(DOCENTES_MINIMO,sep=";",encoding="utf-8-sig")
df_docentes_min.head()
# Out:
#   CodAsignatura                           NomAsignatura  Matriculados  \
# 0      202W0301                           ALGORÍTMICA I            10
# 1      202W0302                             ESTADÍSTICA             5
# 2      202W0303                      FISICA ELÉCTRONICA             6
# 3      202W0304                    INGENIERÍA ECONÓMICA             2
# 4      202W0305  INTRODUCCIÓN AL DESARROLLO DE SOFTWARE             4
#
#    DuracionHoras  NumGrupos  HorasTotales
# 0            5.0          1           5.0
# 1            5.0          1           5.0
# 2            4.0          1           4.0
# 3            4.0          1           4.0
# 4            4.0          1           4.0

# %%
df_disp = pd.read_csv(DISPONIBILIDAD_DOCENTE,sep=",",encoding="utf-8-sig")
df_disp.head()
# Out:
#   CodDocente CodAsignatura     Día HoraInicio HoraFin  DuracionHoras  Ciclo
# 0     085774      202W0301   LUNES      14:00   19:00            5.0      3
# 1     0A1609      202W0301  JUEVES      17:00   22:00            5.0      3
# 2     0A9179      202W0301   LUNES      08:00   13:00            5.0      3
# 3     007056      202W0302  JUEVES      08:00   13:00            5.0      3
# 4     043788      202W0302  JUEVES      08:00   13:00            5.0      3

# %%
df_disp["Día"].unique()
# Out:
# array(['LUNES', 'JUEVES', 'MARTES', 'VIERNES', 'MIERCOLES', 'SABADO'],
#       dtype=object)

# %% [markdown]
# ## 1.3 Generación de datasets restantes

# %%
# Eliminar duplicados para quedarte solo con relaciones únicas docente-curso
df_docente_curso = df_disp[["CodDocente", "CodAsignatura"]].drop_duplicates()

# Agrupar por docente si quieres ver todos los cursos que puede dictar
docentes_con_cursos = df_docente_curso.groupby("CodDocente")["CodAsignatura"].apply(list).reset_index()

# Si quieres usarlo como diccionario:
dict_docente_cursos = df_docente_curso.groupby("CodDocente")["CodAsignatura"].apply(set).to_dict()

# %%
dict_docente_cursos
# Out:
# {'007056': {'202W0302'},
#  '011797': {'202W0704', '202W0803'},
#  '01345428': {'202W0503'},
#  '030228': {'202W0502'},
#  '043788': {'202W0302', '202W0405'},
#  '07240690': {'INE002'},
#  '08232375': {'202W0706', '202W0902', '202W0905'},
#  '08490635': {'202W0304'},
#  '085774': {'202W0301', 'INE002'},
#  '091081': {'202W0706'},
#  '095699': {'202W0407'},
#  '095702': {'202W0607'},
#  '09571E': {'202W0305', '202W0504'},
#  '095729': {'202W0501'},
#  '095753': {'202W0401', '202W0704'},
#  '09620253': {'202W0507', '202W0904'},
#  '099562': {'202W0904'},
#  '099589': {'202W0906'},
#  '0A0182': {'202W0901', 'INE002'},
#  '0A0259': {'202W0306'},
#  '0A0280': {'202W0306'},
#  '0A0307': {'202W0705'},
#  '0A0314': {'202W0305', '202W0808'},
#  '0A06292': {'202W0303'},
#  '0A0690': {'202W0701', '202W0703', '202W0905'},
#  '0A1236': {'202W0802'},
#  '0A1331': {'202W0306'},
#  '0A1607': {'202W0901'},
#  '0A1609': {'202W0301'},
#  '0A1871': {'202W0307', '202W0507', '202W0604'},
#  '0A1873': {'202W0901', '202W0903', '202W0905'},
#  '0A1874': {'202W0807', '202W1004', '202W1005'},
#  '0A1875': {'202W0605', '202W0901'},
#  '0A1876': {'202W0602', '202W1003'},
#  '0A1877': {'202W0503', '202W0706', '202W1006'},
#  '0A1981': {'202W0707', '202W0806'},
#  '0A1982': {'202W0505'},
#  '0A2067': {'202W0702', '202W0705', '202W1001'},
#  '0A2417': {'202W0908', '202W1002'},
#  '0A4049': {'INO205'},
#  '0A4523': {'202W0906'},
#  '0A4524': {'202W0403', '202W0901'},
#  '0A4525': {'202W0603', '202W0701'},
#  '0A5140': {'202W0506'},
#  '0A5230': {'202W0404', '202W0507', '202W1002'},
#  '0A5291': {'202W0601', '202W0704'},
#  '0A5292': {'202W0805', '202W0908'},
#  '0A5306': {'202W0901'},
#  '0A6225': {'202W0803'},
#  '0A6226': {'202W0901', '202W1002'},
#  '0A7565': {'202W0606', '202W0903'},
#  '0A7583': {'202W0303'},
#  '0A7624': {'202W0305'},
#  '0A9124': {'202W0804'},
#  '0A9126': {'202W0703', '202W0907'},
#  '0A9179': {'202W0301', '202W0702'},
#  '10089409': {'202W0502'},
#  '10645375': {'INE002'},
#  '15584946': {'INO101'},
#  '21571331': {'INO106'},
#  '40667934': {'INO106'},
#  '40764399': {'INO204'},
#  '41388541': {'202W0402', 'INO103'},
#  '42229911': {'INO101', 'INO102'},
#  '43813470': {'202W0907'},
#  '44230686': {'202W0705', '202W0801'},
#  '45993187': {'202W0902'},
#  '46107976': {'202W1004'},
#  '72531782': {'202W0506'},
#  'Z000000': {'202W0301'},
#  'Z000001': {'202W0302'},
#  'Z000002': {'202W0303'},
#  'Z000003': {'202W0304'},
#  'Z000004': {'202W0305'},
#  'Z000005': {'202W0306'},
#  'Z000006': {'202W0307'},
#  'Z000007': {'202W0401'},
#  'Z000008': {'202W0402'},
#  'Z000009': {'202W0403'},
#  'Z000010': {'202W0404'},
#  'Z000011': {'202W0405'},
#  'Z000012': {'202W0407'},
#  'Z000013': {'202W0501'},
#  'Z000014': {'202W0502'},
#  'Z000015': {'202W0503'},
#  'Z000016': {'202W0504'},
#  'Z000017': {'202W0505'},
#  'Z000018': {'202W0506'},
#  'Z000019': {'202W0507'},
#  'Z000020': {'202W0601'},
#  'Z000022': {'202W0603'},
#  'Z000023': {'202W0604'},
#  'Z000024': {'202W0605'},
#  'Z000025': {'202W0606'},
#  'Z000026': {'202W0607'},
#  'Z000027': {'202W0701'},
#  'Z000031': {'202W0703'},
#  'Z000032': {'202W0703'},
#  'Z000033': {'202W0704'},
#  'Z000034': {'202W0705'},
#  'Z000035': {'202W0705'},
#  'Z000036': {'202W0706'},
#  'Z000037': {'202W0706'},
#  'Z000038': {'202W0707'},
#  'Z000039': {'202W0707'},
#  'Z000040': {'202W0801'},
#  'Z000041': {'202W0802'},
#  'Z000042': {'202W0803'},
#  'Z000043': {'202W0804'},
#  'Z000044': {'202W0805'},
#  'Z000045': {'202W0806'},
#  'Z000046': {'202W0807'},
#  'Z000047': {'202W0808'},
#  'Z000048': {'202W0901'},
#  'Z000049': {'202W0901'},
#  'Z000050': {'202W0902'},
#  'Z000051': {'202W0902'},
#  'Z000052': {'202W0903'},
#  'Z000053': {'202W0903'},
#  'Z000054': {'202W0904'},
#  'Z000055': {'202W0904'},
#  'Z000056': {'202W0905'},
#  'Z000057': {'202W0905'},
#  'Z000058': {'202W0906'},
#  'Z000059': {'202W0906'},
#  'Z000060': {'202W0907'},
#  'Z000061': {'202W0907'},
#  'Z000062': {'202W0908'},
#  'Z000063': {'202W0908'},
#  'Z000064': {'202W1001'},
#  'Z000065': {'202W1002'},
#  'Z000068': {'202W1005'},
#  'Z000069': {'202W1006'},
#  'Z000070': {'INE002'},
#  'Z000071': {'INO101'},
#  'Z000072': {'INO102'},
#  'Z000073': {'INO103'},
#  'Z000074': {'INO106'},
#  'Z000075': {'INO204'},
#  'Z000076': {'INO205'}}

# %%
dict_prerrequisitos = {}

for _, fila in df_plan.iterrows():
    curso = fila["CodAsignatura"]
    prereq = fila["Cod Pre-Requisito"]

    if pd.notna(prereq):
        if curso not in dict_prerrequisitos:
            dict_prerrequisitos[curso] = []
        dict_prerrequisitos[curso].append(prereq)

# %%
dict_prerrequisitos
# Out:
# {'INO201': ['INO101'],
#  'INO204': ['INO104'],
#  '202W0401': ['202W0301'],
#  '202W0402': ['202W0307'],
#  '202W0403': ['202W0304'],
#  '202W0404': ['202W0306'],
#  '202W0405': ['202W0302'],
#  '202W0406': ['202W0305', '202W0304'],
#  '202W0407': ['202W0303'],
#  '202W0501': ['202W0401', '202W0405'],
#  '202W0502': ['202W0407'],
#  '202W0503': ['202W0406'],
#  '202W0504': ['202W0404'],
#  '202W0505': ['202W0401'],
#  '202W0506': ['202W0402'],
#  '202W0507': ['202W0406'],
#  '202W0601': ['202W0503'],
#  '202W0602': ['202W0505'],
#  '202W0603': ['202W0507', '202W0505'],
#  '202W0604': ['202W0506', '202W0403'],
#  '202W0605': ['202W0406'],
#  '202W0606': ['202W0504'],
#  '202W0607': ['202W0502'],
#  '202W0701': ['202W0602', '202W0603', '202W0601'],
#  '202W0702': ['202W0602'],
#  '202W0703': ['202W0603', '202W0606'],
#  '202W0704': ['202W0604'],
#  '202W0705': ['202W0606'],
#  '202W0706': ['202W0503', '202W0605'],
#  '202W0707': ['202W0607'],
#  '202W0801': ['202W0707'],
#  '202W0802': ['202W0501', '202W0702'],
#  '202W0803': ['202W0701', '202W0705'],
#  '202W0804': ['202W0702'],
#  '202W0805': ['202W0607'],
#  '202W0806': ['202W0601', '202W0707'],
#  '202W0807': ['202W0701', '202W0702', '202W0703', '202W0707'],
#  '202W0808': ['202W0706'],
#  '202W0901': ['202W0803'],
#  '202W0902': ['202W0806'],
#  '202W0903': ['202W0704'],
#  '202W0904': ['202W0807'],
#  '202W0905': ['202W0704'],
#  '202W0906': ['202W0801'],
#  '202W0907': ['202W0807', '202W0808'],
#  '202W0908': ['202W0705'],
#  '202W1001': ['202W0802', '202W0908'],
#  '202W1002': ['202W0901'],
#  '202W1003': ['202W0907'],
#  '202W1004': ['202W0907'],
#  '202W1005': ['202W0907'],
#  '202W1006': ['202W0903']}

# %% [markdown]
# # 2. Definicion de clases

# %% [markdown]
# ## 2.0 Constructores de clase

# %%
from dataclasses import dataclass, field
from typing import List, Set, Optional
#from pathlib import Path
#import pandas as pd

# -------- Clases base --------

@dataclass
class Curso:
    codigo: str
    nombre: str
    ciclo: int
    duracion: float  # en horas
    creditos: float
    prerequisitos: List[str]

@dataclass
class Docente:
    codigo: str
    cursos_dictables: Set[str]
    carga: List['Asignacion'] = field(default_factory=list)

    def agregar_asignacion(self, asignacion: 'Asignacion'):
        self.carga.append(asignacion)

    def horas_totales_asignadas(self) -> float:
        return sum(asig.duracion_horas() for asig in self.carga)

@dataclass
class Disponibilidad:
    cod_docente: str
    cod_asignatura: str
    dia: str
    hora_inicio: str
    hora_fin: str
    duracion: float
    ciclo: int

@dataclass
class Seccion:
    cod_asignatura: str
    grupo: int
    matriculados: int
    duracion: float

@dataclass
class Asignacion:
    cod_asignatura: str
    seccion: int
    cod_docente: str
    dia: str
    hora_inicio: str
    hora_fin: str
    ciclo: str

    def duracion_horas(self) -> float:
        h1, m1 = map(int, self.hora_inicio.split(":"))
        h2, m2 = map(int, self.hora_fin.split(":"))
        return (h2 + m2/60) - (h1 + m1/60)
    
    def __repr__(self):
        return f"{self.cod_asignatura}-Ciclo{self.ciclo}-Sec{self.seccion}- Docente {self.cod_docente} - {self.dia}-{self.hora_inicio}-{self.hora_fin}"


# -------- Individuo (horario completo) --------

@dataclass
class Individuo:
    asignaciones: List[Asignacion]

    def __iter__(self):
        return iter(self.asignaciones)

    def get_carga_por_docente(self, cod_docente: str) -> List[Asignacion]:
        return [a for a in self.asignaciones if a.docente.codigo == cod_docente]

# %% [markdown]
# ## 2.1 Carga de informacion a las clases

# %%
def cargar_cursos(df_duracion: pd.DataFrame, df_plan: pd.DataFrame) -> List[Curso]:
    cursos = []
    for _, row in df_duracion.iterrows():
        codigo = row['CodAsignatura']
        nombre = row['NomAsignatura']
    
        duracion = float(row['DuracionHoras'])
        
        creditos = df_plan[df_plan['CodAsignatura'] == codigo]['Créditos'].values
        creditos = float(creditos[0]) if len(creditos) > 0 else 0
        ciclo = df_plan[df_plan['CodAsignatura'] == codigo]['Ciclo'].values

        prereqs = df_plan[df_plan['CodAsignatura'] == codigo]['Cod Pre-Requisito'].dropna().tolist()

        cursos.append(Curso(codigo, nombre, ciclo, duracion, creditos, prereqs))
    return cursos

def cargar_docentes(dict_docente_cursos: dict) -> List[Docente]:
    return [Docente(codigo=cod, cursos_dictables=set(cursos)) for cod, cursos in dict_docente_cursos.items()]

def cargar_disponibilidades(df_disp: pd.DataFrame) -> List[Disponibilidad]:
    disponibilidades = []
    for _, row in df_disp.iterrows():
        disponibilidades.append(
            Disponibilidad(
                cod_docente=row['CodDocente'],
                cod_asignatura=row['CodAsignatura'],
                dia=row['Día'],
                hora_inicio=row['HoraInicio'],
                hora_fin=row['HoraFin'],
                duracion=float(row['DuracionHoras']),
                ciclo=int(row['Ciclo'])
            )
        )
    return disponibilidades

def cargar_secciones(df_docentes_min: pd.DataFrame) -> List[Seccion]:
    secciones = []
    for _, row in df_docentes_min.iterrows():
        for grupo in range(1, int(row['NumGrupos']) + 1):
            secciones.append(
                Seccion(
                    cod_asignatura=row['CodAsignatura'],
                    grupo=grupo,
                    matriculados=int(row['Matriculados']),
                    duracion=float(row['DuracionHoras'])
                )
            )
    return secciones

# %% [markdown]
# # 3. Creación del algoritmo genético

# %% [markdown]
# ## 3.0 Creación de individuo

# %%
import random
from datetime import datetime, timedelta

# Clase para generar individuos
class GeneradorIndividuo:
    def __init__(self, df_docentes_min, dict_docente_cursos, df_plan):
        self.df_docentes_min = df_docentes_min
        self.dict_docente_cursos = dict_docente_cursos
        self.df_plan=df_plan

    def generar_individuo(self):
        individuo = []

        for _, row in self.df_docentes_min.iterrows():  
            cod_asig = row["CodAsignatura"]
            num_grupos = int(row["NumGrupos"])
            duracion = float(row["DuracionHoras"])
            ciclo = df_plan[df_plan['CodAsignatura'] == cod_asig]['Ciclo'].values[0]
            
            # Obtener docentes que puedan dictar ese curso
            posibles_docentes = [doc for doc, cursos in self.dict_docente_cursos.items() if cod_asig in cursos]

            for seccion_num in range(1, num_grupos + 1):
                if not posibles_docentes:
                    continue  # No hay docentes para este curso

                docente = random.choice(posibles_docentes)
                dia = random.choice(["LUNES", "MARTES", "MIERCOLES", "JUEVES", "VIERNES", "SABADO"])

                # Elegir hora random entre 08:00 y (22:00 - duracion)
                hora_min = datetime.strptime("08:00", "%H:%M")
                hora_max = datetime.strptime("22:00", "%H:%M") - timedelta(hours=duracion)

                # Generar lista de posibles horas (de 1 en 1 hora)
                horas_posibles = []
                hora_actual = hora_min
                while hora_actual <= hora_max:
                    horas_posibles.append(hora_actual)
                    hora_actual += timedelta(hours=1)

                hora_inicio = random.choice(horas_posibles)
                hora_fin = hora_inicio + timedelta(hours=duracion)  

                asignacion = Asignacion(
                    cod_asignatura=cod_asig,
                    ciclo=ciclo,
                    seccion=seccion_num,
                    cod_docente=docente,
                    dia=dia,
                    hora_inicio=hora_inicio.strftime("%H:%M"),
                    hora_fin=hora_fin.strftime("%H:%M")
                )

                individuo.append(asignacion)

        return individuo

# %%
generador = GeneradorIndividuo(df_docentes_min, dict_docente_cursos, df_plan)
individuo = generador.generar_individuo()

for a in individuo:
    print(a)
# Out:
# 202W0301-Ciclo3-Sec1- Docente 0A9179 - LUNES-11:00-16:00
# 202W0302-Ciclo3-Sec1- Docente 043788 - MIERCOLES-10:00-15:00
# 202W0303-Ciclo3-Sec1- Docente Z000002 - MARTES-18:00-22:00
# 202W0304-Ciclo3-Sec1- Docente 08490635 - SABADO-15:00-19:00
# 202W0305-Ciclo3-Sec1- Docente 0A0314 - LUNES-09:00-13:00
# 202W0306-Ciclo3-Sec1- Docente 0A0259 - LUNES-09:00-14:00
# 202W0307-Ciclo3-Sec1- Docente 0A1871 - VIERNES-16:00-20:00
# 202W0401-Ciclo4-Sec1- Docente Z000007 - MIERCOLES-15:00-20:00
# 202W0402-Ciclo4-Sec1- Docente 41388541 - SABADO-14:00-18:00
# 202W0403-Ciclo4-Sec1- Docente Z000009 - MARTES-09:00-13:00
# 202W0404-Ciclo4-Sec1- Docente 0A5230 - MARTES-12:00-16:00
# 202W0405-Ciclo4-Sec1- Docente Z000011 - SABADO-16:00-20:00
# 202W0407-Ciclo4-Sec1- Docente 095699 - SABADO-17:00-22:00
# 202W0501-Ciclo5-Sec1- Docente 095729 - SABADO-09:00-13:00
# 202W0502-Ciclo5-Sec1- Docente 10089409 - LUNES-14:00-18:00
# 202W0503-Ciclo5-Sec1- Docente 01345428 - JUEVES-09:00-13:00
# 202W0504-Ciclo5-Sec1- Docente 09571E - VIERNES-14:00-18:00
# 202W0505-Ciclo5-Sec1- Docente Z000017 - VIERNES-16:00-21:00
# 202W0506-Ciclo5-Sec1- Docente Z000018 - JUEVES-11:00-15:00
# 202W0507-Ciclo5-Sec1- Docente 09620253 - MARTES-16:00-21:00
# 202W0601-Ciclo6-Sec1- Docente 0A5291 - MIERCOLES-17:00-21:00
# 202W0602-Ciclo6-Sec1- Docente 0A1876 - VIERNES-11:00-16:00
# 202W0603-Ciclo6-Sec1- Docente Z000022 - MIERCOLES-09:00-14:00
# 202W0604-Ciclo6-Sec1- Docente 0A1871 - VIERNES-13:00-17:00
# 202W0605-Ciclo6-Sec1- Docente 0A1875 - MARTES-12:00-17:00
# 202W0606-Ciclo6-Sec1- Docente Z000025 - SABADO-15:00-19:00
# 202W0607-Ciclo6-Sec1- Docente Z000026 - LUNES-18:00-22:00
# 202W0701-Ciclo7-Sec1- Docente 0A0690 - MIERCOLES-08:00-13:00
# 202W0701-Ciclo7-Sec2- Docente 0A4525 - JUEVES-17:00-22:00
# 202W0702-Ciclo7-Sec1- Docente 0A2067 - MARTES-14:00-19:00
# 202W0702-Ciclo7-Sec2- Docente 0A2067 - JUEVES-12:00-17:00
# 202W0703-Ciclo7-Sec1- Docente 0A0690 - MARTES-17:00-21:00
# 202W0703-Ciclo7-Sec2- Docente Z000031 - LUNES-14:00-18:00
# 202W0704-Ciclo7-Sec1- Docente 0A5291 - LUNES-11:00-15:00
# 202W0705-Ciclo7-Sec1- Docente 44230686 - MARTES-08:00-12:00
# 202W0705-Ciclo7-Sec2- Docente 44230686 - LUNES-15:00-19:00
# 202W0706-Ciclo7-Sec1- Docente 08232375 - MARTES-08:00-12:00
# 202W0706-Ciclo7-Sec2- Docente 091081 - VIERNES-08:00-12:00
# 202W0707-Ciclo7-Sec1- Docente Z000039 - MARTES-12:00-16:00
# 202W0707-Ciclo7-Sec2- Docente Z000038 - MIERCOLES-16:00-20:00
# 202W0801-Ciclo8-Sec1- Docente 44230686 - JUEVES-16:00-20:00
# 202W0802-Ciclo8-Sec1- Docente 0A1236 - SABADO-12:00-16:00
# 202W0803-Ciclo8-Sec1- Docente 0A6225 - SABADO-19:00-22:00
# 202W0804-Ciclo8-Sec1- Docente Z000043 - MIERCOLES-09:00-13:00
# 202W0805-Ciclo8-Sec1- Docente Z000044 - MIERCOLES-09:00-13:00
# 202W0806-Ciclo8-Sec1- Docente 0A1981 - VIERNES-12:00-16:00
# 202W0807-Ciclo8-Sec1- Docente Z000046 - MARTES-11:00-15:00
# 202W0808-Ciclo8-Sec1- Docente 0A0314 - LUNES-17:00-21:00
# 202W0901-Ciclo9-Sec1- Docente 0A6226 - JUEVES-18:00-21:00
# 202W0901-Ciclo9-Sec2- Docente 0A5306 - LUNES-19:00-22:00
# 202W0902-Ciclo9-Sec1- Docente Z000051 - LUNES-12:00-16:00
# 202W0902-Ciclo9-Sec2- Docente Z000050 - MARTES-14:00-18:00
# 202W0903-Ciclo9-Sec1- Docente Z000052 - MARTES-09:00-13:00
# 202W0903-Ciclo9-Sec2- Docente Z000052 - MARTES-11:00-15:00
# 202W0904-Ciclo9-Sec1- Docente 09620253 - MARTES-10:00-14:00
# 202W0904-Ciclo9-Sec2- Docente Z000055 - LUNES-11:00-15:00
# 202W0905-Ciclo9-Sec1- Docente 0A1873 - LUNES-16:00-20:00
# 202W0905-Ciclo9-Sec2- Docente Z000056 - VIERNES-10:00-14:00
# 202W0906-Ciclo9-Sec1- Docente Z000059 - SABADO-18:00-22:00
# 202W0906-Ciclo9-Sec2- Docente 0A4523 - JUEVES-14:00-18:00
# 202W0907-Ciclo9-Sec1- Docente Z000061 - VIERNES-16:00-20:00
# 202W0907-Ciclo9-Sec2- Docente Z000060 - SABADO-08:00-12:00
# 202W0908-Ciclo9-Sec1- Docente Z000062 - LUNES-18:00-22:00
# 202W0908-Ciclo9-Sec2- Docente 0A2417 - JUEVES-11:00-15:00
# 202W1001-Ciclo10-Sec1- Docente Z000064 - JUEVES-09:00-13:00
# 202W1002-Ciclo10-Sec1- Docente 0A5230 - JUEVES-12:00-15:00
# 202W1003-Ciclo10-Sec1- Docente 0A1876 - MIERCOLES-09:00-15:00
# 202W1004-Ciclo10-Sec1- Docente 46107976 - VIERNES-12:00-17:00
# 202W1005-Ciclo10-Sec1- Docente 0A1874 - JUEVES-15:00-19:00
# 202W1006-Ciclo10-Sec1- Docente 0A1877 - MIERCOLES-18:00-22:00
# INE002-Ciclo1-Sec1- Docente 085774 - JUEVES-14:00-17:00
# INO101-Ciclo1-Sec1- Docente 42229911 - LUNES-18:00-22:00
# INO102-Ciclo1-Sec1- Docente Z000072 - VIERNES-14:00-17:00
# INO103-Ciclo1-Sec1- Docente Z000073 - SABADO-12:00-15:00
# INO106-Ciclo1-Sec1- Docente Z000074 - MARTES-08:00-14:00
# INO204-Ciclo2-Sec1- Docente 40764399 - LUNES-16:00-22:00
# INO205-Ciclo2-Sec1- Docente Z000076 - SABADO-13:00-18:00

# %% [markdown]
# ## 3.1 Calcular Fitness

# %% [markdown]
# ### constrain_cursos_mismo_ciclo_no_solapados

# %%
from collections import defaultdict
from datetime import datetime

# %%
def se_solapan(inicio1, fin1, inicio2, fin2):
    fmt = "%H:%M"
    i1 = datetime.strptime(inicio1, fmt)
    f1 = datetime.strptime(fin1, fmt)
    i2 = datetime.strptime(inicio2, fmt)
    f2 = datetime.strptime(fin2, fmt)
    return max(i1, i2) < min(f1, f2)

# %%
# penalidad por cada curso que genere solape
def constrain_cursos_mismo_ciclo_no_solapados(individuo):

    penalidad = 0
    detalles = []

    # Agrupar asignaciones por ciclo
    asignaciones_por_ciclo = defaultdict(list)
    for asignacion in individuo:
        asignaciones_por_ciclo[asignacion.ciclo].append(asignacion)
    
    for ciclo, asignaciones in asignaciones_por_ciclo.items():
        # Verificar solapes dentro del mismo ciclo
        for i in range(len(asignaciones)):
            for j in range(i + 1, len(asignaciones)):
                a1 = asignaciones[i]
                a2 = asignaciones[j]

                # Si están en el mismo día y se cruzan en horario
                if a1.dia == a2.dia and se_solapan(a1.hora_inicio, a1.hora_fin, a2.hora_inicio, a2.hora_fin):
                    penalidad += 1
                    detalles.append(
                        f"Solapamiento en ciclo {ciclo}: {a1.cod_asignatura}-Sec{a1.seccion} y {a2.cod_asignatura}-Sec{a2.seccion} el {a1.dia} entre {a1.hora_inicio}-{a1.hora_fin} y {a2.hora_inicio}-{a2.hora_fin}"
                    )

    return penalidad, detalles

# %% [markdown]
# ### constrain_cumplir_totalidad_horas

# %%
# penalidades por diferencias entre horas dictadas y horas requeridas
def constrain_cumplir_totalidad_horas(individuo):
    # clave: (cod_asignatura, seccion), valor: suma de horas
    horas_asignadas = defaultdict(float)

    for asignacion in individuo:
        clave = (asignacion.cod_asignatura, asignacion.seccion)
        duracion = asignacion.duracion_horas()
        horas_asignadas[clave] += duracion
        
    penalidad = 0
    detalles = []

    for clave, horas_dictadas in horas_asignadas.items():
        cod_asig, seccion = clave

        fila = df_duracion[df_duracion['CodAsignatura'] == cod_asig]
        if not fila.empty:
            horas_requeridas = float(fila['DuracionHoras'].values[0])
        else:
            # Si no se encuentra el curso en df_duracion, lo penalizamos
            penalidad += 1
            detalles.append(f"{cod_asig} no encontrado en df_duracion")
            continue

        if horas_dictadas != horas_requeridas:
            diferencia = abs(horas_dictadas - horas_requeridas)
            penalidad += diferencia  # penalización proporcional a la diferencia
            detalles.append(f"{cod_asig}-Sec{seccion}: {horas_dictadas}h vs {horas_requeridas}h requeridas")

    return penalidad, detalles

# %% [markdown]
# ### constrain_franjas_validas

# %%
# penalidad por cada curso que este fuera del rango
def constrain_franjas_validas(individuo):
    penalidad = 0
    detalles = []

    hora_minima = 8 * 60     # 08:00 → minutos
    hora_maxima = 22 * 60    # 22:00 → minutos

    for asignacion in individuo:
        # Convertimos hora_inicio y hora_fin a minutos
        h_ini, m_ini = map(int, asignacion.hora_inicio.split(":"))
        h_fin, m_fin = map(int, asignacion.hora_fin.split(":"))
        inicio = h_ini * 60 + m_ini
        fin = h_fin * 60 + m_fin

        # Verificar si está fuera del rango
        if inicio < hora_minima or fin > hora_maxima:
            penalidad += 1
            detalles += f"[{asignacion}] fuera de rango permitido"

    return penalidad, detalles

# %% [markdown]
# ### constrain_docente_max4_cursos

# %%
# 1 punto de penalidad por cada curso de exceso
def constrain_docente_max4_cursos(individuo):
    penalidad = 0
    detalles = []

    # Mapeo: cod_docente → conjunto de cod_asignatura únicos
    cursos_por_docente = defaultdict(set)

    for asignacion in individuo:
        cursos_por_docente[asignacion.cod_docente].add(asignacion.cod_asignatura)

    for cod_docente, cursos in cursos_por_docente.items():
        cantidad_cursos = len(cursos)
        if cantidad_cursos > 4:
            exceso = cantidad_cursos - 4
            penalidad += exceso
            detalles.append(f"Docente {cod_docente} tiene {cantidad_cursos} cursos asignados (máx 4)")

    return penalidad, detalles

# %% [markdown]
# ### constrain_minimo_docentes_por_curso

# %%
# 1 punto de penalidad por cada curso no encontrado y puntos de penalidad 
# adicionales por la diferencia entre aulas reales - aulas requeridas
def constrain_minimo_docentes_por_curso(individuo):
    penalidad = 0
    detalles = []

    # Mapeo: cod_asignatura → conjunto de cod_docente
    docentes_por_curso = defaultdict(set)

    for asignacion in individuo:
        docentes_por_curso[asignacion.cod_asignatura].add(asignacion.cod_docente)

    for cod_asignatura, docentes in docentes_por_curso.items():
        fila = df_docentes_min[df_docentes_min['CodAsignatura'] == cod_asignatura]
        if not fila.empty:
            minimo_requerido = int(fila['NumGrupos'].values[0])
        else:
            # Si no se encuentra el curso en el DataFrame, lo penalizamos
            penalidad += 1
            detalles.append(f"{cod_asignatura} no encontrado en df_docentes_min")
            continue

        cantidad_asignada = len(docentes)
        if cantidad_asignada < minimo_requerido:
            diferencia = minimo_requerido - cantidad_asignada
            penalidad += diferencia
            detalles.append(f"{cod_asignatura} tiene {cantidad_asignada} docentes, requiere mínimo {minimo_requerido}")

    return penalidad, detalles

# %% [markdown]
# ### constrain_ciclos_bajos_horario_preferido

# %%
from datetime import datetime

def constrain_ciclos_bajos_horario_preferido(individuo):
    penalizacion = 0
    detalles_penalizacion = []

    ciclos_bajos = {1, 2, 3, 4, 5}
    hora_almuerzo_inicio = datetime.strptime("13:00", "%H:%M")
    hora_almuerzo_fin = datetime.strptime("14:00", "%H:%M")
    hora_limite = datetime.strptime("18:00", "%H:%M")

    for asignacion in individuo:
        if asignacion.ciclo in ciclos_bajos:
            hora_inicio_dt = datetime.strptime(asignacion.hora_inicio, "%H:%M")

            if hora_almuerzo_inicio <= hora_inicio_dt < hora_almuerzo_fin:
                penalizacion += 1
                detalles_penalizacion.append({
                    "Motivo": "Clase en hora de almuerzo",
                    "CodAsignatura": asignacion.cod_asignatura,
                    "Ciclo": asignacion.ciclo,
                    "HoraInicio": asignacion.hora_inicio,
                    "CodDocente": asignacion.cod_docente,
                    "Día": asignacion.dia
                })

            elif hora_inicio_dt >= hora_limite:
                penalizacion += 1
                detalles_penalizacion.append({
                    "Motivo": "Clase después de las 6pm",
                    "CodAsignatura": asignacion.cod_asignatura,
                    "Ciclo": int(asignacion.ciclo),
                    "HoraInicio": asignacion.hora_inicio,
                    "CodDocente": asignacion.cod_docente,
                    "Día": asignacion.dia
                })

    return penalizacion, detalles_penalizacion

# %% [markdown]
# ### constrain_preferencias_docente

# %%
from datetime import datetime

def convertir_a_hora(valor):
    return datetime.strptime(valor, "%H:%M").time() if isinstance(valor, str) else valor

def constrain_preferencias_docente(individuo):
    penalizacion = 0
    detalles = []

    # Construimos el diccionario de disponibilidad
    disponibilidad_dict = {}
    for _, row in df_disp.iterrows():
        cod = row["CodDocente"]
        dia = row["Día"]
        h_ini = convertir_a_hora(row["HoraInicio"])
        h_fin = convertir_a_hora(row["HoraFin"])

        disponibilidad_dict.setdefault(cod, {}).setdefault(dia, []).append((h_ini, h_fin))

    # Iterar sobre las asignaciones del individuo
    for asignacion in individuo:  # <-- esto depende de tu clase
        cod_docente = asignacion.cod_docente
        dia = asignacion.dia
        h_ini = convertir_a_hora(asignacion.hora_inicio)
        h_fin = convertir_a_hora(asignacion.hora_fin)

        disponible = False
        if cod_docente in disponibilidad_dict and dia in disponibilidad_dict[cod_docente]:
            for rango in disponibilidad_dict[cod_docente][dia]:
                if h_ini >= rango[0] and h_fin <= rango[1]:
                    disponible = True
                    break

        if not disponible:
            penalizacion += 1
            detalles.append(f"{cod_docente} fuera de preferencia en {dia} de {h_ini} a {h_fin}")

    return penalizacion, detalles

# %%
"""def constrain_preferencias_docente(individuo):
    penalizacion = 0
    detalles = []

    # Construimos el diccionario de disponibilidad a partir del DataFrame global
    disponibilidad_dict = {}
    for _, row in df_disp.iterrows():
        cod = row["CodDocente"]
        dia = row["Día"]
        h_ini = row["HoraInicio"]
        h_fin = row["HoraFin"]

        if cod not in disponibilidad_dict:
            disponibilidad_dict[cod] = {}

        if dia not in disponibilidad_dict[cod]:
            disponibilidad_dict[cod][dia] = []

        disponibilidad_dict[cod][dia].append((h_ini, h_fin))

    for asignacion in individuo:
        cod_docente = asignacion.cod_docente
        dia = asignacion.dia
        h_ini = asignacion.hora_inicio
        h_fin = asignacion.hora_fin

        disponible = False
        if cod_docente in disponibilidad_dict and dia in disponibilidad_dict[cod_docente]:
            for rango in disponibilidad_dict[cod_docente][dia]:
                if h_ini >= rango[0] and h_fin <= rango[1]:
                    disponible = True
                    break

        if not disponible:
            penalizacion += 1
            detalles.append(f"{cod_docente} fuera de preferencia en {dia} de {h_ini} a {h_fin}")

    return penalizacion, detalles"""
# Out:
# 'def constrain_preferencias_docente(individuo):\n    penalizacion = 0\n    detalles = []\n\n    # Construimos el diccionario de disponibilidad a partir del DataFrame global\n    disponibilidad_dict = {}\n    for _, row in df_disp.iterrows():\n        cod = row["CodDocente"]\n        dia = row["Día"]\n        h_ini = row["HoraInicio"]\n        h_fin = row["HoraFin"]\n\n        if cod not in disponibilidad_dict:\n            disponibilidad_dict[cod] = {}\n\n        if dia not in disponibilidad_dict[cod]:\n            disponibilidad_dict[cod][dia] = []\n\n        disponibilidad_dict[cod][dia].append((h_ini, h_fin))\n\n    for asignacion in individuo:\n        cod_docente = asignacion.cod_docente\n        dia = asignacion.dia\n        h_ini = asignacion.hora_inicio\n        h_fin = asignacion.hora_fin\n\n        disponible = False\n        if cod_docente in disponibilidad_dict and dia in disponibilidad_dict[cod_docente]:\n            for rango in disponibilidad_dict[cod_docente][dia]:\n                if h_ini >= rango[0] and h_fin <= rango[1]:\n                    disponible = True\n                    break\n\n        if not disponible:\n            penalizacion += 1\n            detalles.append(f"{cod_docente} fuera de preferencia en {dia} de {h_ini} a {h_fin}")\n\n    return penalizacion, detalles'

# %% [markdown]
# ### constrain_3_franjas_mismo_dia

# %%
from collections import defaultdict

def constrain_3_franjas_mismo_dia(individuo):
    penalizacion = 0
    detalles = []

    # Diccionario: (ciclo, día) → contador de franjas
    franjas_por_dia = defaultdict(int)

    for asignacion in individuo:
        clave = (asignacion.ciclo, asignacion.dia)
        franjas_por_dia[clave] += 1

    for (ciclo, dia), cantidad in franjas_por_dia.items():
        if cantidad > 2:
            exceso = cantidad - 2
            penalizacion += exceso
            detalles.append(f"Ciclo {ciclo} tiene {cantidad} cursos el {dia}")

    return penalizacion, detalles

# %% [markdown]
# ### constrain_espacios_mayores_3h_docente

# %%
from collections import defaultdict
from datetime import datetime

def constrain_espacios_mayores_3h_docente(individuo):
    penalizacion = 0
    detalles = []

    # Diccionario: (docente, día) → lista de horas de clases
    sesiones_por_docente_dia = defaultdict(list)

    for asignacion in individuo:
        hora_inicio = datetime.strptime(asignacion.hora_inicio, "%H:%M")
        hora_fin = datetime.strptime(asignacion.hora_fin, "%H:%M")
        sesiones_por_docente_dia[(asignacion.cod_docente, asignacion.dia)].append((hora_inicio, hora_fin))

    for (docente, dia), sesiones in sesiones_por_docente_dia.items():
        # Ordenar las sesiones por hora de inicio
        sesiones.sort()
        for i in range(len(sesiones) - 1):
            fin_actual = sesiones[i][1]
            inicio_siguiente = sesiones[i + 1][0]
            espacio = (inicio_siguiente - fin_actual).total_seconds() / 3600

            if espacio > 3:
                penalizacion += 1
                detalles.append(f"{docente} tiene espacio de {espacio:.1f}h el {dia}")

    return penalizacion, detalles

# %% [markdown]
# ### constrain_espacios_mayores_3h_ciclo

# %%
from collections import defaultdict
from datetime import datetime

def constrain_espacios_mayores_3h_ciclo(individuo):
    penalizacion = 0
    detalles = []

    # Diccionario: (ciclo, día) → lista de horas de clases
    sesiones_por_ciclo_dia = defaultdict(list)

    for asignacion in individuo:
        hora_inicio = datetime.strptime(asignacion.hora_inicio, "%H:%M")
        hora_fin = datetime.strptime(asignacion.hora_fin, "%H:%M")
        sesiones_por_ciclo_dia[(asignacion.ciclo, asignacion.dia)].append((hora_inicio, hora_fin))

    for (ciclo, dia), sesiones in sesiones_por_ciclo_dia.items():
        sesiones.sort()
        for i in range(len(sesiones) - 1):
            fin_actual = sesiones[i][1]
            inicio_siguiente = sesiones[i + 1][0]
            espacio = (inicio_siguiente - fin_actual).total_seconds() / 3600

            if espacio > 3:
                penalizacion += 1
                detalles.append(f"Ciclo {ciclo} tiene espacio de {espacio:.1f}h el {dia}")

    return penalizacion, detalles

# %% [markdown]
# ### constrain_prereq_vs_otros_ciclos

# %%
from datetime import datetime

# Mapa para ordenar los días de la semana
ORDEN_DIAS = {
    "LUNES": 0, "MARTES": 1, "MIERCOLES": 2, "JUEVES": 3,
    "VIERNES": 4, "SABADO": 5
}

def constrain_prereq_vs_otros_ciclos(individuo):
    penalizacion = 0
    detalles = []

    # Agrupar asignaciones por curso
    sesiones_por_curso = {}
    
    for asignacion in individuo:
        if asignacion.cod_asignatura not in sesiones_por_curso:
            sesiones_por_curso[asignacion.cod_asignatura] = []
        sesiones_por_curso[asignacion.cod_asignatura].append(asignacion)

    for curso, prereqs in dict_prerrequisitos.items():
        if curso not in sesiones_por_curso:
            continue  # No se programó el curso
        for prereq in prereqs:
            if prereq not in sesiones_por_curso:
                continue  # No se programó el prerrequisito

            # Obtener la sesión más temprana de prereq y la más temprana del curso
            min_inicio_prereq = min(
                (ORDEN_DIAS[a.dia], datetime.strptime(a.hora_inicio, "%H:%M")) 
                for a in sesiones_por_curso[prereq]
            )

            min_inicio_curso = min(
                (ORDEN_DIAS[a.dia], datetime.strptime(a.hora_inicio, "%H:%M")) 
                for a in sesiones_por_curso[curso]
            )

            if min_inicio_prereq > min_inicio_curso:
                penalizacion += 1
                detalles.append(
                    f"Curso {curso} se dicta antes que su prerrequisito {prereq}"
                )

    return penalizacion, detalles

# %% [markdown]
# ### Ejecución del fitness

# %%
def calcular_fitness(individuo):
    penalidad_total = 0
    detalles_penalidades = []
    penalidad_por_constrain = []

    # Cada función evalúa un constraint y devuelve un número (penalidad) y descripción
    for funcion, nombre_constraint, peso in [
        (constrain_cursos_mismo_ciclo_no_solapados, "Cursos del mismo ciclo no deben compartir franja", 6),
        (constrain_cumplir_totalidad_horas, "Cursos deben cumplir totalidad de horas", 6),
        (constrain_franjas_validas, "Cursos deben estar entre 8am-1pm y 2pm-10pm", 6),
        (constrain_docente_max4_cursos, "Docente dicta máximo 4 cursos", 5),
        (constrain_minimo_docentes_por_curso, "Cantidad mínima de docentes por curso", 5),

        #(constrain_docentes_limite_horas, "Docente no pasa su límite de horas lectivas", 5),
        #(constrain_docente_para_todas_secciones, "Asignar docentes a todas las secciones", 5),

        (constrain_ciclos_bajos_horario_preferido, "Cursos 1-5 ciclo preferencia horario", 4),
        (constrain_preferencias_docente, "Preferencias horarias del docente", 3),
        (constrain_3_franjas_mismo_dia, "Evitar 3 franjas distintas mismo día (mismo ciclo)", 3),
        (constrain_espacios_mayores_3h_docente, "Evitar huecos >3h en un mismo día (docente)", 3),
        (constrain_espacios_mayores_3h_ciclo, "Evitar huecos >3h en un mismo día (ciclo)", 3),
        (constrain_prereq_vs_otros_ciclos, "Evitar solapes de no-prereqs entre ciclos cercanos", 2)#,
        #(constrain_dias_lunes_viernes, "Preferencia lunes a viernes", 1),
    ]:
        penalidad, descripcion = funcion(individuo)
        penalidad_ponderada = penalidad * peso
        penalidad_por_constrain.append({"nombre_constraint": nombre_constraint, "penalidad":penalidad_ponderada})
        penalidad_total += penalidad_ponderada
        detalles_penalidades.append((nombre_constraint, penalidad, peso, penalidad_ponderada, descripcion))

    return penalidad_total, detalles_penalidades,penalidad_por_constrain

# %%
penalidad,detalles_penalidad,penalidad_por_constrain = calcular_fitness(individuo)

# %%
test=calcular_fitness(individuo)

# %%
penalidad
# Out:
# 514

# %%
detalles_penalidad
# Out:
# [('Cursos del mismo ciclo no deben compartir franja',
#   26,
#   6,
#   156,
#   ['Solapamiento en ciclo 3: 202W0301-Sec1 y 202W0305-Sec1 el LUNES entre 11:00-16:00 y 09:00-13:00',
#    'Solapamiento en ciclo 3: 202W0301-Sec1 y 202W0306-Sec1 el LUNES entre 11:00-16:00 y 09:00-14:00',
#    'Solapamiento en ciclo 3: 202W0305-Sec1 y 202W0306-Sec1 el LUNES entre 09:00-13:00 y 09:00-14:00',
#    'Solapamiento en ciclo 4: 202W0402-Sec1 y 202W0405-Sec1 el SABADO entre 14:00-18:00 y 16:00-20:00',
#    'Solapamiento en ciclo 4: 202W0402-Sec1 y 202W0407-Sec1 el SABADO entre 14:00-18:00 y 17:00-22:00',
#    'Solapamiento en ciclo 4: 202W0403-Sec1 y 202W0404-Sec1 el MARTES entre 09:00-13:00 y 12:00-16:00',
#    'Solapamiento en ciclo 4: 202W0405-Sec1 y 202W0407-Sec1 el SABADO entre 16:00-20:00 y 17:00-22:00',
#    'Solapamiento en ciclo 5: 202W0503-Sec1 y 202W0506-Sec1 el JUEVES entre 09:00-13:00 y 11:00-15:00',
#    'Solapamiento en ciclo 5: 202W0504-Sec1 y 202W0505-Sec1 el VIERNES entre 14:00-18:00 y 16:00-21:00',
#    'Solapamiento en ciclo 6: 202W0602-Sec1 y 202W0604-Sec1 el VIERNES entre 11:00-16:00 y 13:00-17:00',
#    'Solapamiento en ciclo 7: 202W0702-Sec1 y 202W0703-Sec1 el MARTES entre 14:00-19:00 y 17:00-21:00',
#    'Solapamiento en ciclo 7: 202W0702-Sec1 y 202W0707-Sec1 el MARTES entre 14:00-19:00 y 12:00-16:00',
#    'Solapamiento en ciclo 7: 202W0703-Sec2 y 202W0704-Sec1 el LUNES entre 14:00-18:00 y 11:00-15:00',
#    'Solapamiento en ciclo 7: 202W0703-Sec2 y 202W0705-Sec2 el LUNES entre 14:00-18:00 y 15:00-19:00',
#    'Solapamiento en ciclo 7: 202W0705-Sec1 y 202W0706-Sec1 el MARTES entre 08:00-12:00 y 08:00-12:00',
#    'Solapamiento en ciclo 8: 202W0804-Sec1 y 202W0805-Sec1 el MIERCOLES entre 09:00-13:00 y 09:00-13:00',
#    'Solapamiento en ciclo 9: 202W0901-Sec2 y 202W0905-Sec1 el LUNES entre 19:00-22:00 y 16:00-20:00',
#    'Solapamiento en ciclo 9: 202W0901-Sec2 y 202W0908-Sec1 el LUNES entre 19:00-22:00 y 18:00-22:00',
#    'Solapamiento en ciclo 9: 202W0902-Sec1 y 202W0904-Sec2 el LUNES entre 12:00-16:00 y 11:00-15:00',
#    'Solapamiento en ciclo 9: 202W0902-Sec2 y 202W0903-Sec2 el MARTES entre 14:00-18:00 y 11:00-15:00',
#    'Solapamiento en ciclo 9: 202W0903-Sec1 y 202W0903-Sec2 el MARTES entre 09:00-13:00 y 11:00-15:00',
#    'Solapamiento en ciclo 9: 202W0903-Sec1 y 202W0904-Sec1 el MARTES entre 09:00-13:00 y 10:00-14:00',
#    'Solapamiento en ciclo 9: 202W0903-Sec2 y 202W0904-Sec1 el MARTES entre 11:00-15:00 y 10:00-14:00',
#    'Solapamiento en ciclo 9: 202W0905-Sec1 y 202W0908-Sec1 el LUNES entre 16:00-20:00 y 18:00-22:00',
#    'Solapamiento en ciclo 9: 202W0906-Sec2 y 202W0908-Sec2 el JUEVES entre 14:00-18:00 y 11:00-15:00',
#    'Solapamiento en ciclo 10: 202W1001-Sec1 y 202W1002-Sec1 el JUEVES entre 09:00-13:00 y 12:00-15:00']),
#  ('Cursos deben cumplir totalidad de horas', 0, 6, 0, []),
#  ('Cursos deben estar entre 8am-1pm y 2pm-10pm', 0, 6, 0, []),
#  ('Docente dicta máximo 4 cursos', 0, 5, 0, []),
#  ('Cantidad mínima de docentes por curso',
#   3,
#   5,
#   15,
#   ['202W0702 tiene 1 docentes, requiere mínimo 2',
#    '202W0705 tiene 1 docentes, requiere mínimo 2',
#    '202W0903 tiene 1 docentes, requiere mínimo 2']),
#  ('Cursos 1-5 ciclo preferencia horario',
#   3,
#   4,
#   12,
#   [{'Motivo': 'Clase después de las 6pm',
#     'CodAsignatura': '202W0303',
#     'Ciclo': 3,
#     'HoraInicio': '18:00',
#     'CodDocente': 'Z000002',
#     'Día': 'MARTES'},
#    {'Motivo': 'Clase después de las 6pm',
#     'CodAsignatura': 'INO101',
#     'Ciclo': 1,
#     'HoraInicio': '18:00',
#     'CodDocente': '42229911',
#     'Día': 'LUNES'},
#    {'Motivo': 'Clase en hora de almuerzo',
#     'CodAsignatura': 'INO205',
#     'Ciclo': np.int64(2),
#     'HoraInicio': '13:00',
#     'CodDocente': 'Z000076',
#     'Día': 'SABADO'}]),
#  ('Preferencias horarias del docente',
#   76,
#   3,
#   228,
#   ['0A9179 fuera de preferencia en LUNES de 11:00:00 a 16:00:00',
#    '043788 fuera de preferencia en MIERCOLES de 10:00:00 a 15:00:00',
#    'Z000002 fuera de preferencia en MARTES de 18:00:00 a 22:00:00',
#    '08490635 fuera de preferencia en SABADO de 15:00:00 a 19:00:00',
#    '0A0314 fuera de preferencia en LUNES de 09:00:00 a 13:00:00',
#    '0A0259 fuera de preferencia en LUNES de 09:00:00 a 14:00:00',
#    '0A1871 fuera de preferencia en VIERNES de 16:00:00 a 20:00:00',
#    'Z000007 fuera de preferencia en MIERCOLES de 15:00:00 a 20:00:00',
#    '41388541 fuera de preferencia en SABADO de 14:00:00 a 18:00:00',
#    'Z000009 fuera de preferencia en MARTES de 09:00:00 a 13:00:00',
#    '0A5230 fuera de preferencia en MARTES de 12:00:00 a 16:00:00',
#    'Z000011 fuera de preferencia en SABADO de 16:00:00 a 20:00:00',
#    '095699 fuera de preferencia en SABADO de 17:00:00 a 22:00:00',
#    '095729 fuera de preferencia en SABADO de 09:00:00 a 13:00:00',
#    '10089409 fuera de preferencia en LUNES de 14:00:00 a 18:00:00',
#    '01345428 fuera de preferencia en JUEVES de 09:00:00 a 13:00:00',
#    '09571E fuera de preferencia en VIERNES de 14:00:00 a 18:00:00',
#    'Z000017 fuera de preferencia en VIERNES de 16:00:00 a 21:00:00',
#    'Z000018 fuera de preferencia en JUEVES de 11:00:00 a 15:00:00',
#    '09620253 fuera de preferencia en MARTES de 16:00:00 a 21:00:00',
#    '0A5291 fuera de preferencia en MIERCOLES de 17:00:00 a 21:00:00',
#    '0A1876 fuera de preferencia en VIERNES de 11:00:00 a 16:00:00',
#    'Z000022 fuera de preferencia en MIERCOLES de 09:00:00 a 14:00:00',
#    '0A1871 fuera de preferencia en VIERNES de 13:00:00 a 17:00:00',
#    '0A1875 fuera de preferencia en MARTES de 12:00:00 a 17:00:00',
#    'Z000025 fuera de preferencia en SABADO de 15:00:00 a 19:00:00',
#    'Z000026 fuera de preferencia en LUNES de 18:00:00 a 22:00:00',
#    '0A0690 fuera de preferencia en MIERCOLES de 08:00:00 a 13:00:00',
#    '0A4525 fuera de preferencia en JUEVES de 17:00:00 a 22:00:00',
#    '0A2067 fuera de preferencia en MARTES de 14:00:00 a 19:00:00',
#    '0A2067 fuera de preferencia en JUEVES de 12:00:00 a 17:00:00',
#    '0A0690 fuera de preferencia en MARTES de 17:00:00 a 21:00:00',
#    'Z000031 fuera de preferencia en LUNES de 14:00:00 a 18:00:00',
#    '0A5291 fuera de preferencia en LUNES de 11:00:00 a 15:00:00',
#    '44230686 fuera de preferencia en MARTES de 08:00:00 a 12:00:00',
#    '44230686 fuera de preferencia en LUNES de 15:00:00 a 19:00:00',
#    '08232375 fuera de preferencia en MARTES de 08:00:00 a 12:00:00',
#    '091081 fuera de preferencia en VIERNES de 08:00:00 a 12:00:00',
#    'Z000039 fuera de preferencia en MARTES de 12:00:00 a 16:00:00',
#    'Z000038 fuera de preferencia en MIERCOLES de 16:00:00 a 20:00:00',
#    '44230686 fuera de preferencia en JUEVES de 16:00:00 a 20:00:00',
#    '0A1236 fuera de preferencia en SABADO de 12:00:00 a 16:00:00',
#    '0A6225 fuera de preferencia en SABADO de 19:00:00 a 22:00:00',
#    'Z000043 fuera de preferencia en MIERCOLES de 09:00:00 a 13:00:00',
#    'Z000044 fuera de preferencia en MIERCOLES de 09:00:00 a 13:00:00',
#    '0A1981 fuera de preferencia en VIERNES de 12:00:00 a 16:00:00',
#    'Z000046 fuera de preferencia en MARTES de 11:00:00 a 15:00:00',
#    '0A0314 fuera de preferencia en LUNES de 17:00:00 a 21:00:00',
#    '0A6226 fuera de preferencia en JUEVES de 18:00:00 a 21:00:00',
#    '0A5306 fuera de preferencia en LUNES de 19:00:00 a 22:00:00',
#    'Z000051 fuera de preferencia en LUNES de 12:00:00 a 16:00:00',
#    'Z000050 fuera de preferencia en MARTES de 14:00:00 a 18:00:00',
#    'Z000052 fuera de preferencia en MARTES de 09:00:00 a 13:00:00',
#    'Z000052 fuera de preferencia en MARTES de 11:00:00 a 15:00:00',
#    '09620253 fuera de preferencia en MARTES de 10:00:00 a 14:00:00',
#    'Z000055 fuera de preferencia en LUNES de 11:00:00 a 15:00:00',
#    '0A1873 fuera de preferencia en LUNES de 16:00:00 a 20:00:00',
#    'Z000056 fuera de preferencia en VIERNES de 10:00:00 a 14:00:00',
#    'Z000059 fuera de preferencia en SABADO de 18:00:00 a 22:00:00',
#    'Z000061 fuera de preferencia en VIERNES de 16:00:00 a 20:00:00',
#    'Z000060 fuera de preferencia en SABADO de 08:00:00 a 12:00:00',
#    'Z000062 fuera de preferencia en LUNES de 18:00:00 a 22:00:00',
#    '0A2417 fuera de preferencia en JUEVES de 11:00:00 a 15:00:00',
#    'Z000064 fuera de preferencia en JUEVES de 09:00:00 a 13:00:00',
#    '0A5230 fuera de preferencia en JUEVES de 12:00:00 a 15:00:00',
#    '0A1876 fuera de preferencia en MIERCOLES de 09:00:00 a 15:00:00',
#    '46107976 fuera de preferencia en VIERNES de 12:00:00 a 17:00:00',
#    '0A1874 fuera de preferencia en JUEVES de 15:00:00 a 19:00:00',
#    '0A1877 fuera de preferencia en MIERCOLES de 18:00:00 a 22:00:00',
#    '085774 fuera de preferencia en JUEVES de 14:00:00 a 17:00:00',
#    '42229911 fuera de preferencia en LUNES de 18:00:00 a 22:00:00',
#    'Z000072 fuera de preferencia en VIERNES de 14:00:00 a 17:00:00',
#    'Z000073 fuera de preferencia en SABADO de 12:00:00 a 15:00:00',
#    'Z000074 fuera de preferencia en MARTES de 08:00:00 a 14:00:00',
#    '40764399 fuera de preferencia en LUNES de 16:00:00 a 22:00:00',
#    'Z000076 fuera de preferencia en SABADO de 13:00:00 a 18:00:00']),
#  ('Evitar 3 franjas distintas mismo día (mismo ciclo)',
#   13,
#   3,
#   39,
#   ['Ciclo 3 tiene 3 cursos el LUNES',
#    'Ciclo 4 tiene 3 cursos el SABADO',
#    'Ciclo 7 tiene 5 cursos el MARTES',
#    'Ciclo 7 tiene 3 cursos el LUNES',
#    'Ciclo 9 tiene 3 cursos el JUEVES',
#    'Ciclo 9 tiene 5 cursos el LUNES',
#    'Ciclo 9 tiene 4 cursos el MARTES',
#    'Ciclo 10 tiene 3 cursos el JUEVES']),
#  ('Evitar huecos >3h en un mismo día (docente)',
#   1,
#   3,
#   3,
#   ['0A0314 tiene espacio de 4.0h el LUNES']),
#  ('Evitar huecos >3h en un mismo día (ciclo)',
#   1,
#   3,
#   3,
#   ['Ciclo 9 tiene espacio de 6.0h el SABADO']),
#  ('Evitar solapes de no-prereqs entre ciclos cercanos',
#   29,
#   2,
#   58,
#   ['Curso 202W0403 se dicta antes que su prerrequisito 202W0304',
#    'Curso 202W0501 se dicta antes que su prerrequisito 202W0405',
#    'Curso 202W0502 se dicta antes que su prerrequisito 202W0407',
#    'Curso 202W0506 se dicta antes que su prerrequisito 202W0402',
#    'Curso 202W0601 se dicta antes que su prerrequisito 202W0503',
#    'Curso 202W0602 se dicta antes que su prerrequisito 202W0505',
#    'Curso 202W0603 se dicta antes que su prerrequisito 202W0505',
#    'Curso 202W0701 se dicta antes que su prerrequisito 202W0602',
#    'Curso 202W0701 se dicta antes que su prerrequisito 202W0603',
#    'Curso 202W0701 se dicta antes que su prerrequisito 202W0601',
#    'Curso 202W0702 se dicta antes que su prerrequisito 202W0602',
#    'Curso 202W0703 se dicta antes que su prerrequisito 202W0603',
#    'Curso 202W0703 se dicta antes que su prerrequisito 202W0606',
#    'Curso 202W0704 se dicta antes que su prerrequisito 202W0604',
#    'Curso 202W0705 se dicta antes que su prerrequisito 202W0606',
#    'Curso 202W0706 se dicta antes que su prerrequisito 202W0503',
#    'Curso 202W0706 se dicta antes que su prerrequisito 202W0605',
#    'Curso 202W0807 se dicta antes que su prerrequisito 202W0701',
#    'Curso 202W0807 se dicta antes que su prerrequisito 202W0702',
#    'Curso 202W0807 se dicta antes que su prerrequisito 202W0707',
#    'Curso 202W0808 se dicta antes que su prerrequisito 202W0706',
#    'Curso 202W0901 se dicta antes que su prerrequisito 202W0803',
#    'Curso 202W0902 se dicta antes que su prerrequisito 202W0806',
#    'Curso 202W0904 se dicta antes que su prerrequisito 202W0807',
#    'Curso 202W0906 se dicta antes que su prerrequisito 202W0801',
#    'Curso 202W1001 se dicta antes que su prerrequisito 202W0802',
#    'Curso 202W1003 se dicta antes que su prerrequisito 202W0907',
#    'Curso 202W1004 se dicta antes que su prerrequisito 202W0907',
#    'Curso 202W1005 se dicta antes que su prerrequisito 202W0907'])]

# %%
penalidad_por_constrain
# Out:
# [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#   'penalidad': 156},
#  {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#   'penalidad': 0},
#  {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#   'penalidad': 0},
#  {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#  {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#   'penalidad': 15},
#  {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#   'penalidad': 12},
#  {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 228},
#  {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#   'penalidad': 39},
#  {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#   'penalidad': 3},
#  {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#   'penalidad': 3},
#  {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#   'penalidad': 58}]

# %% [markdown]
# ## 3.2 Cruce

# %% [markdown]
# ### Cruce

# %%
from copy import deepcopy

# %%
def cruce_inteligente(poblacion, tamaño_torneo=5, prob_cruce=0.9):
    
    def suma_penalidades(penal_dict):
        if isinstance(penal_dict, dict):
            return sum(float(v) for v in penal_dict.values() if isinstance(v, (int, float, str)) and str(v).replace('.', '', 1).isdigit())
        return 0


    nueva_poblacion = []

    while len(nueva_poblacion) < len(poblacion):
        # Selección por torneo
        torneo1 = random.sample(poblacion, tamaño_torneo)
        torneo2 = random.sample(poblacion, tamaño_torneo)

        padre1 = min(torneo1, key=lambda ind: calcular_fitness(ind)[0])
        padre2 = min(torneo2, key=lambda ind: calcular_fitness(ind)[0])

        if random.random() < prob_cruce:
            penalidades1 = calcular_fitness(padre1)[2]  # penalidad_por_constrain
            penalidades2 = calcular_fitness(padre2)[2]

            hijo = []
            for i in range(len(padre1)):
                penal1 = penalidades1[i] if i < len(penalidades1) else {}
                penal2 = penalidades2[i] if i < len(penalidades2) else {}

                suma1 = suma_penalidades(penal1)
                suma2 = suma_penalidades(penal2)

                if suma1 == 0 and suma2 == 0:
                    hijo.append(random.choice([padre1[i], padre2[i]]))
                elif suma1 == 0:
                    hijo.append(padre1[i])
                elif suma2 == 0:
                    hijo.append(padre2[i])
                else:
                    hijo.append(padre1[i] if suma1 < suma2 else padre2[i])
            nueva_poblacion.append(hijo)
        else:
            nueva_poblacion.extend([deepcopy(padre1), deepcopy(padre2)])

    return nueva_poblacion[:len(poblacion)]

# %% [markdown]
# ## 3.3 Mutación

# %% [markdown]
# ### Mutación

# %%
import copy

DIAS_VALIDOS = ['LUNES', 'MARTES', 'MIERCOLES', 'JUEVES', 'VIERNES', 'SABADO']

def mutar_individuo_por_penalidad(individuo, penalidad, dia=None, penalidad_max=800):
    """
    Aplica mutación más intensa en individuos con más penalidad.
    Cambia el día de una o más sesiones del individuo.

    Args:
        individuo: lista de sesiones (cada una es un objeto Asignacion)
        penalidad: penalidad del individuo
        dia: día al que se quiere mutar (si None, se elige al azar distinto del actual)
        penalidad_max: penalidad más alta posible (para escalar la probabilidad)

    Return:
        nuevo_individuo: individuo mutado
    """
    nuevo_individuo = [copy.deepcopy(sesion) for sesion in individuo]

    # Escalar la probabilidad: más penalidad → más chance de mutar
    prob_mutacion = min(1.0, penalidad / penalidad_max)  # Normalizar entre 0 y 1

    for sesion in nuevo_individuo:
        if random.random() < prob_mutacion:
            dia_actual = sesion.dia

            if dia:
                nuevo_dia = dia
            else:
                dias_disponibles = [d for d in DIAS_VALIDOS if d != dia_actual]
                nuevo_dia = random.choice(dias_disponibles)

            sesion.dia = nuevo_dia

    return nuevo_individuo

# %% [markdown]
# ## 4.3 Correr algoritmo genetico

# %%
import matplotlib.pyplot as plt

def run_algoritmo_genetico(
    tam_poblacion=30,
    generaciones=100,
    porcentaje_elite=0.1,
    verbose=True
):
    penalidades_totales = []
    historial_penalidad = []

    # 1. Inicialización
    poblacion = [generador.generar_individuo() for _ in range(tam_poblacion)]
    poblacion_fitness = [(ind, *calcular_fitness(ind)) for ind in poblacion]

    for gen in range(generaciones):
        # Ordenar por penalidad (fitness más bajo = mejor)
        poblacion_fitness.sort(key=lambda x: x[1])  # Ordenar por penalidad total
        elite_count = int(porcentaje_elite * tam_poblacion)
        elite = [x[0] for x in poblacion_fitness[:elite_count]]

        # Obtener individuos para cruce (solo genotipos)
        poblacion_actual = [x[0] for x in poblacion_fitness]

        # Aplicar cruce por torneo con población completa
        hijos = cruce_inteligente(poblacion_actual)

        # Aplicar mutación a los hijos
        hijos_mutados = []
        for hijo in hijos:
            penalidad,_,_ = calcular_fitness(hijo)
            hijo_mutado = mutar_individuo_por_penalidad(hijo, penalidad)
            hijos_mutados.append(hijo_mutado)

        # Armar nueva población (elite + hijos mutados)
        nueva_poblacion = elite + hijos_mutados[:tam_poblacion - elite_count]

        # Evaluar nueva población
        poblacion_fitness = [(ind, *calcular_fitness(ind)) for ind in nueva_poblacion]

        # Ordenar por penalidad total (p[1]) y extraer p[2]

        # Mejor individuo de la generación
        mejor_individuo_fitness = min(poblacion_fitness, key=lambda p: p[1])
        mejor_penalidad = mejor_individuo_fitness[1]
        h_pemalidades = mejor_individuo_fitness[3]

        penalidades_totales.append(mejor_penalidad)
        historial_penalidad.append(h_pemalidades)

        if verbose:
            print(f"Generación {gen + 1}: Mejor penalidad = {mejor_penalidad}")

        # Obtener mejor individuo
        mejor_individuo = min(poblacion_fitness, key=lambda x: x[1])

    return mejor_individuo, historial_penalidad, penalidades_totales

# %%
mejor_individuo, historial, mejores_penalidades = run_algoritmo_genetico(
    tam_poblacion=60,
    generaciones=120,
    porcentaje_elite=0.3
)
# Out:
# Generación 1: Mejor penalidad = 448
# Generación 2: Mejor penalidad = 448
# Generación 3: Mejor penalidad = 448
# Generación 4: Mejor penalidad = 443
# Generación 5: Mejor penalidad = 426
# Generación 6: Mejor penalidad = 426
# Generación 7: Mejor penalidad = 426
# Generación 8: Mejor penalidad = 426
# Generación 9: Mejor penalidad = 426
# Generación 10: Mejor penalidad = 426
# Generación 11: Mejor penalidad = 426
# Generación 12: Mejor penalidad = 426
# Generación 13: Mejor penalidad = 426
# Generación 14: Mejor penalidad = 426
# Generación 15: Mejor penalidad = 426
# Generación 16: Mejor penalidad = 426
# Generación 17: Mejor penalidad = 426
# Generación 18: Mejor penalidad = 426
# Generación 19: Mejor penalidad = 426
# Generación 20: Mejor penalidad = 406
# Generación 21: Mejor penalidad = 406
# Generación 22: Mejor penalidad = 406
# Generación 23: Mejor penalidad = 406
# Generación 24: Mejor penalidad = 406
# Generación 25: Mejor penalidad = 395
# Generación 26: Mejor penalidad = 395
# Generación 27: Mejor penalidad = 395
# Generación 28: Mejor penalidad = 395
# Generación 29: Mejor penalidad = 395
# Generación 30: Mejor penalidad = 395
# Generación 31: Mejor penalidad = 395
# Generación 32: Mejor penalidad = 395
# Generación 33: Mejor penalidad = 395
# Generación 34: Mejor penalidad = 395
# Generación 35: Mejor penalidad = 395
# Generación 36: Mejor penalidad = 395
# Generación 37: Mejor penalidad = 395
# Generación 38: Mejor penalidad = 395
# Generación 39: Mejor penalidad = 395
# Generación 40: Mejor penalidad = 395
# Generación 41: Mejor penalidad = 395
# Generación 42: Mejor penalidad = 395
# Generación 43: Mejor penalidad = 395
# Generación 44: Mejor penalidad = 395
# Generación 45: Mejor penalidad = 395
# Generación 46: Mejor penalidad = 395
# Generación 47: Mejor penalidad = 395
# Generación 48: Mejor penalidad = 395
# Generación 49: Mejor penalidad = 395
# Generación 50: Mejor penalidad = 395
# Generación 51: Mejor penalidad = 395
# Generación 52: Mejor penalidad = 395
# Generación 53: Mejor penalidad = 395
# Generación 54: Mejor penalidad = 395
# Generación 55: Mejor penalidad = 395
# Generación 56: Mejor penalidad = 395
# Generación 57: Mejor penalidad = 395
# Generación 58: Mejor penalidad = 395
# Generación 59: Mejor penalidad = 395
# Generación 60: Mejor penalidad = 395
# Generación 61: Mejor penalidad = 395
# Generación 62: Mejor penalidad = 395
# Generación 63: Mejor penalidad = 395
# Generación 64: Mejor penalidad = 395
# Generación 65: Mejor penalidad = 395
# Generación 66: Mejor penalidad = 395
# Generación 67: Mejor penalidad = 395
# Generación 68: Mejor penalidad = 395
# Generación 69: Mejor penalidad = 395
# Generación 70: Mejor penalidad = 395
# Generación 71: Mejor penalidad = 386
# Generación 72: Mejor penalidad = 386
# Generación 73: Mejor penalidad = 386
# Generación 74: Mejor penalidad = 386
# Generación 75: Mejor penalidad = 370
# Generación 76: Mejor penalidad = 370
# Generación 77: Mejor penalidad = 370
# Generación 78: Mejor penalidad = 370
# Generación 79: Mejor penalidad = 370
# Generación 80: Mejor penalidad = 370
# Generación 81: Mejor penalidad = 370
# Generación 82: Mejor penalidad = 370
# Generación 83: Mejor penalidad = 370
# Generación 84: Mejor penalidad = 370
# Generación 85: Mejor penalidad = 370
# Generación 86: Mejor penalidad = 370
# Generación 87: Mejor penalidad = 370
# Generación 88: Mejor penalidad = 370
# Generación 89: Mejor penalidad = 370
# Generación 90: Mejor penalidad = 370
# Generación 91: Mejor penalidad = 370
# Generación 92: Mejor penalidad = 370
# Generación 93: Mejor penalidad = 370
# Generación 94: Mejor penalidad = 370
# Generación 95: Mejor penalidad = 370
# Generación 96: Mejor penalidad = 370
# Generación 97: Mejor penalidad = 370
# Generación 98: Mejor penalidad = 370
# Generación 99: Mejor penalidad = 370
# Generación 100: Mejor penalidad = 370
# Generación 101: Mejor penalidad = 370
# Generación 102: Mejor penalidad = 370
# Generación 103: Mejor penalidad = 370
# Generación 104: Mejor penalidad = 370
# Generación 105: Mejor penalidad = 370
# Generación 106: Mejor penalidad = 370
# Generación 107: Mejor penalidad = 370
# Generación 108: Mejor penalidad = 370
# Generación 109: Mejor penalidad = 370
# Generación 110: Mejor penalidad = 370
# Generación 111: Mejor penalidad = 370
# Generación 112: Mejor penalidad = 370
# Generación 113: Mejor penalidad = 370
# Generación 114: Mejor penalidad = 370
# Generación 115: Mejor penalidad = 370
# Generación 116: Mejor penalidad = 370
# Generación 117: Mejor penalidad = 370
# Generación 118: Mejor penalidad = 370
# Generación 119: Mejor penalidad = 370
# Generación 120: Mejor penalidad = 370

# %%
historial
# Out:
# [[{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 114},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 25},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 16},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 207},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 114},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 25},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 16},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 207},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 114},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 25},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 16},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 207},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 24},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 62}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 126},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 10},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 213},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 30},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 50}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 78},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 15},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 20},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 216},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 64}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 78},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 15},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 20},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 216},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 64}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 78},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 15},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 20},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 216},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 64}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 78},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 15},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 20},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 216},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 64}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 78},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 15},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 20},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 216},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 64}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 78},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 15},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 20},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 216},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 64}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 78},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 15},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 20},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 216},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 64}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 78},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 15},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 20},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 216},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 64}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 78},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 15},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 20},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 216},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 64}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 78},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 15},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 20},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 216},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 64}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 78},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 15},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 20},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 216},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 64}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 78},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 15},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 20},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 216},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 64}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 78},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 15},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 20},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 216},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 64}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 78},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 15},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 20},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 216},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 64}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 78},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 15},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 20},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 216},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 64}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 84},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 216},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 36},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 56}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 84},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 216},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 36},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 56}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 84},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 216},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 36},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 56}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 84},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 216},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 36},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 56}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 84},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 216},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 36},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 56}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 90},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 46}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 90},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 46}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 90},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 46}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 90},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 46}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 90},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 46}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 90},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 46}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 90},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 46}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 90},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 46}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 90},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 46}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 90},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 46}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 90},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 46}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 90},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 46}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 90},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 46}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 90},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 46}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 90},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 46}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 90},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 46}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 90},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 46}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 90},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 46}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 90},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 46}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 90},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 46}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 90},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 46}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 90},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 46}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 90},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 46}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 90},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 46}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 90},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 4},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 222},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 27},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 0},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 6},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 46}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
# ...
#    'penalidad': 21},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 50}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 207},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 21},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 50}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 207},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 21},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 50}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 207},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 21},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 50}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 207},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 21},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 50}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 207},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 21},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 50}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 207},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 21},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 50}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 207},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 21},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 50}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 207},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 21},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 50}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 207},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 21},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 50}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 207},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 21},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 50}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 207},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 21},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 50}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 207},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 21},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 50}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 207},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 21},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 50}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 207},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 21},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 50}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 207},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 21},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 50}],
#  [{'nombre_constraint': 'Cursos del mismo ciclo no deben compartir franja',
#    'penalidad': 72},
#   {'nombre_constraint': 'Cursos deben cumplir totalidad de horas',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos deben estar entre 8am-1pm y 2pm-10pm',
#    'penalidad': 0},
#   {'nombre_constraint': 'Docente dicta máximo 4 cursos', 'penalidad': 0},
#   {'nombre_constraint': 'Cantidad mínima de docentes por curso',
#    'penalidad': 0},
#   {'nombre_constraint': 'Cursos 1-5 ciclo preferencia horario',
#    'penalidad': 8},
#   {'nombre_constraint': 'Preferencias horarias del docente', 'penalidad': 207},
#   {'nombre_constraint': 'Evitar 3 franjas distintas mismo día (mismo ciclo)',
#    'penalidad': 21},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (docente)',
#    'penalidad': 3},
#   {'nombre_constraint': 'Evitar huecos >3h en un mismo día (ciclo)',
#    'penalidad': 9},
#   {'nombre_constraint': 'Evitar solapes de no-prereqs entre ciclos cercanos',
#    'penalidad': 50}]]

# %%
# Transformar historial a una lista de diccionarios por generación
historial_dicts = [
    {item['nombre_constraint']: item['penalidad'] for item in generacion}
    for generacion in historial
]

# %%
historial_dicts
# Out:
# [{'Cursos del mismo ciclo no deben compartir franja': 114,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 25,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 0,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 114,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 25,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 0,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 114,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 25,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 0,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 126,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 10,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 213,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 84,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 36,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 56},
#  {'Cursos del mismo ciclo no deben compartir franja': 84,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 36,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 56},
#  {'Cursos del mismo ciclo no deben compartir franja': 84,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 36,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 56},
#  {'Cursos del mismo ciclo no deben compartir franja': 84,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 36,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 56},
#  {'Cursos del mismo ciclo no deben compartir franja': 84,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 36,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 56},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 213,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 40},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 213,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 40},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 213,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 40},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 213,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 40},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
# ...
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50}]

# %%
mejor_individuo[0]
# Out:
# [202W0301-Ciclo3-Sec1- Docente 085774 - VIERNES-13:00-18:00,
#  202W0302-Ciclo3-Sec1- Docente 043788 - VIERNES-17:00-22:00,
#  202W0303-Ciclo3-Sec1- Docente 0A06292 - MARTES-09:00-13:00,
#  202W0304-Ciclo3-Sec1- Docente Z000003 - MARTES-09:00-13:00,
#  202W0305-Ciclo3-Sec1- Docente 0A0314 - MIERCOLES-15:00-19:00,
#  202W0306-Ciclo3-Sec1- Docente 0A0280 - LUNES-17:00-22:00,
#  202W0307-Ciclo3-Sec1- Docente Z000006 - JUEVES-11:00-15:00,
#  202W0401-Ciclo4-Sec1- Docente 095753 - JUEVES-14:00-19:00,
#  202W0402-Ciclo4-Sec1- Docente Z000008 - MIERCOLES-14:00-18:00,
#  202W0403-Ciclo4-Sec1- Docente 0A4524 - SABADO-09:00-13:00,
#  202W0404-Ciclo4-Sec1- Docente 0A5230 - LUNES-17:00-21:00,
#  202W0405-Ciclo4-Sec1- Docente Z000011 - MARTES-16:00-20:00,
#  202W0407-Ciclo4-Sec1- Docente 095699 - VIERNES-17:00-22:00,
#  202W0501-Ciclo5-Sec1- Docente Z000013 - VIERNES-16:00-20:00,
#  202W0502-Ciclo5-Sec1- Docente Z000014 - JUEVES-10:00-14:00,
#  202W0503-Ciclo5-Sec1- Docente 01345428 - SABADO-14:00-18:00,
#  202W0504-Ciclo5-Sec1- Docente Z000016 - JUEVES-15:00-19:00,
#  202W0505-Ciclo5-Sec1- Docente Z000017 - MIERCOLES-08:00-13:00,
#  202W0506-Ciclo5-Sec1- Docente 0A5140 - MARTES-17:00-21:00,
#  202W0507-Ciclo5-Sec1- Docente Z000019 - MARTES-09:00-14:00,
#  202W0601-Ciclo6-Sec1- Docente 0A5291 - MIERCOLES-17:00-21:00,
#  202W0602-Ciclo6-Sec1- Docente 0A1876 - SABADO-17:00-22:00,
#  202W0603-Ciclo6-Sec1- Docente 0A4525 - JUEVES-12:00-17:00,
#  202W0604-Ciclo6-Sec1- Docente 0A1871 - MARTES-14:00-18:00,
#  202W0605-Ciclo6-Sec1- Docente 0A1875 - LUNES-10:00-15:00,
#  202W0606-Ciclo6-Sec1- Docente 0A7565 - LUNES-15:00-19:00,
#  202W0607-Ciclo6-Sec1- Docente 095702 - JUEVES-10:00-14:00,
#  202W0701-Ciclo7-Sec1- Docente 0A4525 - JUEVES-16:00-21:00,
#  202W0701-Ciclo7-Sec2- Docente Z000027 - LUNES-11:00-16:00,
#  202W0702-Ciclo7-Sec1- Docente 0A9179 - SABADO-11:00-16:00,
#  202W0702-Ciclo7-Sec2- Docente 0A2067 - MIERCOLES-17:00-22:00,
#  202W0703-Ciclo7-Sec1- Docente 0A0690 - VIERNES-08:00-12:00,
#  202W0703-Ciclo7-Sec2- Docente Z000032 - MIERCOLES-16:00-20:00,
#  202W0704-Ciclo7-Sec1- Docente 095753 - LUNES-16:00-20:00,
#  202W0705-Ciclo7-Sec1- Docente Z000035 - MARTES-10:00-14:00,
#  202W0705-Ciclo7-Sec2- Docente 0A0307 - JUEVES-12:00-16:00,
#  202W0706-Ciclo7-Sec1- Docente Z000037 - MARTES-16:00-20:00,
#  202W0706-Ciclo7-Sec2- Docente 0A1877 - LUNES-11:00-15:00,
#  202W0707-Ciclo7-Sec1- Docente Z000038 - VIERNES-15:00-19:00,
#  202W0707-Ciclo7-Sec2- Docente Z000039 - VIERNES-09:00-13:00,
#  202W0801-Ciclo8-Sec1- Docente Z000040 - VIERNES-09:00-13:00,
#  202W0802-Ciclo8-Sec1- Docente 0A1236 - MARTES-17:00-21:00,
#  202W0803-Ciclo8-Sec1- Docente 0A6225 - MIERCOLES-16:00-19:00,
#  202W0804-Ciclo8-Sec1- Docente 0A9124 - SABADO-08:00-12:00,
#  202W0805-Ciclo8-Sec1- Docente Z000044 - VIERNES-18:00-22:00,
#  202W0806-Ciclo8-Sec1- Docente Z000045 - JUEVES-13:00-17:00,
#  202W0807-Ciclo8-Sec1- Docente 0A1874 - JUEVES-17:00-21:00,
#  202W0808-Ciclo8-Sec1- Docente Z000047 - LUNES-18:00-22:00,
#  202W0901-Ciclo9-Sec1- Docente 0A0182 - JUEVES-09:00-12:00,
#  202W0901-Ciclo9-Sec2- Docente Z000048 - JUEVES-14:00-17:00,
#  202W0902-Ciclo9-Sec1- Docente Z000050 - JUEVES-13:00-17:00,
#  202W0902-Ciclo9-Sec2- Docente Z000051 - SABADO-15:00-19:00,
#  202W0903-Ciclo9-Sec1- Docente 0A1873 - MARTES-12:00-16:00,
#  202W0903-Ciclo9-Sec2- Docente 0A7565 - LUNES-18:00-22:00,
#  202W0904-Ciclo9-Sec1- Docente 09620253 - MIERCOLES-18:00-22:00,
#  202W0904-Ciclo9-Sec2- Docente Z000054 - JUEVES-10:00-14:00,
#  202W0905-Ciclo9-Sec1- Docente Z000056 - JUEVES-18:00-22:00,
#  202W0905-Ciclo9-Sec2- Docente 0A0690 - MIERCOLES-09:00-13:00,
#  202W0906-Ciclo9-Sec1- Docente Z000058 - LUNES-08:00-12:00,
#  202W0906-Ciclo9-Sec2- Docente 0A4523 - VIERNES-17:00-21:00,
#  202W0907-Ciclo9-Sec1- Docente Z000060 - MARTES-17:00-21:00,
#  202W0907-Ciclo9-Sec2- Docente 43813470 - MARTES-16:00-20:00,
#  202W0908-Ciclo9-Sec1- Docente Z000062 - SABADO-08:00-12:00,
#  202W0908-Ciclo9-Sec2- Docente 0A2417 - MIERCOLES-09:00-13:00,
#  202W1001-Ciclo10-Sec1- Docente 0A2067 - MARTES-18:00-22:00,
#  202W1002-Ciclo10-Sec1- Docente 0A5230 - VIERNES-12:00-15:00,
#  202W1003-Ciclo10-Sec1- Docente 0A1876 - MIERCOLES-10:00-16:00,
#  202W1004-Ciclo10-Sec1- Docente 0A1874 - SABADO-11:00-16:00,
#  202W1005-Ciclo10-Sec1- Docente 0A1874 - JUEVES-18:00-22:00,
#  202W1006-Ciclo10-Sec1- Docente 0A1877 - SABADO-13:00-17:00,
#  INE002-Ciclo1-Sec1- Docente 0A0182 - JUEVES-19:00-22:00,
#  INO101-Ciclo1-Sec1- Docente Z000071 - JUEVES-15:00-19:00,
#  INO102-Ciclo1-Sec1- Docente 42229911 - VIERNES-14:00-17:00,
#  INO103-Ciclo1-Sec1- Docente Z000073 - LUNES-16:00-19:00,
#  INO106-Ciclo1-Sec1- Docente Z000074 - LUNES-09:00-15:00,
#  INO204-Ciclo2-Sec1- Docente 40764399 - JUEVES-10:00-16:00,
#  INO205-Ciclo2-Sec1- Docente 0A4049 - VIERNES-08:00-13:00]

# %%
import matplotlib.pyplot as plt

def graficar_penalidades_por_constraint(historial_penalidad):
    claves = historial_penalidad[0].keys()
    penalidades_por_constraint = {clave: [] for clave in claves}

    for generacion in historial_penalidad:
        for clave in claves:
            penalidades_por_constraint[clave].append(generacion.get(clave, 0))

    plt.figure(figsize=(12, 6))
    for clave, valores in penalidades_por_constraint.items():
        plt.plot(valores, label=clave)

    plt.xlabel("Generación")
    plt.ylabel("Penalidad")
    plt.title("Evolución de penalidades por constraint")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
graficar_penalidades_por_constraint(historial_dicts)

# %%
historial_dicts
# Out:
# [{'Cursos del mismo ciclo no deben compartir franja': 114,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 25,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 0,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 114,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 25,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 0,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 114,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 25,
#   'Cursos 1-5 ciclo preferencia horario': 16,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 24,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 0,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 62},
#  {'Cursos del mismo ciclo no deben compartir franja': 126,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 10,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 213,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 78,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 15,
#   'Cursos 1-5 ciclo preferencia horario': 20,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 3,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 64},
#  {'Cursos del mismo ciclo no deben compartir franja': 84,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 36,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 56},
#  {'Cursos del mismo ciclo no deben compartir franja': 84,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 36,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 56},
#  {'Cursos del mismo ciclo no deben compartir franja': 84,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 36,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 56},
#  {'Cursos del mismo ciclo no deben compartir franja': 84,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 36,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 56},
#  {'Cursos del mismo ciclo no deben compartir franja': 84,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 216,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 36,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 56},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 222,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 27,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 6,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 46},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 213,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 40},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 213,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 40},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 213,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 40},
#  {'Cursos del mismo ciclo no deben compartir franja': 90,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 4,
#   'Preferencias horarias del docente': 213,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 30,
#   'Evitar huecos >3h en un mismo día (docente)': 0,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 40},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
# ...
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50},
#  {'Cursos del mismo ciclo no deben compartir franja': 72,
#   'Cursos deben cumplir totalidad de horas': 0,
#   'Cursos deben estar entre 8am-1pm y 2pm-10pm': 0,
#   'Docente dicta máximo 4 cursos': 0,
#   'Cantidad mínima de docentes por curso': 0,
#   'Cursos 1-5 ciclo preferencia horario': 8,
#   'Preferencias horarias del docente': 207,
#   'Evitar 3 franjas distintas mismo día (mismo ciclo)': 21,
#   'Evitar huecos >3h en un mismo día (docente)': 3,
#   'Evitar huecos >3h en un mismo día (ciclo)': 9,
#   'Evitar solapes de no-prereqs entre ciclos cercanos': 50}]

# %% [markdown]
# # 5. Algoritmo Tabu

# %%
def calcular_fitness_cromosomas(individuo):
    penalidad_total = 0
    detalles_penalidades = []
    penalidad_por_constrain = []

    # Constraints aplicables a nivel de cromosoma (asignación)
    for funcion, nombre_constraint, peso in [
        (constrain_franjas_validas, "Cursos deben estar entre 8am-1pm y 2pm-10pm", 6),
        (constrain_ciclos_bajos_horario_preferido, "Cursos 1-5 ciclo preferencia horario", 4),
        (constrain_preferencias_docente, "Preferencias horarias del docente", 3),
    ]:
        penalidad, descripcion = funcion(individuo)
        penalidad_ponderada = penalidad * peso
        penalidad_por_constrain.append({"nombre_constraint": nombre_constraint, "penalidad": penalidad_ponderada})
        penalidad_total += penalidad_ponderada
        detalles_penalidades.append((nombre_constraint, penalidad, peso, penalidad_ponderada, descripcion))

    return penalidad_total, detalles_penalidades, penalidad_por_constrain

# %%
def generar_vecindario_inteligente(individuo, top_k=3, n_vecinos=5):
    """
    Genera vecinos inteligentes del individuo, modificando asignaciones con más penalizaciones.
    - df_disp: DataFrame con columnas [CodDocente, CodAsignatura, Día, HoraInicio, HoraFin, DuracionHoras, Ciclo]
    """
    vecinos = []

    # Evaluamos penalizaciones del individuo original
    _, _, penalidades_por_asignacion = calcular_fitness(individuo)

    # Ordenar por penalización más alta
    asignaciones_ordenadas = sorted(
        zip(individuo.asignaciones, penalidades_por_asignacion),
        key=lambda x: sum(float(v) for v in x[1].values() if isinstance(v, (int, float)) or (isinstance(v, str) and v.replace('.', '', 1).isdigit())),
        reverse=True
    )


    # Seleccionar las asignaciones más penalizadas
    top_conflictivas = [x[0] for x in asignaciones_ordenadas[:top_k]]

    for _ in range(n_vecinos):
        nuevo_individuo = deepcopy(individuo)

        for asignacion_conflictiva in top_conflictivas:
            # Buscar alternativas en df_disp para este docente y curso
            opciones = df_disp[
                (df_disp['CodDocente'].astype(str).str.strip() == str(asignacion_conflictiva.cod_docente).strip()) &
                (df_disp['CodAsignatura'] == asignacion_conflictiva.cod_asignatura)
            ]

            if not opciones.empty:
                nueva_opcion = opciones.sample(1).iloc[0]

                # Modificar la asignación conflictiva en el individuo
                for asignacion in nuevo_individuo.asignaciones:
                    if (
                        asignacion.cod_docente == asignacion_conflictiva.cod_docente and
                        asignacion.cod_asignatura == asignacion_conflictiva.cod_asignatura and
                        asignacion.dia == asignacion_conflictiva.dia and
                        asignacion.hora_inicio == asignacion_conflictiva.hora_inicio
                    ):
                        asignacion.dia = nueva_opcion["Día"]
                        asignacion.hora_inicio = nueva_opcion["HoraInicio"]
                        asignacion.hora_fin = nueva_opcion["HoraFin"]
                        break  # solo modifica una vez

        vecinos.append(nuevo_individuo)

    return vecinos

# %%
from typing import Tuple, List

def algoritmo_tabu_solapamientos_y_minsecciones(
    individuo_inicial: Individuo,
    calcular_fitness,
    max_iter: int = 100,
    tabu_tam: int = 20
) -> Tuple[Individuo, List[float]]:
    
    actual = deepcopy(individuo_inicial)
    mejor = deepcopy(individuo_inicial)
    tabu_lista = []
    historial_penalidades = []

    mejor_penalidad, _, _ = calcular_fitness(mejor)
    
    for iteracion in range(max_iter):
        vecinos = generar_vecindario_inteligente(actual)
        vecinos_filtrados = [v for v in vecinos if v not in tabu_lista]
        
        if not vecinos_filtrados:
            break

        penalidades_vecinos = [calcular_fitness(v)[0] for v in vecinos_filtrados]
        mejor_vecino = vecinos_filtrados[penalidades_vecinos.index(min(penalidades_vecinos))]

        actual = mejor_vecino
        tabu_lista.append(actual)
        if len(tabu_lista) > tabu_tam:
            tabu_lista.pop(0)

        penalidad_actual, _, _ = calcular_fitness(actual)
        historial_penalidades.append(penalidad_actual)

        if penalidad_actual < mejor_penalidad:
            mejor = deepcopy(actual)
            mejor_penalidad = penalidad_actual

    return mejor, historial_penalidades

# %%
type(mejor_individuo[0][0])
# Out:
# __main__.Asignacion

# %%
individuo_inicial = Individuo(asignaciones=mejor_individuo[0])

# %%
mejor_individuo_t, historial_penalidades_t = algoritmo_tabu_solapamientos_y_minsecciones(
    individuo_inicial=individuo_inicial,
    calcular_fitness=calcular_fitness,
    max_iter=200,
    tabu_tam=60
)

# %%
import matplotlib.pyplot as plt

plt.plot(historial_penalidades_t)
plt.xlabel("Iteración")
plt.ylabel("Penalidad")
plt.title("Evolución de penalidad - Algoritmo Tabú")
plt.grid(True)
plt.show()

# %%
historial_penalidades_t
# Out:
# [365]

# %%
type(mejor_individuo_t)
# Out:
# __main__.Individuo

# %%
penalidad_final_t,detalles_penalidad_final_t,penalidad_por_constrain_final_t = calcular_fitness(mejor_individuo_t)

# %%
detalles_penalidad_final_t
# Out:
# [('Cursos del mismo ciclo no deben compartir franja',
#   14,
#   6,
#   84,
#   ['Solapamiento en ciclo 3: 202W0301-Sec1 y 202W0306-Sec1 el LUNES entre 14:00-19:00 y 17:00-22:00',
#    'Solapamiento en ciclo 3: 202W0303-Sec1 y 202W0304-Sec1 el MARTES entre 09:00-13:00 y 09:00-13:00',
#    'Solapamiento en ciclo 3: 202W0305-Sec1 y 202W0307-Sec1 el MIERCOLES entre 15:00-19:00 y 12:00-16:00',
#    'Solapamiento en ciclo 4: 202W0402-Sec1 y 202W0404-Sec1 el MIERCOLES entre 14:00-18:00 y 14:00-18:00',
#    'Solapamiento en ciclo 6: 202W0603-Sec1 y 202W0607-Sec1 el JUEVES entre 12:00-17:00 y 10:00-14:00',
#    'Solapamiento en ciclo 7: 202W0701-Sec2 y 202W0706-Sec2 el LUNES entre 11:00-16:00 y 11:00-15:00',
#    'Solapamiento en ciclo 7: 202W0702-Sec2 y 202W0703-Sec2 el MIERCOLES entre 17:00-22:00 y 16:00-20:00',
#    'Solapamiento en ciclo 7: 202W0703-Sec1 y 202W0707-Sec2 el VIERNES entre 08:00-12:00 y 09:00-13:00',
#    'Solapamiento en ciclo 9: 202W0901-Sec1 y 202W0904-Sec2 el JUEVES entre 09:00-12:00 y 10:00-14:00',
#    'Solapamiento en ciclo 9: 202W0901-Sec2 y 202W0902-Sec1 el JUEVES entre 14:00-17:00 y 13:00-17:00',
#    'Solapamiento en ciclo 9: 202W0902-Sec1 y 202W0904-Sec2 el JUEVES entre 13:00-17:00 y 10:00-14:00',
#    'Solapamiento en ciclo 9: 202W0905-Sec2 y 202W0908-Sec2 el MIERCOLES entre 09:00-13:00 y 09:00-13:00',
#    'Solapamiento en ciclo 9: 202W0907-Sec1 y 202W0907-Sec2 el MARTES entre 17:00-21:00 y 16:00-20:00',
#    'Solapamiento en ciclo 10: 202W1004-Sec1 y 202W1006-Sec1 el SABADO entre 11:00-16:00 y 13:00-17:00']),
#  ('Cursos deben cumplir totalidad de horas', 0, 6, 0, []),
#  ('Cursos deben estar entre 8am-1pm y 2pm-10pm', 0, 6, 0, []),
#  ('Docente dicta máximo 4 cursos', 0, 5, 0, []),
#  ('Cantidad mínima de docentes por curso', 0, 5, 0, []),
#  ('Cursos 1-5 ciclo preferencia horario',
#   1,
#   4,
#   4,
#   [{'Motivo': 'Clase después de las 6pm',
#     'CodAsignatura': 'INE002',
#     'Ciclo': 1,
#     'HoraInicio': '19:00',
#     'CodDocente': '0A0182',
#     'Día': 'JUEVES'}]),
#  ('Preferencias horarias del docente',
#   66,
#   3,
#   198,
#   ['043788 fuera de preferencia en VIERNES de 17:00:00 a 22:00:00',
#    '0A06292 fuera de preferencia en MARTES de 09:00:00 a 13:00:00',
#    'Z000003 fuera de preferencia en MARTES de 09:00:00 a 13:00:00',
#    '0A0314 fuera de preferencia en MIERCOLES de 15:00:00 a 19:00:00',
#    '0A0280 fuera de preferencia en LUNES de 17:00:00 a 22:00:00',
#    '095753 fuera de preferencia en JUEVES de 14:00:00 a 19:00:00',
#    'Z000008 fuera de preferencia en MIERCOLES de 14:00:00 a 18:00:00',
#    '0A4524 fuera de preferencia en SABADO de 09:00:00 a 13:00:00',
#    'Z000011 fuera de preferencia en MARTES de 16:00:00 a 20:00:00',
#    '095699 fuera de preferencia en VIERNES de 17:00:00 a 22:00:00',
#    'Z000013 fuera de preferencia en VIERNES de 16:00:00 a 20:00:00',
#    'Z000014 fuera de preferencia en JUEVES de 10:00:00 a 14:00:00',
#    '01345428 fuera de preferencia en SABADO de 14:00:00 a 18:00:00',
#    'Z000016 fuera de preferencia en JUEVES de 15:00:00 a 19:00:00',
#    '0A5140 fuera de preferencia en MARTES de 17:00:00 a 21:00:00',
#    'Z000019 fuera de preferencia en MARTES de 09:00:00 a 14:00:00',
#    '0A5291 fuera de preferencia en MIERCOLES de 17:00:00 a 21:00:00',
#    '0A4525 fuera de preferencia en JUEVES de 12:00:00 a 17:00:00',
#    '0A1875 fuera de preferencia en LUNES de 10:00:00 a 15:00:00',
#    '0A7565 fuera de preferencia en LUNES de 15:00:00 a 19:00:00',
#    '095702 fuera de preferencia en JUEVES de 10:00:00 a 14:00:00',
#    '0A4525 fuera de preferencia en JUEVES de 16:00:00 a 21:00:00',
#    'Z000027 fuera de preferencia en LUNES de 11:00:00 a 16:00:00',
#    '0A9179 fuera de preferencia en SABADO de 11:00:00 a 16:00:00',
#    '0A2067 fuera de preferencia en MIERCOLES de 17:00:00 a 22:00:00',
#    '0A0690 fuera de preferencia en VIERNES de 08:00:00 a 12:00:00',
#    'Z000032 fuera de preferencia en MIERCOLES de 16:00:00 a 20:00:00',
#    '095753 fuera de preferencia en LUNES de 16:00:00 a 20:00:00',
#    'Z000035 fuera de preferencia en MARTES de 10:00:00 a 14:00:00',
#    '0A0307 fuera de preferencia en JUEVES de 12:00:00 a 16:00:00',
#    'Z000037 fuera de preferencia en MARTES de 16:00:00 a 20:00:00',
#    '0A1877 fuera de preferencia en LUNES de 11:00:00 a 15:00:00',
#    'Z000038 fuera de preferencia en VIERNES de 15:00:00 a 19:00:00',
#    'Z000039 fuera de preferencia en VIERNES de 09:00:00 a 13:00:00',
#    'Z000040 fuera de preferencia en VIERNES de 09:00:00 a 13:00:00',
#    '0A1236 fuera de preferencia en MARTES de 17:00:00 a 21:00:00',
#    '0A6225 fuera de preferencia en MIERCOLES de 16:00:00 a 19:00:00',
#    '0A9124 fuera de preferencia en SABADO de 08:00:00 a 12:00:00',
#    'Z000044 fuera de preferencia en VIERNES de 18:00:00 a 22:00:00',
#    'Z000045 fuera de preferencia en JUEVES de 13:00:00 a 17:00:00',
#    '0A0182 fuera de preferencia en JUEVES de 09:00:00 a 12:00:00',
#    'Z000048 fuera de preferencia en JUEVES de 14:00:00 a 17:00:00',
#    'Z000050 fuera de preferencia en JUEVES de 13:00:00 a 17:00:00',
#    'Z000051 fuera de preferencia en SABADO de 15:00:00 a 19:00:00',
#    '0A1873 fuera de preferencia en MARTES de 12:00:00 a 16:00:00',
#    '0A7565 fuera de preferencia en LUNES de 18:00:00 a 22:00:00',
#    '09620253 fuera de preferencia en MIERCOLES de 18:00:00 a 22:00:00',
#    'Z000054 fuera de preferencia en JUEVES de 10:00:00 a 14:00:00',
#    'Z000056 fuera de preferencia en JUEVES de 18:00:00 a 22:00:00',
#    '0A0690 fuera de preferencia en MIERCOLES de 09:00:00 a 13:00:00',
#    'Z000058 fuera de preferencia en LUNES de 08:00:00 a 12:00:00',
#    '0A4523 fuera de preferencia en VIERNES de 17:00:00 a 21:00:00',
#    'Z000060 fuera de preferencia en MARTES de 17:00:00 a 21:00:00',
#    '43813470 fuera de preferencia en MARTES de 16:00:00 a 20:00:00',
#    'Z000062 fuera de preferencia en SABADO de 08:00:00 a 12:00:00',
#    '0A2417 fuera de preferencia en MIERCOLES de 09:00:00 a 13:00:00',
#    '0A5230 fuera de preferencia en VIERNES de 12:00:00 a 15:00:00',
#    '0A1876 fuera de preferencia en MIERCOLES de 10:00:00 a 16:00:00',
#    '0A1874 fuera de preferencia en SABADO de 11:00:00 a 16:00:00',
#    '0A1877 fuera de preferencia en SABADO de 13:00:00 a 17:00:00',
#    '0A0182 fuera de preferencia en JUEVES de 19:00:00 a 22:00:00',
#    'Z000071 fuera de preferencia en JUEVES de 15:00:00 a 19:00:00',
#    'Z000073 fuera de preferencia en LUNES de 16:00:00 a 19:00:00',
#    'Z000074 fuera de preferencia en LUNES de 09:00:00 a 15:00:00',
#    '40764399 fuera de preferencia en JUEVES de 10:00:00 a 16:00:00',
#    '0A4049 fuera de preferencia en VIERNES de 08:00:00 a 13:00:00']),
#  ('Evitar 3 franjas distintas mismo día (mismo ciclo)',
#   7,
#   3,
#   21,
#   ['Ciclo 7 tiene 3 cursos el LUNES',
#    'Ciclo 7 tiene 3 cursos el VIERNES',
#    'Ciclo 9 tiene 5 cursos el JUEVES',
#    'Ciclo 9 tiene 3 cursos el MARTES',
#    'Ciclo 9 tiene 3 cursos el MIERCOLES']),
#  ('Evitar huecos >3h en un mismo día (docente)',
#   1,
#   3,
#   3,
#   ['0A0182 tiene espacio de 7.0h el JUEVES']),
#  ('Evitar huecos >3h en un mismo día (ciclo)',
#   3,
#   3,
#   9,
#   ['Ciclo 8 tiene espacio de 5.0h el VIERNES',
#    'Ciclo 9 tiene espacio de 6.0h el LUNES',
#    'Ciclo 9 tiene espacio de 5.0h el MIERCOLES']),
#  ('Evitar solapes de no-prereqs entre ciclos cercanos',
#   23,
#   2,
#   46,
#   ['Curso 202W0405 se dicta antes que su prerrequisito 202W0302',
#    'Curso 202W0502 se dicta antes que su prerrequisito 202W0407',
#    'Curso 202W0505 se dicta antes que su prerrequisito 202W0401',
#    'Curso 202W0506 se dicta antes que su prerrequisito 202W0402',
#    'Curso 202W0601 se dicta antes que su prerrequisito 202W0503',
#    'Curso 202W0604 se dicta antes que su prerrequisito 202W0506',
#    'Curso 202W0604 se dicta antes que su prerrequisito 202W0403',
#    'Curso 202W0606 se dicta antes que su prerrequisito 202W0504',
#    'Curso 202W0701 se dicta antes que su prerrequisito 202W0602',
#    'Curso 202W0701 se dicta antes que su prerrequisito 202W0603',
#    'Curso 202W0701 se dicta antes que su prerrequisito 202W0601',
#    'Curso 202W0702 se dicta antes que su prerrequisito 202W0602',
#    'Curso 202W0703 se dicta antes que su prerrequisito 202W0603',
#    'Curso 202W0704 se dicta antes que su prerrequisito 202W0604',
#    'Curso 202W0706 se dicta antes que su prerrequisito 202W0503',
#    'Curso 202W0802 se dicta antes que su prerrequisito 202W0501',
#    'Curso 202W0802 se dicta antes que su prerrequisito 202W0702',
#    'Curso 202W0806 se dicta antes que su prerrequisito 202W0707',
#    'Curso 202W0807 se dicta antes que su prerrequisito 202W0707',
#    'Curso 202W0904 se dicta antes que su prerrequisito 202W0807',
#    'Curso 202W0906 se dicta antes que su prerrequisito 202W0801',
#    'Curso 202W0907 se dicta antes que su prerrequisito 202W0807',
#    'Curso 202W1001 se dicta antes que su prerrequisito 202W0908'])]

# %%
mejor_individuo_t
# Out:
# Individuo(asignaciones=[202W0301-Ciclo3-Sec1- Docente 085774 - LUNES-14:00-19:00, 202W0302-Ciclo3-Sec1- Docente 043788 - VIERNES-17:00-22:00, 202W0303-Ciclo3-Sec1- Docente 0A06292 - MARTES-09:00-13:00, 202W0304-Ciclo3-Sec1- Docente Z000003 - MARTES-09:00-13:00, 202W0305-Ciclo3-Sec1- Docente 0A0314 - MIERCOLES-15:00-19:00, 202W0306-Ciclo3-Sec1- Docente 0A0280 - LUNES-17:00-22:00, 202W0307-Ciclo3-Sec1- Docente Z000006 - MIERCOLES-12:00-16:00, 202W0401-Ciclo4-Sec1- Docente 095753 - JUEVES-14:00-19:00, 202W0402-Ciclo4-Sec1- Docente Z000008 - MIERCOLES-14:00-18:00, 202W0403-Ciclo4-Sec1- Docente 0A4524 - SABADO-09:00-13:00, 202W0404-Ciclo4-Sec1- Docente 0A5230 - MIERCOLES-14:00-18:00, 202W0405-Ciclo4-Sec1- Docente Z000011 - MARTES-16:00-20:00, 202W0407-Ciclo4-Sec1- Docente 095699 - VIERNES-17:00-22:00, 202W0501-Ciclo5-Sec1- Docente Z000013 - VIERNES-16:00-20:00, 202W0502-Ciclo5-Sec1- Docente Z000014 - JUEVES-10:00-14:00, 202W0503-Ciclo5-Sec1- Docente 01345428 - SABADO-14:00-18:00, 202W0504-Ciclo5-Sec1- Docente Z000016 - JUEVES-15:00-19:00, 202W0505-Ciclo5-Sec1- Docente Z000017 - MIERCOLES-08:00-13:00, 202W0506-Ciclo5-Sec1- Docente 0A5140 - MARTES-17:00-21:00, 202W0507-Ciclo5-Sec1- Docente Z000019 - MARTES-09:00-14:00, 202W0601-Ciclo6-Sec1- Docente 0A5291 - MIERCOLES-17:00-21:00, 202W0602-Ciclo6-Sec1- Docente 0A1876 - SABADO-17:00-22:00, 202W0603-Ciclo6-Sec1- Docente 0A4525 - JUEVES-12:00-17:00, 202W0604-Ciclo6-Sec1- Docente 0A1871 - MARTES-14:00-18:00, 202W0605-Ciclo6-Sec1- Docente 0A1875 - LUNES-10:00-15:00, 202W0606-Ciclo6-Sec1- Docente 0A7565 - LUNES-15:00-19:00, 202W0607-Ciclo6-Sec1- Docente 095702 - JUEVES-10:00-14:00, 202W0701-Ciclo7-Sec1- Docente 0A4525 - JUEVES-16:00-21:00, 202W0701-Ciclo7-Sec2- Docente Z000027 - LUNES-11:00-16:00, 202W0702-Ciclo7-Sec1- Docente 0A9179 - SABADO-11:00-16:00, 202W0702-Ciclo7-Sec2- Docente 0A2067 - MIERCOLES-17:00-22:00, 202W0703-Ciclo7-Sec1- Docente 0A0690 - VIERNES-08:00-12:00, 202W0703-Ciclo7-Sec2- Docente Z000032 - MIERCOLES-16:00-20:00, 202W0704-Ciclo7-Sec1- Docente 095753 - LUNES-16:00-20:00, 202W0705-Ciclo7-Sec1- Docente Z000035 - MARTES-10:00-14:00, 202W0705-Ciclo7-Sec2- Docente 0A0307 - JUEVES-12:00-16:00, 202W0706-Ciclo7-Sec1- Docente Z000037 - MARTES-16:00-20:00, 202W0706-Ciclo7-Sec2- Docente 0A1877 - LUNES-11:00-15:00, 202W0707-Ciclo7-Sec1- Docente Z000038 - VIERNES-15:00-19:00, 202W0707-Ciclo7-Sec2- Docente Z000039 - VIERNES-09:00-13:00, 202W0801-Ciclo8-Sec1- Docente Z000040 - VIERNES-09:00-13:00, 202W0802-Ciclo8-Sec1- Docente 0A1236 - MARTES-17:00-21:00, 202W0803-Ciclo8-Sec1- Docente 0A6225 - MIERCOLES-16:00-19:00, 202W0804-Ciclo8-Sec1- Docente 0A9124 - SABADO-08:00-12:00, 202W0805-Ciclo8-Sec1- Docente Z000044 - VIERNES-18:00-22:00, 202W0806-Ciclo8-Sec1- Docente Z000045 - JUEVES-13:00-17:00, 202W0807-Ciclo8-Sec1- Docente 0A1874 - JUEVES-17:00-21:00, 202W0808-Ciclo8-Sec1- Docente Z000047 - LUNES-18:00-22:00, 202W0901-Ciclo9-Sec1- Docente 0A0182 - JUEVES-09:00-12:00, 202W0901-Ciclo9-Sec2- Docente Z000048 - JUEVES-14:00-17:00, 202W0902-Ciclo9-Sec1- Docente Z000050 - JUEVES-13:00-17:00, 202W0902-Ciclo9-Sec2- Docente Z000051 - SABADO-15:00-19:00, 202W0903-Ciclo9-Sec1- Docente 0A1873 - MARTES-12:00-16:00, 202W0903-Ciclo9-Sec2- Docente 0A7565 - LUNES-18:00-22:00, 202W0904-Ciclo9-Sec1- Docente 09620253 - MIERCOLES-18:00-22:00, 202W0904-Ciclo9-Sec2- Docente Z000054 - JUEVES-10:00-14:00, 202W0905-Ciclo9-Sec1- Docente Z000056 - JUEVES-18:00-22:00, 202W0905-Ciclo9-Sec2- Docente 0A0690 - MIERCOLES-09:00-13:00, 202W0906-Ciclo9-Sec1- Docente Z000058 - LUNES-08:00-12:00, 202W0906-Ciclo9-Sec2- Docente 0A4523 - VIERNES-17:00-21:00, 202W0907-Ciclo9-Sec1- Docente Z000060 - MARTES-17:00-21:00, 202W0907-Ciclo9-Sec2- Docente 43813470 - MARTES-16:00-20:00, 202W0908-Ciclo9-Sec1- Docente Z000062 - SABADO-08:00-12:00, 202W0908-Ciclo9-Sec2- Docente 0A2417 - MIERCOLES-09:00-13:00, 202W1001-Ciclo10-Sec1- Docente 0A2067 - MARTES-18:00-22:00, 202W1002-Ciclo10-Sec1- Docente 0A5230 - VIERNES-12:00-15:00, 202W1003-C ...

# %%
from datetime import datetime

def individuo_a_df(individuo):
    data = []
    for a in individuo.asignaciones:
        hora_inicio = datetime.strptime(a.hora_inicio, "%H:%M")
        hora_fin = datetime.strptime(a.hora_fin, "%H:%M")
        duracion = (hora_fin - hora_inicio).seconds // 3600  # duración en horas

        data.append({
            "CodAsignatura": a.cod_asignatura,
            "Ciclo": a.ciclo,
            "Seccion": a.seccion,
            "CodDocente": a.cod_docente,
            "Día": a.dia,
            "HoraInicio": a.hora_inicio,
            "HoraFin": a.hora_fin,
            "DuraciónHoras": duracion
        })

    return pd.DataFrame(data)

# %%
df = individuo_a_df(mejor_individuo_t)
df
# Out:
#    CodAsignatura  Ciclo  Seccion CodDocente        Día HoraInicio HoraFin  \
# 0       202W0301      3        1     085774      LUNES      14:00   19:00
# 1       202W0302      3        1     043788    VIERNES      17:00   22:00
# 2       202W0303      3        1    0A06292     MARTES      09:00   13:00
# 3       202W0304      3        1    Z000003     MARTES      09:00   13:00
# 4       202W0305      3        1     0A0314  MIERCOLES      15:00   19:00
# ..           ...    ...      ...        ...        ...        ...     ...
# 72        INO102      1        1   42229911    VIERNES      14:00   17:00
# 73        INO103      1        1    Z000073      LUNES      16:00   19:00
# 74        INO106      1        1    Z000074      LUNES      09:00   15:00
# 75        INO204      2        1   40764399     JUEVES      10:00   16:00
# 76        INO205      2        1     0A4049    VIERNES      08:00   13:00
#
#     DuraciónHoras
# 0               5
# 1               5
# 2               4
# 3               4
# 4               4
# ..            ...
# 72              3
# 73              3
# 74              6
# 75              6
# 76              5
#
# [77 rows x 8 columns]

# %%
df.to_csv("horario_fisi_completo.csv",sep=";",encoding="utf-8-sig")
